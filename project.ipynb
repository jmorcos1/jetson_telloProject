# %% [markdown]
# # Remotely Viewing RTP stream

# %% [markdown]
# ### Step 1: Install VLC player on your PC
# ### Step 2: Create a .stp file with these contents:
#     c=IN IP4 127.0.0.1
#     m=video 1234 RTP/AVP 96
#     a=rtpmap:96 H264/90000

# %% [markdown]
# # Get to Know Jetson Inference

# %%
# CHAMGE to <your PC's IP address>:1234
# !video-viewer /dev/video0 rtp://192.168.1.13:1234
# Out:
# [gstreamer] initialized gstreamer, version 1.14.5.0
# [gstreamer] gstCamera -- attempting to create device v4l2:///dev/video0
# [gstreamer] gstCamera -- found v4l2 device: USB Camera
# [gstreamer] v4l2-proplist, device.path=(string)/dev/video0, udev-probed=(boolean)false, device.api=(string)v4l2, v4l2.device.driver=(string)uvcvideo, v4l2.device.card=(string)"USB\ Camera", v4l2.device.bus_info=(string)usb-70090000.xusb-2.3, v4l2.device.version=(uint)264701, v4l2.device.capabilities=(uint)2216689665, v4l2.device.device_caps=(uint)69206017;
# [gstreamer] gstCamera -- found 26 caps for v4l2 device /dev/video0
# [gstreamer] [0] video/x-raw, format=(string)YUY2, width=(int)1920, height=(int)1080, pixel-aspect-ratio=(fraction)1/1, framerate=(fraction)5/1;
# [gstreamer] [1] video/x-raw, format=(string)YUY2, width=(int)1280, height=(int)960, pixel-aspect-ratio=(fraction)1/1, framerate=(fraction)5/1;
# [gstreamer] [2] video/x-raw, format=(string)YUY2, width=(int)1280, height=(int)720, pixel-aspect-ratio=(fraction)1/1, framerate=(fraction)10/1;
# [gstreamer] [3] video/x-raw, format=(string)YUY2, width=(int)1024, height=(int)768, pixel-aspect-ratio=(fraction)1/1, framerate=(fraction)15/1;
# [gstreamer] [4] video/x-raw, format=(string)YUY2, width=(int)1280, height=(int)480, pixel-aspect-ratio=(fraction)1/1, framerate=(fraction)10/1;
# [gstreamer] [5] video/x-raw, format=(string)YUY2, width=(int)800, height=(int)600, pixel-aspect-ratio=(fraction)1/1, framerate=(fraction)20/1;
# [gstreamer] [6] video/x-raw, format=(string)YUY2, width=(int)848, height=(int)480, pixel-aspect-ratio=(fraction)1/1, framerate=(fraction)20/1;
# [gstreamer] [7] video/x-raw, format=(string)YUY2, width=(int)640, height=(int)480, pixel-aspect-ratio=(fraction)1/1, framerate=(fraction)30/1;
# [gstreamer] [8] video/x-raw, format=(string)YUY2, width=(int)640, height=(int)400, pixel-aspect-ratio=(fraction)1/1, framerate=(fraction)30/1;
# [gstreamer] [9] video/x-raw, format=(string)YUY2, width=(int)352, height=(int)288, pixel-aspect-ratio=(fraction)1/1, framerate=(fraction)30/1;
# [gstreamer] [10] video/x-raw, format=(string)YUY2, width=(int)320, height=(int)240, pixel-aspect-ratio=(fraction)1/1, framerate=(fraction)30/1;
# [gstreamer] [11] video/x-raw, format=(string)YUY2, width=(int)176, height=(int)144, pixel-aspect-ratio=(fraction)1/1, framerate=(fraction)30/1;
# [gstreamer] [12] video/x-raw, format=(string)YUY2, width=(int)160, height=(int)120, pixel-aspect-ratio=(fraction)1/1, framerate=(fraction){ 30/1, 5/1 };
# [gstreamer] [13] image/jpeg, width=(int)1920, height=(int)1080, pixel-aspect-ratio=(fraction)1/1, framerate=(fraction)30/1;
# [gstreamer] [14] image/jpeg, width=(int)1280, height=(int)1024, pixel-aspect-ratio=(fraction)1/1, framerate=(fraction)30/1;
# [gstreamer] [15] image/jpeg, width=(int)1280, height=(int)960, pixel-aspect-ratio=(fraction)1/1, framerate=(fraction)30/1;
# [gstreamer] [16] image/jpeg, width=(int)1280, height=(int)720, pixel-aspect-ratio=(fraction)1/1, framerate=(fraction){ 30/1, 5/1 };
# [gstreamer] [17] image/jpeg, width=(int)1280, height=(int)480, pixel-aspect-ratio=(fraction)1/1, framerate=(fraction)30/1;
# [gstreamer] [18] image/jpeg, width=(int)800, height=(int)600, pixel-aspect-ratio=(fraction)1/1, framerate=(fraction){ 30/1, 5/1 };
# [gstreamer] [19] image/jpeg, width=(int)848, height=(int)480, pixel-aspect-ratio=(fraction)1/1, framerate=(fraction)30/1;
# [gstreamer] [20] image/jpeg, width=(int)640, height=(int)480, pixel-aspect-ratio=(fraction)1/1, framerate=(fraction){ 30/1, 5/1 };
# [gstreamer] [21] image/jpeg, width=(int)640, height=(int)400, pixel-aspect-ratio=(fraction)1/1, framerate=(fraction)30/1;
# [gstreamer] [22] image/jpeg, width=(int)352, height=(int)288, pixel-aspect-ratio=(fraction)1/1, framerate=(fraction)30/1;
# [gstreamer] [23] image/jpeg, width=(int)320, height=(int)240, pixel-aspect-ratio=(fraction)1/1, framerate=(fraction){ 30/1, 5/1 };
# [gstreamer] [24] image/jpeg, width=(int)176, height=(int)144, pixel-aspect-ratio=(fraction)1/1, framerate=(fraction)30/1;
# [gstreamer] [25] image/jpeg, width=(int)160, height=(int)120, pixel-aspect-ratio=(fraction)1/1, framerate=(fraction){ 30/1, 5/1 };
# [gstreamer] gstCamera -- selected device profile:  codec=mjpeg format=unknown width=1280 height=720
# [gstreamer] gstCamera pipeline string:
# [gstreamer] v4l2src device=/dev/video0 ! image/jpeg, width=(int)1280, height=(int)720 ! jpegdec ! video/x-raw ! appsink name=mysink
# [gstreamer] gstCamera successfully created device v4l2:///dev/video0
# [video]  created gstCamera from v4l2:///dev/video0
# ------------------------------------------------
# gstCamera video options:
# ------------------------------------------------
#   -- URI: v4l2:///dev/video0
#      - protocol:  v4l2
#      - location:  /dev/video0
#   -- deviceType: v4l2
#   -- ioType:     input
#   -- codec:      mjpeg
#   -- width:      1280
#   -- height:     720
#   -- frameRate:  30.000000
#   -- bitRate:    0
#   -- numBuffers: 4
#   -- zeroCopy:   true
#   -- flipMethod: none
#   -- loop:       0
#   -- rtspLatency 2000
# ------------------------------------------------
# [gstreamer] gstEncoder -- codec not specified, defaulting to H.264
# [gstreamer] gstEncoder -- pipeline launch string:
# [gstreamer] appsrc name=mysource is-live=true do-timestamp=true format=3 ! omxh264enc bitrate=4000000 ! video/x-h264 !  rtph264pay config-interval=1 ! udpsink host=192.168.1.13 port=1234 auto-multicast=true
# [video]  created gstEncoder from rtp://192.168.1.13:1234
# ------------------------------------------------
# gstEncoder video options:
# ------------------------------------------------
#   -- URI: rtp://192.168.1.13:1234
#      - protocol:  rtp
#      - location:  192.168.1.13
#      - port:      1234
#   -- deviceType: ip
#   -- ioType:     output
#   -- codec:      h264
#   -- width:      0
#   -- height:     0
#   -- frameRate:  30.000000
#   -- bitRate:    4000000
#   -- numBuffers: 4
#   -- zeroCopy:   true
#   -- flipMethod: none
#   -- loop:       0
#   -- rtspLatency 2000
# ------------------------------------------------
# [OpenGL] failed to open X11 server connection.
# [OpenGL] failed to create X11 Window.
# [gstreamer] opening gstCamera for streaming, transitioning pipeline to GST_STATE_PLAYING
# [gstreamer] gstreamer changed state from NULL to READY ==> mysink
# [gstreamer] gstreamer changed state from NULL to READY ==> capsfilter1
# [gstreamer] gstreamer changed state from NULL to READY ==> jpegdec0
# [gstreamer] gstreamer changed state from NULL to READY ==> capsfilter0
# [gstreamer] gstreamer changed state from NULL to READY ==> v4l2src0
# [gstreamer] gstreamer changed state from NULL to READY ==> pipeline0
# [gstreamer] gstreamer changed state from READY to PAUSED ==> capsfilter1
# [gstreamer] gstreamer changed state from READY to PAUSED ==> jpegdec0
# [gstreamer] gstreamer changed state from READY to PAUSED ==> capsfilter0
# [gstreamer] gstreamer stream status CREATE ==> src
# [gstreamer] gstreamer changed state from READY to PAUSED ==> v4l2src0
# [gstreamer] gstreamer changed state from READY to PAUSED ==> pipeline0
# [gstreamer] gstreamer message new-clock ==> pipeline0
# [gstreamer] gstreamer stream status ENTER ==> src
# [gstreamer] gstreamer changed state from PAUSED to PLAYING ==> capsfilter1
# [gstreamer] gstreamer changed state from PAUSED to PLAYING ==> jpegdec0
# [gstreamer] gstreamer changed state from PAUSED to PLAYING ==> capsfilter0
# [gstreamer] gstreamer changed state from PAUSED to PLAYING ==> v4l2src0
# [gstreamer] gstreamer message stream-start ==> pipeline0
# [gstreamer] gstCamera -- onPreroll
# [gstreamer] gstCamera -- map buffer size was less than max size (1382400 vs 1382407)
# [gstreamer] gstCamera recieve caps:  video/x-raw, format=(string)I420, width=(int)1280, height=(int)720, interlace-mode=(string)progressive, multiview-mode=(string)mono, multiview-flags=(GstVideoMultiviewFlagsSet)0:ffffffff:/right-view-first/left-flipped/left-flopped/right-flipped/right-flopped/half-aspect/mixed-mono, pixel-aspect-ratio=(fraction)1/1, chroma-site=(string)mpeg2, colorimetry=(string)1:4:0:0, framerate=(fraction)30/1
# [gstreamer] gstCamera -- recieved first frame, codec=mjpeg format=i420 width=1280 height=720 size=1382407
# RingBuffer -- allocated 4 buffers (1382407 bytes each, 5529628 bytes total)
# [gstreamer] gstreamer changed state from READY to PAUSED ==> mysink
# [gstreamer] gstreamer message async-done ==> pipeline0
# [gstreamer] gstreamer changed state from PAUSED to PLAYING ==> mysink
# [gstreamer] gstreamer changed state from PAUSED to PLAYING ==> pipeline0
# RingBuffer -- allocated 4 buffers (2764800 bytes each, 11059200 bytes total)
# video-viewer:  captured 1 frames (1280 x 720)
# RingBuffer -- allocated 2 buffers (1382400 bytes each, 2764800 bytes total)
# [gstreamer] gstEncoder-- starting pipeline, transitioning to GST_STATE_PLAYING
# [gstreamer] gstreamer changed state from NULL to READY ==> udpsink0
# [gstreamer] gstreamer changed state from NULL to READY ==> rtph264pay0
# [gstreamer] gstreamer changed state from NULL to READY ==> capsfilter2
# [gstreamer] gstreamer changed state from NULL to READY ==> omxh264enc-omxh264enc0
# [gstreamer] gstreamer changed state from NULL to READY ==> mysource
# [gstreamer] gstreamer changed state from NULL to READY ==> pipeline1
# [gstreamer] gstreamer changed state from READY to PAUSED ==> rtph264pay0
# [gstreamer] gstreamer changed state from READY to PAUSED ==> capsfilter2
# [gstreamer] gstreamer changed state from READY to PAUSED ==> omxh264enc-omxh264enc0
# [gstreamer] gstreamer stream status CREATE ==> src
# [gstreamer] gstreamer changed state from READY to PAUSED ==> mysource
# [gstreamer] gstreamer changed state from READY to PAUSED ==> pipeline1
# [gstreamer] gstreamer message new-clock ==> pipeline1
# [gstreamer] gstreamer changed state from PAUSED to PLAYING ==> rtph264pay0
# [gstreamer] gstreamer changed state from PAUSED to PLAYING ==> capsfilter2
# [gstreamer] gstreamer changed state from PAUSED to PLAYING ==> omxh264enc-omxh264enc0
# [gstreamer] gstreamer changed state from PAUSED to PLAYING ==> mysource
# [gstreamer] gstreamer message qos ==> v4l2src0
# [gstreamer] gstreamer stream status ENTER ==> src
# [gstreamer] gstEncoder -- new caps: video/x-raw, width=1280, height=720, format=(string)I420, framerate=30/1
# video-viewer:  captured 2 frames (1280 x 720)
# Framerate set to : 30 at NvxVideoEncoderSetParameterNvMMLiteOpen : Block : BlockType = 4
# ===== NVMEDIA: NVENC =====
# NvMMLiteBlockCreate : Block : BlockType = 4
# H264: Profile = 66, Level = 40
# NVMEDIA_ENC: bBlitMode is set to TRUE
# [gstreamer] gstreamer stream status CREATE ==> src
# [gstreamer] gstreamer stream status ENTER ==> src
# [gstreamer] gstreamer message stream-start ==> pipeline1
# [gstreamer] gstreamer changed state from READY to PAUSED ==> udpsink0
# [gstreamer] gstreamer message async-done ==> pipeline1
# [gstreamer] gstreamer changed state from PAUSED to PLAYING ==> udpsink0
# [gstreamer] gstreamer changed state from PAUSED to PLAYING ==> pipeline1
# video-viewer:  captured 3 frames (1280 x 720)
# video-viewer:  captured 4 frames (1280 x 720)
# video-viewer:  captured 5 frames (1280 x 720)
# video-viewer:  captured 6 frames (1280 x 720)
# video-viewer:  captured 7 frames (1280 x 720)
# video-viewer:  captured 8 frames (1280 x 720)
# video-viewer:  captured 9 frames (1280 x 720)
# video-viewer:  captured 10 frames (1280 x 720)
# video-viewer:  captured 11 frames (1280 x 720)
# video-viewer:  captured 12 frames (1280 x 720)
# video-viewer:  captured 13 frames (1280 x 720)
# video-viewer:  captured 14 frames (1280 x 720)
# video-viewer:  captured 15 frames (1280 x 720)
# video-viewer:  captured 16 frames (1280 x 720)
# video-viewer:  captured 17 frames (1280 x 720)
# video-viewer:  captured 18 frames (1280 x 720)
# video-viewer:  captured 19 frames (1280 x 720)
# video-viewer:  captured 20 frames (1280 x 720)
# video-viewer:  captured 21 frames (1280 x 720)
# video-viewer:  captured 22 frames (1280 x 720)
# video-viewer:  captured 23 frames (1280 x 720)
# video-viewer:  captured 24 frames (1280 x 720)
# video-viewer:  captured 25 frames (1280 x 720)
# video-viewer:  captured 26 frames (1280 x 720)
# video-viewer:  captured 27 frames (1280 x 720)
# video-viewer:  captured 28 frames (1280 x 720)
# video-viewer:  captured 29 frames (1280 x 720)
# video-viewer:  captured 30 frames (1280 x 720)
# video-viewer:  captured 31 frames (1280 x 720)
# video-viewer:  captured 32 frames (1280 x 720)
# video-viewer:  captured 33 frames (1280 x 720)
# video-viewer:  captured 34 frames (1280 x 720)
# video-viewer:  captured 35 frames (1280 x 720)
# video-viewer:  captured 36 frames (1280 x 720)
# video-viewer:  captured 37 frames (1280 x 720)
# video-viewer:  captured 38 frames (1280 x 720)
# video-viewer:  captured 39 frames (1280 x 720)
# video-viewer:  captured 40 frames (1280 x 720)
# video-viewer:  captured 41 frames (1280 x 720)
# video-viewer:  captured 42 frames (1280 x 720)
# video-viewer:  captured 43 frames (1280 x 720)
# video-viewer:  captured 44 frames (1280 x 720)
# video-viewer:  captured 45 frames (1280 x 720)
# video-viewer:  captured 46 frames (1280 x 720)
# video-viewer:  captured 47 frames (1280 x 720)
# video-viewer:  captured 48 frames (1280 x 720)
# video-viewer:  captured 49 frames (1280 x 720)
# video-viewer:  captured 50 frames (1280 x 720)
# video-viewer:  captured 51 frames (1280 x 720)
# video-viewer:  captured 52 frames (1280 x 720)
# video-viewer:  captured 53 frames (1280 x 720)
# video-viewer:  captured 54 frames (1280 x 720)
# video-viewer:  captured 55 frames (1280 x 720)
# video-viewer:  captured 56 frames (1280 x 720)
# video-viewer:  captured 57 frames (1280 x 720)
# video-viewer:  captured 58 frames (1280 x 720)
# video-viewer:  captured 59 frames (1280 x 720)
# video-viewer:  captured 60 frames (1280 x 720)
# video-viewer:  captured 61 frames (1280 x 720)
# video-viewer:  captured 62 frames (1280 x 720)
# video-viewer:  captured 63 frames (1280 x 720)
# video-viewer:  captured 64 frames (1280 x 720)
# video-viewer:  captured 65 frames (1280 x 720)
# video-viewer:  captured 66 frames (1280 x 720)
# video-viewer:  captured 67 frames (1280 x 720)
# video-viewer:  captured 68 frames (1280 x 720)
# video-viewer:  captured 69 frames (1280 x 720)
# video-viewer:  captured 70 frames (1280 x 720)
# video-viewer:  captured 71 frames (1280 x 720)
# video-viewer:  captured 72 frames (1280 x 720)
# video-viewer:  captured 73 frames (1280 x 720)
# video-viewer:  captured 74 frames (1280 x 720)
# video-viewer:  captured 75 frames (1280 x 720)
# video-viewer:  captured 76 frames (1280 x 720)
# video-viewer:  captured 77 frames (1280 x 720)
# video-viewer:  captured 78 frames (1280 x 720)
# video-viewer:  captured 79 frames (1280 x 720)
# video-viewer:  captured 80 frames (1280 x 720)
# video-viewer:  captured 81 frames (1280 x 720)
# video-viewer:  captured 82 frames (1280 x 720)
# video-viewer:  captured 83 frames (1280 x 720)
# video-viewer:  captured 84 frames (1280 x 720)
# video-viewer:  captured 85 frames (1280 x 720)
# video-viewer:  captured 86 frames (1280 x 720)
# video-viewer:  captured 87 frames (1280 x 720)
# video-viewer:  captured 88 frames (1280 x 720)
# video-viewer:  captured 89 frames (1280 x 720)
# video-viewer:  captured 90 frames (1280 x 720)
# video-viewer:  captured 91 frames (1280 x 720)
# video-viewer:  captured 92 frames (1280 x 720)
# video-viewer:  captured 93 frames (1280 x 720)
# video-viewer:  captured 94 frames (1280 x 720)
# video-viewer:  captured 95 frames (1280 x 720)
# video-viewer:  captured 96 frames (1280 x 720)
# video-viewer:  captured 97 frames (1280 x 720)
# video-viewer:  captured 98 frames (1280 x 720)
# video-viewer:  captured 99 frames (1280 x 720)
# video-viewer:  captured 100 frames (1280 x 720)
# video-viewer:  captured 101 frames (1280 x 720)
# video-viewer:  captured 102 frames (1280 x 720)
# video-viewer:  captured 103 frames (1280 x 720)
# video-viewer:  captured 104 frames (1280 x 720)
# video-viewer:  captured 105 frames (1280 x 720)
# video-viewer:  captured 106 frames (1280 x 720)
# video-viewer:  captured 107 frames (1280 x 720)
# video-viewer:  captured 108 frames (1280 x 720)
# video-viewer:  captured 109 frames (1280 x 720)
# video-viewer:  captured 110 frames (1280 x 720)
# video-viewer:  captured 111 frames (1280 x 720)
# video-viewer:  captured 112 frames (1280 x 720)
# video-viewer:  captured 113 frames (1280 x 720)
# video-viewer:  captured 114 frames (1280 x 720)
# video-viewer:  captured 115 frames (1280 x 720)
# video-viewer:  captured 116 frames (1280 x 720)
# video-viewer:  captured 117 frames (1280 x 720)
# video-viewer:  captured 118 frames (1280 x 720)
# video-viewer:  captured 119 frames (1280 x 720)
# video-viewer:  captured 120 frames (1280 x 720)
# video-viewer:  captured 121 frames (1280 x 720)
# video-viewer:  captured 122 frames (1280 x 720)
# video-viewer:  captured 123 frames (1280 x 720)
# video-viewer:  captured 124 frames (1280 x 720)
# video-viewer:  captured 125 frames (1280 x 720)
# video-viewer:  captured 126 frames (1280 x 720)
# video-viewer:  captured 127 frames (1280 x 720)
# video-viewer:  captured 128 frames (1280 x 720)
# video-viewer:  captured 129 frames (1280 x 720)
# video-viewer:  captured 130 frames (1280 x 720)
# video-viewer:  captured 131 frames (1280 x 720)
# video-viewer:  captured 132 frames (1280 x 720)
# video-viewer:  captured 133 frames (1280 x 720)
# video-viewer:  captured 134 frames (1280 x 720)
# video-viewer:  captured 135 frames (1280 x 720)
# video-viewer:  captured 136 frames (1280 x 720)
# video-viewer:  captured 137 frames (1280 x 720)
# video-viewer:  captured 138 frames (1280 x 720)
# video-viewer:  captured 139 frames (1280 x 720)
# video-viewer:  captured 140 frames (1280 x 720)
# video-viewer:  captured 141 frames (1280 x 720)
# video-viewer:  captured 142 frames (1280 x 720)
# video-viewer:  captured 143 frames (1280 x 720)
# video-viewer:  captured 144 frames (1280 x 720)
# video-viewer:  captured 145 frames (1280 x 720)
# video-viewer:  captured 146 frames (1280 x 720)
# video-viewer:  captured 147 frames (1280 x 720)
# video-viewer:  captured 148 frames (1280 x 720)
# video-viewer:  captured 149 frames (1280 x 720)
# video-viewer:  captured 150 frames (1280 x 720)
# video-viewer:  captured 151 frames (1280 x 720)
# video-viewer:  captured 152 frames (1280 x 720)
# video-viewer:  captured 153 frames (1280 x 720)
# video-viewer:  captured 154 frames (1280 x 720)
# video-viewer:  captured 155 frames (1280 x 720)
# video-viewer:  captured 156 frames (1280 x 720)
# video-viewer:  captured 157 frames (1280 x 720)
# video-viewer:  captured 158 frames (1280 x 720)
# video-viewer:  captured 159 frames (1280 x 720)
# video-viewer:  captured 160 frames (1280 x 720)
# video-viewer:  captured 161 frames (1280 x 720)
# video-viewer:  captured 162 frames (1280 x 720)
# video-viewer:  captured 163 frames (1280 x 720)
# video-viewer:  captured 164 frames (1280 x 720)
# video-viewer:  captured 165 frames (1280 x 720)
# video-viewer:  captured 166 frames (1280 x 720)
# video-viewer:  captured 167 frames (1280 x 720)
# video-viewer:  captured 168 frames (1280 x 720)
# video-viewer:  captured 169 frames (1280 x 720)
# video-viewer:  captured 170 frames (1280 x 720)
# video-viewer:  captured 171 frames (1280 x 720)
# video-viewer:  captured 172 frames (1280 x 720)
# video-viewer:  captured 173 frames (1280 x 720)
# video-viewer:  captured 174 frames (1280 x 720)
# video-viewer:  captured 175 frames (1280 x 720)
# video-viewer:  captured 176 frames (1280 x 720)
# video-viewer:  captured 177 frames (1280 x 720)
# video-viewer:  captured 178 frames (1280 x 720)
# video-viewer:  captured 179 frames (1280 x 720)
# video-viewer:  captured 180 frames (1280 x 720)
# video-viewer:  captured 181 frames (1280 x 720)
# video-viewer:  captured 182 frames (1280 x 720)
# video-viewer:  captured 183 frames (1280 x 720)
# video-viewer:  captured 184 frames (1280 x 720)
# video-viewer:  captured 185 frames (1280 x 720)
# video-viewer:  captured 186 frames (1280 x 720)
# video-viewer:  captured 187 frames (1280 x 720)
# video-viewer:  captured 188 frames (1280 x 720)
# video-viewer:  captured 189 frames (1280 x 720)
# video-viewer:  captured 190 frames (1280 x 720)
# video-viewer:  captured 191 frames (1280 x 720)
# video-viewer:  captured 192 frames (1280 x 720)
# video-viewer:  captured 193 frames (1280 x 720)
# video-viewer:  captured 194 frames (1280 x 720)
# video-viewer:  captured 195 frames (1280 x 720)
# video-viewer:  captured 196 frames (1280 x 720)
# video-viewer:  captured 197 frames (1280 x 720)
# video-viewer:  captured 198 frames (1280 x 720)
# video-viewer:  captured 199 frames (1280 x 720)
# video-viewer:  captured 200 frames (1280 x 720)
# video-viewer:  captured 201 frames (1280 x 720)
# video-viewer:  captured 202 frames (1280 x 720)
# video-viewer:  captured 203 frames (1280 x 720)
# video-viewer:  captured 204 frames (1280 x 720)
# video-viewer:  captured 205 frames (1280 x 720)
# video-viewer:  captured 206 frames (1280 x 720)
# video-viewer:  captured 207 frames (1280 x 720)
# video-viewer:  captured 208 frames (1280 x 720)
# video-viewer:  captured 209 frames (1280 x 720)
# video-viewer:  captured 210 frames (1280 x 720)
# video-viewer:  captured 211 frames (1280 x 720)
# video-viewer:  captured 212 frames (1280 x 720)
# video-viewer:  captured 213 frames (1280 x 720)
# video-viewer:  captured 214 frames (1280 x 720)
# video-viewer:  captured 215 frames (1280 x 720)
# video-viewer:  captured 216 frames (1280 x 720)
# video-viewer:  captured 217 frames (1280 x 720)
# video-viewer:  captured 218 frames (1280 x 720)
# video-viewer:  captured 219 frames (1280 x 720)
# video-viewer:  captured 220 frames (1280 x 720)
# video-viewer:  captured 221 frames (1280 x 720)
# video-viewer:  captured 222 frames (1280 x 720)
# video-viewer:  captured 223 frames (1280 x 720)
# video-viewer:  captured 224 frames (1280 x 720)
# video-viewer:  captured 225 frames (1280 x 720)
# video-viewer:  captured 226 frames (1280 x 720)
# video-viewer:  captured 227 frames (1280 x 720)
# video-viewer:  captured 228 frames (1280 x 720)
# video-viewer:  captured 229 frames (1280 x 720)
# video-viewer:  captured 230 frames (1280 x 720)
# video-viewer:  captured 231 frames (1280 x 720)
# video-viewer:  captured 232 frames (1280 x 720)
# video-viewer:  captured 233 frames (1280 x 720)
# video-viewer:  captured 234 frames (1280 x 720)
# video-viewer:  captured 235 frames (1280 x 720)
# video-viewer:  captured 236 frames (1280 x 720)
# video-viewer:  captured 237 frames (1280 x 720)
# video-viewer:  captured 238 frames (1280 x 720)
# video-viewer:  captured 239 frames (1280 x 720)
# video-viewer:  captured 240 frames (1280 x 720)
# video-viewer:  captured 241 frames (1280 x 720)
# video-viewer:  captured 242 frames (1280 x 720)
# video-viewer:  captured 243 frames (1280 x 720)
# video-viewer:  captured 244 frames (1280 x 720)
# video-viewer:  captured 245 frames (1280 x 720)
# video-viewer:  captured 246 frames (1280 x 720)
# video-viewer:  captured 247 frames (1280 x 720)
# video-viewer:  captured 248 frames (1280 x 720)
# video-viewer:  captured 249 frames (1280 x 720)
# video-viewer:  captured 250 frames (1280 x 720)
# video-viewer:  captured 251 frames (1280 x 720)
# video-viewer:  captured 252 frames (1280 x 720)
# video-viewer:  captured 253 frames (1280 x 720)
# video-viewer:  captured 254 frames (1280 x 720)
# video-viewer:  captured 255 frames (1280 x 720)
# video-viewer:  captured 256 frames (1280 x 720)
# video-viewer:  captured 257 frames (1280 x 720)
# video-viewer:  captured 258 frames (1280 x 720)
# video-viewer:  captured 259 frames (1280 x 720)
# video-viewer:  captured 260 frames (1280 x 720)
# video-viewer:  captured 261 frames (1280 x 720)
# video-viewer:  captured 262 frames (1280 x 720)
# video-viewer:  captured 263 frames (1280 x 720)
# video-viewer:  captured 264 frames (1280 x 720)
# video-viewer:  captured 265 frames (1280 x 720)
# video-viewer:  captured 266 frames (1280 x 720)
# video-viewer:  captured 267 frames (1280 x 720)
# video-viewer:  captured 268 frames (1280 x 720)
# video-viewer:  captured 269 frames (1280 x 720)
# video-viewer:  captured 270 frames (1280 x 720)
# video-viewer:  captured 271 frames (1280 x 720)
# video-viewer:  captured 272 frames (1280 x 720)
# video-viewer:  captured 273 frames (1280 x 720)
# video-viewer:  captured 274 frames (1280 x 720)
# video-viewer:  captured 275 frames (1280 x 720)
# video-viewer:  captured 276 frames (1280 x 720)
# video-viewer:  captured 277 frames (1280 x 720)
# video-viewer:  captured 278 frames (1280 x 720)
# video-viewer:  captured 279 frames (1280 x 720)
# video-viewer:  captured 280 frames (1280 x 720)
# video-viewer:  captured 281 frames (1280 x 720)
# video-viewer:  captured 282 frames (1280 x 720)
# video-viewer:  captured 283 frames (1280 x 720)
# video-viewer:  captured 284 frames (1280 x 720)
# video-viewer:  captured 285 frames (1280 x 720)
# video-viewer:  captured 286 frames (1280 x 720)
# video-viewer:  captured 287 frames (1280 x 720)
# video-viewer:  captured 288 frames (1280 x 720)
# video-viewer:  captured 289 frames (1280 x 720)
# video-viewer:  captured 290 frames (1280 x 720)
# video-viewer:  captured 291 frames (1280 x 720)
# video-viewer:  captured 292 frames (1280 x 720)
# video-viewer:  captured 293 frames (1280 x 720)
# video-viewer:  captured 294 frames (1280 x 720)
# video-viewer:  captured 295 frames (1280 x 720)
# video-viewer:  captured 296 frames (1280 x 720)
# video-viewer:  captured 297 frames (1280 x 720)
# video-viewer:  captured 298 frames (1280 x 720)
# video-viewer:  captured 299 frames (1280 x 720)
# video-viewer:  captured 300 frames (1280 x 720)
# video-viewer:  captured 301 frames (1280 x 720)
# video-viewer:  captured 302 frames (1280 x 720)
# video-viewer:  captured 303 frames (1280 x 720)
# video-viewer:  captured 304 frames (1280 x 720)
# video-viewer:  captured 305 frames (1280 x 720)
# video-viewer:  captured 306 frames (1280 x 720)
# video-viewer:  captured 307 frames (1280 x 720)
# video-viewer:  captured 308 frames (1280 x 720)
# video-viewer:  captured 309 frames (1280 x 720)
# video-viewer:  captured 310 frames (1280 x 720)
# video-viewer:  captured 311 frames (1280 x 720)
# video-viewer:  captured 312 frames (1280 x 720)
# video-viewer:  captured 313 frames (1280 x 720)
# video-viewer:  captured 314 frames (1280 x 720)
# video-viewer:  captured 315 frames (1280 x 720)
# video-viewer:  captured 316 frames (1280 x 720)
# video-viewer:  captured 317 frames (1280 x 720)
# video-viewer:  captured 318 frames (1280 x 720)
# video-viewer:  captured 319 frames (1280 x 720)
# video-viewer:  captured 320 frames (1280 x 720)
# video-viewer:  captured 321 frames (1280 x 720)
# video-viewer:  captured 322 frames (1280 x 720)
# video-viewer:  captured 323 frames (1280 x 720)
# video-viewer:  captured 324 frames (1280 x 720)
# video-viewer:  captured 325 frames (1280 x 720)
# video-viewer:  captured 326 frames (1280 x 720)
# video-viewer:  captured 327 frames (1280 x 720)
# video-viewer:  captured 328 frames (1280 x 720)
# video-viewer:  captured 329 frames (1280 x 720)
# video-viewer:  captured 330 frames (1280 x 720)
# video-viewer:  captured 331 frames (1280 x 720)
# video-viewer:  captured 332 frames (1280 x 720)
# video-viewer:  captured 333 frames (1280 x 720)
# video-viewer:  captured 334 frames (1280 x 720)
# video-viewer:  captured 335 frames (1280 x 720)
# video-viewer:  captured 336 frames (1280 x 720)
# video-viewer:  captured 337 frames (1280 x 720)
# video-viewer:  captured 338 frames (1280 x 720)
# video-viewer:  captured 339 frames (1280 x 720)
# video-viewer:  captured 340 frames (1280 x 720)
# video-viewer:  captured 341 frames (1280 x 720)
# video-viewer:  captured 342 frames (1280 x 720)
# video-viewer:  captured 343 frames (1280 x 720)
# video-viewer:  captured 344 frames (1280 x 720)
# video-viewer:  captured 345 frames (1280 x 720)
# video-viewer:  captured 346 frames (1280 x 720)
# video-viewer:  captured 347 frames (1280 x 720)
# video-viewer:  captured 348 frames (1280 x 720)
# video-viewer:  captured 349 frames (1280 x 720)
# video-viewer:  captured 350 frames (1280 x 720)
# video-viewer:  captured 351 frames (1280 x 720)
# video-viewer:  captured 352 frames (1280 x 720)
# video-viewer:  captured 353 frames (1280 x 720)
# video-viewer:  captured 354 frames (1280 x 720)
# video-viewer:  captured 355 frames (1280 x 720)
# video-viewer:  captured 356 frames (1280 x 720)
# video-viewer:  captured 357 frames (1280 x 720)
# video-viewer:  captured 358 frames (1280 x 720)
# video-viewer:  captured 359 frames (1280 x 720)
# video-viewer:  captured 360 frames (1280 x 720)
# video-viewer:  captured 361 frames (1280 x 720)
# video-viewer:  captured 362 frames (1280 x 720)
# video-viewer:  captured 363 frames (1280 x 720)
# video-viewer:  captured 364 frames (1280 x 720)
# video-viewer:  captured 365 frames (1280 x 720)
# video-viewer:  captured 366 frames (1280 x 720)
# video-viewer:  captured 367 frames (1280 x 720)
# video-viewer:  captured 368 frames (1280 x 720)
# video-viewer:  captured 369 frames (1280 x 720)
# video-viewer:  captured 370 frames (1280 x 720)
# video-viewer:  captured 371 frames (1280 x 720)
# video-viewer:  captured 372 frames (1280 x 720)
# video-viewer:  captured 373 frames (1280 x 720)
# video-viewer:  captured 374 frames (1280 x 720)
# video-viewer:  captured 375 frames (1280 x 720)
# video-viewer:  captured 376 frames (1280 x 720)
# video-viewer:  captured 377 frames (1280 x 720)
# video-viewer:  captured 378 frames (1280 x 720)
# video-viewer:  captured 379 frames (1280 x 720)
# video-viewer:  captured 380 frames (1280 x 720)
# video-viewer:  captured 381 frames (1280 x 720)
# video-viewer:  captured 382 frames (1280 x 720)
# video-viewer:  captured 383 frames (1280 x 720)
# video-viewer:  captured 384 frames (1280 x 720)
# video-viewer:  captured 385 frames (1280 x 720)
# video-viewer:  captured 386 frames (1280 x 720)
# video-viewer:  captured 387 frames (1280 x 720)
# video-viewer:  captured 388 frames (1280 x 720)
# video-viewer:  captured 389 frames (1280 x 720)
# video-viewer:  captured 390 frames (1280 x 720)
# video-viewer:  captured 391 frames (1280 x 720)
# video-viewer:  captured 392 frames (1280 x 720)
# video-viewer:  captured 393 frames (1280 x 720)
# video-viewer:  captured 394 frames (1280 x 720)
# video-viewer:  captured 395 frames (1280 x 720)
# video-viewer:  captured 396 frames (1280 x 720)
# video-viewer:  captured 397 frames (1280 x 720)
# video-viewer:  captured 398 frames (1280 x 720)
# video-viewer:  captured 399 frames (1280 x 720)
# video-viewer:  captured 400 frames (1280 x 720)
# video-viewer:  captured 401 frames (1280 x 720)
# video-viewer:  captured 402 frames (1280 x 720)
# video-viewer:  captured 403 frames (1280 x 720)
# video-viewer:  captured 404 frames (1280 x 720)
# video-viewer:  captured 405 frames (1280 x 720)
# video-viewer:  captured 406 frames (1280 x 720)
# video-viewer:  captured 407 frames (1280 x 720)
# video-viewer:  captured 408 frames (1280 x 720)
# video-viewer:  captured 409 frames (1280 x 720)
# video-viewer:  captured 410 frames (1280 x 720)
# video-viewer:  captured 411 frames (1280 x 720)
# video-viewer:  captured 412 frames (1280 x 720)
# video-viewer:  captured 413 frames (1280 x 720)
# video-viewer:  captured 414 frames (1280 x 720)
# video-viewer:  captured 415 frames (1280 x 720)
# video-viewer:  captured 416 frames (1280 x 720)
# video-viewer:  captured 417 frames (1280 x 720)
# video-viewer:  captured 418 frames (1280 x 720)
# video-viewer:  captured 419 frames (1280 x 720)
# video-viewer:  captured 420 frames (1280 x 720)
# video-viewer:  captured 421 frames (1280 x 720)
# video-viewer:  captured 422 frames (1280 x 720)
# video-viewer:  captured 423 frames (1280 x 720)
# video-viewer:  captured 424 frames (1280 x 720)
# video-viewer:  captured 425 frames (1280 x 720)
# video-viewer:  captured 426 frames (1280 x 720)
# video-viewer:  captured 427 frames (1280 x 720)
# video-viewer:  captured 428 frames (1280 x 720)
# video-viewer:  captured 429 frames (1280 x 720)
# video-viewer:  captured 430 frames (1280 x 720)
# video-viewer:  captured 431 frames (1280 x 720)
# video-viewer:  captured 432 frames (1280 x 720)
# video-viewer:  captured 433 frames (1280 x 720)
# video-viewer:  captured 434 frames (1280 x 720)
# video-viewer:  captured 435 frames (1280 x 720)
# video-viewer:  captured 436 frames (1280 x 720)
# video-viewer:  captured 437 frames (1280 x 720)
# video-viewer:  captured 438 frames (1280 x 720)
# video-viewer:  captured 439 frames (1280 x 720)
# video-viewer:  captured 440 frames (1280 x 720)
# video-viewer:  captured 441 frames (1280 x 720)
# video-viewer:  captured 442 frames (1280 x 720)
# video-viewer:  captured 443 frames (1280 x 720)
# video-viewer:  captured 444 frames (1280 x 720)
# video-viewer:  captured 445 frames (1280 x 720)
# video-viewer:  captured 446 frames (1280 x 720)
# video-viewer:  captured 447 frames (1280 x 720)
# video-viewer:  captured 448 frames (1280 x 720)
# video-viewer:  captured 449 frames (1280 x 720)
# video-viewer:  captured 450 frames (1280 x 720)
# video-viewer:  captured 451 frames (1280 x 720)
# video-viewer:  captured 452 frames (1280 x 720)
# video-viewer:  captured 453 frames (1280 x 720)
# video-viewer:  captured 454 frames (1280 x 720)
# video-viewer:  captured 455 frames (1280 x 720)
# video-viewer:  captured 456 frames (1280 x 720)
# video-viewer:  captured 457 frames (1280 x 720)
# video-viewer:  captured 458 frames (1280 x 720)
# video-viewer:  captured 459 frames (1280 x 720)
# video-viewer:  captured 460 frames (1280 x 720)
# video-viewer:  captured 461 frames (1280 x 720)
# video-viewer:  captured 462 frames (1280 x 720)
# video-viewer:  captured 463 frames (1280 x 720)
# video-viewer:  captured 464 frames (1280 x 720)
# video-viewer:  captured 465 frames (1280 x 720)
# video-viewer:  captured 466 frames (1280 x 720)
# video-viewer:  captured 467 frames (1280 x 720)
# video-viewer:  captured 468 frames (1280 x 720)
# video-viewer:  captured 469 frames (1280 x 720)
# video-viewer:  captured 470 frames (1280 x 720)
# video-viewer:  captured 471 frames (1280 x 720)
# video-viewer:  captured 472 frames (1280 x 720)
# video-viewer:  captured 473 frames (1280 x 720)
# video-viewer:  captured 474 frames (1280 x 720)
# video-viewer:  captured 475 frames (1280 x 720)
# video-viewer:  captured 476 frames (1280 x 720)
# video-viewer:  captured 477 frames (1280 x 720)
# video-viewer:  captured 478 frames (1280 x 720)
# video-viewer:  captured 479 frames (1280 x 720)
# video-viewer:  captured 480 frames (1280 x 720)
# video-viewer:  captured 481 frames (1280 x 720)
# video-viewer:  captured 482 frames (1280 x 720)
# video-viewer:  captured 483 frames (1280 x 720)
# video-viewer:  captured 484 frames (1280 x 720)
# video-viewer:  captured 485 frames (1280 x 720)
# video-viewer:  captured 486 frames (1280 x 720)
# video-viewer:  captured 487 frames (1280 x 720)
# video-viewer:  captured 488 frames (1280 x 720)
# video-viewer:  captured 489 frames (1280 x 720)
# video-viewer:  captured 490 frames (1280 x 720)
# video-viewer:  captured 491 frames (1280 x 720)
# video-viewer:  captured 492 frames (1280 x 720)
# video-viewer:  captured 493 frames (1280 x 720)
# video-viewer:  captured 494 frames (1280 x 720)
# video-viewer:  captured 495 frames (1280 x 720)
# video-viewer:  captured 496 frames (1280 x 720)
# video-viewer:  captured 497 frames (1280 x 720)
# video-viewer:  captured 498 frames (1280 x 720)
# video-viewer:  captured 499 frames (1280 x 720)
# video-viewer:  captured 500 frames (1280 x 720)
# video-viewer:  captured 501 frames (1280 x 720)
# video-viewer:  captured 502 frames (1280 x 720)
# video-viewer:  captured 503 frames (1280 x 720)
# video-viewer:  captured 504 frames (1280 x 720)
# video-viewer:  captured 505 frames (1280 x 720)
# video-viewer:  captured 506 frames (1280 x 720)
# video-viewer:  captured 507 frames (1280 x 720)
# video-viewer:  captured 508 frames (1280 x 720)
# video-viewer:  captured 509 frames (1280 x 720)
# video-viewer:  captured 510 frames (1280 x 720)
# video-viewer:  captured 511 frames (1280 x 720)
# video-viewer:  captured 512 frames (1280 x 720)
# video-viewer:  captured 513 frames (1280 x 720)
# video-viewer:  captured 514 frames (1280 x 720)
# video-viewer:  captured 515 frames (1280 x 720)
# video-viewer:  captured 516 frames (1280 x 720)
# video-viewer:  captured 517 frames (1280 x 720)
# video-viewer:  captured 518 frames (1280 x 720)
# video-viewer:  captured 519 frames (1280 x 720)
# video-viewer:  captured 520 frames (1280 x 720)
# video-viewer:  captured 521 frames (1280 x 720)
# video-viewer:  captured 522 frames (1280 x 720)
# video-viewer:  captured 523 frames (1280 x 720)
# video-viewer:  captured 524 frames (1280 x 720)
# video-viewer:  captured 525 frames (1280 x 720)
# video-viewer:  captured 526 frames (1280 x 720)
# video-viewer:  captured 527 frames (1280 x 720)
# video-viewer:  captured 528 frames (1280 x 720)
# video-viewer:  captured 529 frames (1280 x 720)
# video-viewer:  captured 530 frames (1280 x 720)
# video-viewer:  captured 531 frames (1280 x 720)
# video-viewer:  captured 532 frames (1280 x 720)
# video-viewer:  captured 533 frames (1280 x 720)
# video-viewer:  captured 534 frames (1280 x 720)
# video-viewer:  captured 535 frames (1280 x 720)
# video-viewer:  captured 536 frames (1280 x 720)
# video-viewer:  captured 537 frames (1280 x 720)
# video-viewer:  captured 538 frames (1280 x 720)
# video-viewer:  captured 539 frames (1280 x 720)
# video-viewer:  captured 540 frames (1280 x 720)
# video-viewer:  captured 541 frames (1280 x 720)
# video-viewer:  captured 542 frames (1280 x 720)
# video-viewer:  captured 543 frames (1280 x 720)
# video-viewer:  captured 544 frames (1280 x 720)
# video-viewer:  captured 545 frames (1280 x 720)
# video-viewer:  captured 546 frames (1280 x 720)
# video-viewer:  captured 547 frames (1280 x 720)
# video-viewer:  captured 548 frames (1280 x 720)
# video-viewer:  captured 549 frames (1280 x 720)
# video-viewer:  captured 550 frames (1280 x 720)
# video-viewer:  captured 551 frames (1280 x 720)
# video-viewer:  captured 552 frames (1280 x 720)
# video-viewer:  captured 553 frames (1280 x 720)
# video-viewer:  captured 554 frames (1280 x 720)
# video-viewer:  captured 555 frames (1280 x 720)
# video-viewer:  captured 556 frames (1280 x 720)
# video-viewer:  captured 557 frames (1280 x 720)
# video-viewer:  captured 558 frames (1280 x 720)
# video-viewer:  captured 559 frames (1280 x 720)
# video-viewer:  captured 560 frames (1280 x 720)
# video-viewer:  captured 561 frames (1280 x 720)
# video-viewer:  captured 562 frames (1280 x 720)
# video-viewer:  captured 563 frames (1280 x 720)
# video-viewer:  captured 564 frames (1280 x 720)
# video-viewer:  captured 565 frames (1280 x 720)
# video-viewer:  captured 566 frames (1280 x 720)
# video-viewer:  captured 567 frames (1280 x 720)
# video-viewer:  captured 568 frames (1280 x 720)
# video-viewer:  captured 569 frames (1280 x 720)
# video-viewer:  captured 570 frames (1280 x 720)
# video-viewer:  captured 571 frames (1280 x 720)
# video-viewer:  captured 572 frames (1280 x 720)
# video-viewer:  captured 573 frames (1280 x 720)
# video-viewer:  captured 574 frames (1280 x 720)
# video-viewer:  captured 575 frames (1280 x 720)
# video-viewer:  captured 576 frames (1280 x 720)
# video-viewer:  captured 577 frames (1280 x 720)
# video-viewer:  captured 578 frames (1280 x 720)
# video-viewer:  captured 579 frames (1280 x 720)
# video-viewer:  captured 580 frames (1280 x 720)
# video-viewer:  captured 581 frames (1280 x 720)
# video-viewer:  captured 582 frames (1280 x 720)
# video-viewer:  captured 583 frames (1280 x 720)
# video-viewer:  captured 584 frames (1280 x 720)
# video-viewer:  captured 585 frames (1280 x 720)
# video-viewer:  captured 586 frames (1280 x 720)
# video-viewer:  captured 587 frames (1280 x 720)
# video-viewer:  captured 588 frames (1280 x 720)
# video-viewer:  captured 589 frames (1280 x 720)
# video-viewer:  captured 590 frames (1280 x 720)
# video-viewer:  captured 591 frames (1280 x 720)
# video-viewer:  captured 592 frames (1280 x 720)
# video-viewer:  captured 593 frames (1280 x 720)
# video-viewer:  captured 594 frames (1280 x 720)
# video-viewer:  captured 595 frames (1280 x 720)
# video-viewer:  captured 596 frames (1280 x 720)
# video-viewer:  captured 597 frames (1280 x 720)
# video-viewer:  captured 598 frames (1280 x 720)
# video-viewer:  captured 599 frames (1280 x 720)
# video-viewer:  captured 600 frames (1280 x 720)
# video-viewer:  captured 601 frames (1280 x 720)
# video-viewer:  captured 602 frames (1280 x 720)
# video-viewer:  captured 603 frames (1280 x 720)
# video-viewer:  captured 604 frames (1280 x 720)
# video-viewer:  captured 605 frames (1280 x 720)
# video-viewer:  captured 606 frames (1280 x 720)
# video-viewer:  captured 607 frames (1280 x 720)
# video-viewer:  captured 608 frames (1280 x 720)
# video-viewer:  captured 609 frames (1280 x 720)
# video-viewer:  captured 610 frames (1280 x 720)
# video-viewer:  captured 611 frames (1280 x 720)
# video-viewer:  captured 612 frames (1280 x 720)
# video-viewer:  captured 613 frames (1280 x 720)
# video-viewer:  captured 614 frames (1280 x 720)
# video-viewer:  captured 615 frames (1280 x 720)
# video-viewer:  captured 616 frames (1280 x 720)
# video-viewer:  captured 617 frames (1280 x 720)
# video-viewer:  captured 618 frames (1280 x 720)
# video-viewer:  captured 619 frames (1280 x 720)
# video-viewer:  captured 620 frames (1280 x 720)
# video-viewer:  captured 621 frames (1280 x 720)
# video-viewer:  captured 622 frames (1280 x 720)
# video-viewer:  captured 623 frames (1280 x 720)
# video-viewer:  captured 624 frames (1280 x 720)
# video-viewer:  captured 625 frames (1280 x 720)
# video-viewer:  captured 626 frames (1280 x 720)
# video-viewer:  captured 627 frames (1280 x 720)
# video-viewer:  captured 628 frames (1280 x 720)
# video-viewer:  captured 629 frames (1280 x 720)
# video-viewer:  captured 630 frames (1280 x 720)
# video-viewer:  captured 631 frames (1280 x 720)
# video-viewer:  captured 632 frames (1280 x 720)
# video-viewer:  captured 633 frames (1280 x 720)
# video-viewer:  captured 634 frames (1280 x 720)
# video-viewer:  captured 635 frames (1280 x 720)
# video-viewer:  captured 636 frames (1280 x 720)
# video-viewer:  captured 637 frames (1280 x 720)
# video-viewer:  captured 638 frames (1280 x 720)
# video-viewer:  captured 639 frames (1280 x 720)
# video-viewer:  captured 640 frames (1280 x 720)
# video-viewer:  captured 641 frames (1280 x 720)
# video-viewer:  captured 642 frames (1280 x 720)
# video-viewer:  captured 643 frames (1280 x 720)
# video-viewer:  captured 644 frames (1280 x 720)
# video-viewer:  captured 645 frames (1280 x 720)
# video-viewer:  captured 646 frames (1280 x 720)
# video-viewer:  captured 647 frames (1280 x 720)
# video-viewer:  captured 648 frames (1280 x 720)
# video-viewer:  captured 649 frames (1280 x 720)
# video-viewer:  captured 650 frames (1280 x 720)
# video-viewer:  captured 651 frames (1280 x 720)
# video-viewer:  captured 652 frames (1280 x 720)
# video-viewer:  captured 653 frames (1280 x 720)
# video-viewer:  captured 654 frames (1280 x 720)
# video-viewer:  captured 655 frames (1280 x 720)
# video-viewer:  captured 656 frames (1280 x 720)
# video-viewer:  captured 657 frames (1280 x 720)
# video-viewer:  captured 658 frames (1280 x 720)
# video-viewer:  captured 659 frames (1280 x 720)
# video-viewer:  captured 660 frames (1280 x 720)
# video-viewer:  captured 661 frames (1280 x 720)
# video-viewer:  captured 662 frames (1280 x 720)
# video-viewer:  captured 663 frames (1280 x 720)
# video-viewer:  captured 664 frames (1280 x 720)
# video-viewer:  captured 665 frames (1280 x 720)
# video-viewer:  captured 666 frames (1280 x 720)
# video-viewer:  captured 667 frames (1280 x 720)
# video-viewer:  captured 668 frames (1280 x 720)
# video-viewer:  captured 669 frames (1280 x 720)
# video-viewer:  captured 670 frames (1280 x 720)
# video-viewer:  captured 671 frames (1280 x 720)
# video-viewer:  captured 672 frames (1280 x 720)
# video-viewer:  captured 673 frames (1280 x 720)
# video-viewer:  captured 674 frames (1280 x 720)
# video-viewer:  captured 675 frames (1280 x 720)
# video-viewer:  captured 676 frames (1280 x 720)
# video-viewer:  captured 677 frames (1280 x 720)
# video-viewer:  captured 678 frames (1280 x 720)
# video-viewer:  captured 679 frames (1280 x 720)
# video-viewer:  captured 680 frames (1280 x 720)
# video-viewer:  captured 681 frames (1280 x 720)
# video-viewer:  captured 682 frames (1280 x 720)
# video-viewer:  captured 683 frames (1280 x 720)
# video-viewer:  captured 684 frames (1280 x 720)
# video-viewer:  captured 685 frames (1280 x 720)
# video-viewer:  captured 686 frames (1280 x 720)
# video-viewer:  captured 687 frames (1280 x 720)
# video-viewer:  captured 688 frames (1280 x 720)
# video-viewer:  captured 689 frames (1280 x 720)
# video-viewer:  captured 690 frames (1280 x 720)
# video-viewer:  captured 691 frames (1280 x 720)
# video-viewer:  captured 692 frames (1280 x 720)
# video-viewer:  captured 693 frames (1280 x 720)
# video-viewer:  captured 694 frames (1280 x 720)
# video-viewer:  captured 695 frames (1280 x 720)
# video-viewer:  captured 696 frames (1280 x 720)
# video-viewer:  captured 697 frames (1280 x 720)
# video-viewer:  captured 698 frames (1280 x 720)
# video-viewer:  captured 699 frames (1280 x 720)
# video-viewer:  captured 700 frames (1280 x 720)
# video-viewer:  captured 701 frames (1280 x 720)
# video-viewer:  captured 702 frames (1280 x 720)
# video-viewer:  captured 703 frames (1280 x 720)
# video-viewer:  captured 704 frames (1280 x 720)
# video-viewer:  captured 705 frames (1280 x 720)
# video-viewer:  captured 706 frames (1280 x 720)
# video-viewer:  captured 707 frames (1280 x 720)
# video-viewer:  captured 708 frames (1280 x 720)
# video-viewer:  captured 709 frames (1280 x 720)
# video-viewer:  captured 710 frames (1280 x 720)
# video-viewer:  captured 711 frames (1280 x 720)
# video-viewer:  captured 712 frames (1280 x 720)
# video-viewer:  captured 713 frames (1280 x 720)
# video-viewer:  captured 714 frames (1280 x 720)
# video-viewer:  captured 715 frames (1280 x 720)
# video-viewer:  captured 716 frames (1280 x 720)
# video-viewer:  captured 717 frames (1280 x 720)
# video-viewer:  captured 718 frames (1280 x 720)
# video-viewer:  captured 719 frames (1280 x 720)
# video-viewer:  captured 720 frames (1280 x 720)
# video-viewer:  captured 721 frames (1280 x 720)
# video-viewer:  captured 722 frames (1280 x 720)
# video-viewer:  captured 723 frames (1280 x 720)
# video-viewer:  captured 724 frames (1280 x 720)
# video-viewer:  captured 725 frames (1280 x 720)
# video-viewer:  captured 726 frames (1280 x 720)
# video-viewer:  captured 727 frames (1280 x 720)
# video-viewer:  captured 728 frames (1280 x 720)
# video-viewer:  captured 729 frames (1280 x 720)
# video-viewer:  captured 730 frames (1280 x 720)
# video-viewer:  captured 731 frames (1280 x 720)
# video-viewer:  captured 732 frames (1280 x 720)
# video-viewer:  captured 733 frames (1280 x 720)
# video-viewer:  captured 734 frames (1280 x 720)
# video-viewer:  captured 735 frames (1280 x 720)
# video-viewer:  captured 736 frames (1280 x 720)
# video-viewer:  captured 737 frames (1280 x 720)
# video-viewer:  captured 738 frames (1280 x 720)
# video-viewer:  captured 739 frames (1280 x 720)
# video-viewer:  captured 740 frames (1280 x 720)
# video-viewer:  captured 741 frames (1280 x 720)
# video-viewer:  captured 742 frames (1280 x 720)
# video-viewer:  captured 743 frames (1280 x 720)
# video-viewer:  captured 744 frames (1280 x 720)
# video-viewer:  captured 745 frames (1280 x 720)
# video-viewer:  captured 746 frames (1280 x 720)
# video-viewer:  captured 747 frames (1280 x 720)
# video-viewer:  captured 748 frames (1280 x 720)
# video-viewer:  captured 749 frames (1280 x 720)
# video-viewer:  captured 750 frames (1280 x 720)
# video-viewer:  captured 751 frames (1280 x 720)
# video-viewer:  captured 752 frames (1280 x 720)
# video-viewer:  captured 753 frames (1280 x 720)
# video-viewer:  captured 754 frames (1280 x 720)
# video-viewer:  captured 755 frames (1280 x 720)
# video-viewer:  captured 756 frames (1280 x 720)
# video-viewer:  captured 757 frames (1280 x 720)
# video-viewer:  captured 758 frames (1280 x 720)
# video-viewer:  captured 759 frames (1280 x 720)
# video-viewer:  captured 760 frames (1280 x 720)
# video-viewer:  captured 761 frames (1280 x 720)
# video-viewer:  captured 762 frames (1280 x 720)
# video-viewer:  captured 763 frames (1280 x 720)
# video-viewer:  captured 764 frames (1280 x 720)
# video-viewer:  captured 765 frames (1280 x 720)
# video-viewer:  captured 766 frames (1280 x 720)
# video-viewer:  captured 767 frames (1280 x 720)
# video-viewer:  captured 768 frames (1280 x 720)
# video-viewer:  captured 769 frames (1280 x 720)
# video-viewer:  captured 770 frames (1280 x 720)
# video-viewer:  captured 771 frames (1280 x 720)
# video-viewer:  captured 772 frames (1280 x 720)
# video-viewer:  captured 773 frames (1280 x 720)
# video-viewer:  captured 774 frames (1280 x 720)
# video-viewer:  captured 775 frames (1280 x 720)
# video-viewer:  captured 776 frames (1280 x 720)
# video-viewer:  captured 777 frames (1280 x 720)
# video-viewer:  captured 778 frames (1280 x 720)
# video-viewer:  captured 779 frames (1280 x 720)
# ...
# video-viewer:  captured 2235 frames (1280 x 720)
# video-viewer:  captured 2236 frames (1280 x 720)
# video-viewer:  captured 2237 frames (1280 x 720)
# video-viewer:  captured 2238 frames (1280 x 720)
# video-viewer:  captured 2239 frames (1280 x 720)
# video-viewer:  captured 2240 frames (1280 x 720)
# video-viewer:  captured 2241 frames (1280 x 720)
# video-viewer:  captured 2242 frames (1280 x 720)
# video-viewer:  captured 2243 frames (1280 x 720)
# video-viewer:  captured 2244 frames (1280 x 720)
# video-viewer:  captured 2245 frames (1280 x 720)
# video-viewer:  captured 2246 frames (1280 x 720)
# video-viewer:  captured 2247 frames (1280 x 720)
# video-viewer:  captured 2248 frames (1280 x 720)
# video-viewer:  captured 2249 frames (1280 x 720)
# video-viewer:  captured 2250 frames (1280 x 720)
# video-viewer:  captured 2251 frames (1280 x 720)
# video-viewer:  captured 2252 frames (1280 x 720)
# video-viewer:  captured 2253 frames (1280 x 720)
# video-viewer:  captured 2254 frames (1280 x 720)
# video-viewer:  captured 2255 frames (1280 x 720)
# video-viewer:  captured 2256 frames (1280 x 720)
# video-viewer:  captured 2257 frames (1280 x 720)
# video-viewer:  captured 2258 frames (1280 x 720)
# video-viewer:  captured 2259 frames (1280 x 720)
# video-viewer:  captured 2260 frames (1280 x 720)
# video-viewer:  captured 2261 frames (1280 x 720)
# video-viewer:  captured 2262 frames (1280 x 720)
# video-viewer:  captured 2263 frames (1280 x 720)
# video-viewer:  captured 2264 frames (1280 x 720)
# video-viewer:  captured 2265 frames (1280 x 720)
# video-viewer:  captured 2266 frames (1280 x 720)
# video-viewer:  captured 2267 frames (1280 x 720)
# video-viewer:  captured 2268 frames (1280 x 720)
# video-viewer:  captured 2269 frames (1280 x 720)
# video-viewer:  captured 2270 frames (1280 x 720)
# video-viewer:  captured 2271 frames (1280 x 720)
# video-viewer:  captured 2272 frames (1280 x 720)
# video-viewer:  captured 2273 frames (1280 x 720)
# video-viewer:  captured 2274 frames (1280 x 720)
# video-viewer:  captured 2275 frames (1280 x 720)
# video-viewer:  captured 2276 frames (1280 x 720)
# video-viewer:  captured 2277 frames (1280 x 720)
# video-viewer:  captured 2278 frames (1280 x 720)
# video-viewer:  captured 2279 frames (1280 x 720)
# video-viewer:  captured 2280 frames (1280 x 720)
# video-viewer:  captured 2281 frames (1280 x 720)
# video-viewer:  captured 2282 frames (1280 x 720)
# video-viewer:  captured 2283 frames (1280 x 720)
# video-viewer:  captured 2284 frames (1280 x 720)
# video-viewer:  captured 2285 frames (1280 x 720)
# video-viewer:  captured 2286 frames (1280 x 720)
# video-viewer:  captured 2287 frames (1280 x 720)
# video-viewer:  captured 2288 frames (1280 x 720)
# video-viewer:  captured 2289 frames (1280 x 720)
# video-viewer:  captured 2290 frames (1280 x 720)
# video-viewer:  captured 2291 frames (1280 x 720)
# video-viewer:  captured 2292 frames (1280 x 720)
# video-viewer:  captured 2293 frames (1280 x 720)
# video-viewer:  captured 2294 frames (1280 x 720)
# video-viewer:  captured 2295 frames (1280 x 720)
# video-viewer:  captured 2296 frames (1280 x 720)
# video-viewer:  captured 2297 frames (1280 x 720)
# video-viewer:  captured 2298 frames (1280 x 720)
# video-viewer:  captured 2299 frames (1280 x 720)
# video-viewer:  captured 2300 frames (1280 x 720)
# video-viewer:  captured 2301 frames (1280 x 720)
# video-viewer:  captured 2302 frames (1280 x 720)
# video-viewer:  captured 2303 frames (1280 x 720)
# video-viewer:  captured 2304 frames (1280 x 720)
# video-viewer:  captured 2305 frames (1280 x 720)
# video-viewer:  captured 2306 frames (1280 x 720)
# video-viewer:  captured 2307 frames (1280 x 720)
# video-viewer:  captured 2308 frames (1280 x 720)
# video-viewer:  captured 2309 frames (1280 x 720)
# video-viewer:  captured 2310 frames (1280 x 720)
# video-viewer:  captured 2311 frames (1280 x 720)
# video-viewer:  captured 2312 frames (1280 x 720)
# video-viewer:  captured 2313 frames (1280 x 720)
# video-viewer:  captured 2314 frames (1280 x 720)
# video-viewer:  captured 2315 frames (1280 x 720)
# video-viewer:  captured 2316 frames (1280 x 720)
# video-viewer:  captured 2317 frames (1280 x 720)
# video-viewer:  captured 2318 frames (1280 x 720)
# video-viewer:  captured 2319 frames (1280 x 720)
# video-viewer:  captured 2320 frames (1280 x 720)
# video-viewer:  captured 2321 frames (1280 x 720)
# video-viewer:  captured 2322 frames (1280 x 720)
# video-viewer:  captured 2323 frames (1280 x 720)
# video-viewer:  captured 2324 frames (1280 x 720)
# video-viewer:  captured 2325 frames (1280 x 720)
# video-viewer:  captured 2326 frames (1280 x 720)
# video-viewer:  captured 2327 frames (1280 x 720)
# video-viewer:  captured 2328 frames (1280 x 720)
# video-viewer:  captured 2329 frames (1280 x 720)
# video-viewer:  captured 2330 frames (1280 x 720)
# video-viewer:  captured 2331 frames (1280 x 720)
# video-viewer:  captured 2332 frames (1280 x 720)
# video-viewer:  captured 2333 frames (1280 x 720)
# video-viewer:  captured 2334 frames (1280 x 720)
# video-viewer:  captured 2335 frames (1280 x 720)
# video-viewer:  captured 2336 frames (1280 x 720)
# video-viewer:  captured 2337 frames (1280 x 720)
# video-viewer:  captured 2338 frames (1280 x 720)
# video-viewer:  captured 2339 frames (1280 x 720)
# video-viewer:  captured 2340 frames (1280 x 720)
# video-viewer:  captured 2341 frames (1280 x 720)
# video-viewer:  captured 2342 frames (1280 x 720)
# video-viewer:  captured 2343 frames (1280 x 720)
# video-viewer:  captured 2344 frames (1280 x 720)
# video-viewer:  captured 2345 frames (1280 x 720)
# video-viewer:  captured 2346 frames (1280 x 720)
# video-viewer:  captured 2347 frames (1280 x 720)
# video-viewer:  captured 2348 frames (1280 x 720)
# video-viewer:  captured 2349 frames (1280 x 720)
# video-viewer:  captured 2350 frames (1280 x 720)
# video-viewer:  captured 2351 frames (1280 x 720)
# video-viewer:  captured 2352 frames (1280 x 720)
# video-viewer:  captured 2353 frames (1280 x 720)
# video-viewer:  captured 2354 frames (1280 x 720)
# video-viewer:  captured 2355 frames (1280 x 720)
# video-viewer:  captured 2356 frames (1280 x 720)
# video-viewer:  captured 2357 frames (1280 x 720)
# video-viewer:  captured 2358 frames (1280 x 720)
# video-viewer:  captured 2359 frames (1280 x 720)
# video-viewer:  captured 2360 frames (1280 x 720)
# video-viewer:  captured 2361 frames (1280 x 720)
# video-viewer:  captured 2362 frames (1280 x 720)
# video-viewer:  captured 2363 frames (1280 x 720)
# video-viewer:  captured 2364 frames (1280 x 720)
# video-viewer:  captured 2365 frames (1280 x 720)
# video-viewer:  captured 2366 frames (1280 x 720)
# video-viewer:  captured 2367 frames (1280 x 720)
# video-viewer:  captured 2368 frames (1280 x 720)
# video-viewer:  captured 2369 frames (1280 x 720)
# video-viewer:  captured 2370 frames (1280 x 720)
# video-viewer:  captured 2371 frames (1280 x 720)
# video-viewer:  captured 2372 frames (1280 x 720)
# video-viewer:  captured 2373 frames (1280 x 720)
# video-viewer:  captured 2374 frames (1280 x 720)
# video-viewer:  captured 2375 frames (1280 x 720)
# video-viewer:  captured 2376 frames (1280 x 720)
# video-viewer:  captured 2377 frames (1280 x 720)
# video-viewer:  captured 2378 frames (1280 x 720)
# video-viewer:  captured 2379 frames (1280 x 720)
# video-viewer:  captured 2380 frames (1280 x 720)
# video-viewer:  captured 2381 frames (1280 x 720)
# video-viewer:  captured 2382 frames (1280 x 720)
# video-viewer:  captured 2383 frames (1280 x 720)
# video-viewer:  captured 2384 frames (1280 x 720)
# video-viewer:  captured 2385 frames (1280 x 720)
# video-viewer:  captured 2386 frames (1280 x 720)
# video-viewer:  captured 2387 frames (1280 x 720)
# video-viewer:  captured 2388 frames (1280 x 720)
# video-viewer:  captured 2389 frames (1280 x 720)
# video-viewer:  captured 2390 frames (1280 x 720)
# video-viewer:  captured 2391 frames (1280 x 720)
# video-viewer:  captured 2392 frames (1280 x 720)
# video-viewer:  captured 2393 frames (1280 x 720)
# video-viewer:  captured 2394 frames (1280 x 720)
# video-viewer:  captured 2395 frames (1280 x 720)
# video-viewer:  captured 2396 frames (1280 x 720)
# video-viewer:  captured 2397 frames (1280 x 720)
# video-viewer:  captured 2398 frames (1280 x 720)
# video-viewer:  captured 2399 frames (1280 x 720)
# video-viewer:  captured 2400 frames (1280 x 720)
# video-viewer:  captured 2401 frames (1280 x 720)
# video-viewer:  captured 2402 frames (1280 x 720)
# video-viewer:  captured 2403 frames (1280 x 720)
# video-viewer:  captured 2404 frames (1280 x 720)
# video-viewer:  captured 2405 frames (1280 x 720)
# video-viewer:  captured 2406 frames (1280 x 720)
# video-viewer:  captured 2407 frames (1280 x 720)
# video-viewer:  captured 2408 frames (1280 x 720)
# video-viewer:  captured 2409 frames (1280 x 720)
# video-viewer:  captured 2410 frames (1280 x 720)
# video-viewer:  captured 2411 frames (1280 x 720)
# video-viewer:  captured 2412 frames (1280 x 720)
# video-viewer:  captured 2413 frames (1280 x 720)
# video-viewer:  captured 2414 frames (1280 x 720)
# video-viewer:  captured 2415 frames (1280 x 720)
# video-viewer:  captured 2416 frames (1280 x 720)
# video-viewer:  captured 2417 frames (1280 x 720)
# video-viewer:  captured 2418 frames (1280 x 720)
# video-viewer:  captured 2419 frames (1280 x 720)
# video-viewer:  captured 2420 frames (1280 x 720)
# video-viewer:  captured 2421 frames (1280 x 720)
# video-viewer:  captured 2422 frames (1280 x 720)
# video-viewer:  captured 2423 frames (1280 x 720)
# video-viewer:  captured 2424 frames (1280 x 720)
# video-viewer:  captured 2425 frames (1280 x 720)
# video-viewer:  captured 2426 frames (1280 x 720)
# video-viewer:  captured 2427 frames (1280 x 720)
# video-viewer:  captured 2428 frames (1280 x 720)
# video-viewer:  captured 2429 frames (1280 x 720)
# video-viewer:  captured 2430 frames (1280 x 720)
# video-viewer:  captured 2431 frames (1280 x 720)
# video-viewer:  captured 2432 frames (1280 x 720)
# video-viewer:  captured 2433 frames (1280 x 720)
# video-viewer:  captured 2434 frames (1280 x 720)
# video-viewer:  captured 2435 frames (1280 x 720)
# video-viewer:  captured 2436 frames (1280 x 720)
# video-viewer:  captured 2437 frames (1280 x 720)
# video-viewer:  captured 2438 frames (1280 x 720)
# video-viewer:  captured 2439 frames (1280 x 720)
# video-viewer:  captured 2440 frames (1280 x 720)
# video-viewer:  captured 2441 frames (1280 x 720)
# video-viewer:  captured 2442 frames (1280 x 720)
# video-viewer:  captured 2443 frames (1280 x 720)
# video-viewer:  captured 2444 frames (1280 x 720)
# video-viewer:  captured 2445 frames (1280 x 720)
# video-viewer:  captured 2446 frames (1280 x 720)
# video-viewer:  captured 2447 frames (1280 x 720)
# video-viewer:  captured 2448 frames (1280 x 720)
# video-viewer:  captured 2449 frames (1280 x 720)
# video-viewer:  captured 2450 frames (1280 x 720)
# video-viewer:  captured 2451 frames (1280 x 720)
# video-viewer:  captured 2452 frames (1280 x 720)
# video-viewer:  captured 2453 frames (1280 x 720)
# video-viewer:  captured 2454 frames (1280 x 720)
# video-viewer:  captured 2455 frames (1280 x 720)
# video-viewer:  captured 2456 frames (1280 x 720)
# video-viewer:  captured 2457 frames (1280 x 720)
# video-viewer:  captured 2458 frames (1280 x 720)
# video-viewer:  captured 2459 frames (1280 x 720)
# video-viewer:  captured 2460 frames (1280 x 720)
# video-viewer:  captured 2461 frames (1280 x 720)
# video-viewer:  captured 2462 frames (1280 x 720)
# video-viewer:  captured 2463 frames (1280 x 720)
# video-viewer:  captured 2464 frames (1280 x 720)
# video-viewer:  captured 2465 frames (1280 x 720)
# video-viewer:  captured 2466 frames (1280 x 720)
# video-viewer:  captured 2467 frames (1280 x 720)
# video-viewer:  captured 2468 frames (1280 x 720)
# video-viewer:  captured 2469 frames (1280 x 720)
# video-viewer:  captured 2470 frames (1280 x 720)
# video-viewer:  captured 2471 frames (1280 x 720)
# video-viewer:  captured 2472 frames (1280 x 720)
# video-viewer:  captured 2473 frames (1280 x 720)
# video-viewer:  captured 2474 frames (1280 x 720)
# video-viewer:  captured 2475 frames (1280 x 720)
# video-viewer:  captured 2476 frames (1280 x 720)
# video-viewer:  captured 2477 frames (1280 x 720)
# video-viewer:  captured 2478 frames (1280 x 720)
# video-viewer:  captured 2479 frames (1280 x 720)
# video-viewer:  captured 2480 frames (1280 x 720)
# video-viewer:  captured 2481 frames (1280 x 720)
# video-viewer:  captured 2482 frames (1280 x 720)
# video-viewer:  captured 2483 frames (1280 x 720)
# video-viewer:  captured 2484 frames (1280 x 720)
# video-viewer:  captured 2485 frames (1280 x 720)
# video-viewer:  captured 2486 frames (1280 x 720)
# video-viewer:  captured 2487 frames (1280 x 720)
# video-viewer:  captured 2488 frames (1280 x 720)
# video-viewer:  captured 2489 frames (1280 x 720)
# video-viewer:  captured 2490 frames (1280 x 720)
# video-viewer:  captured 2491 frames (1280 x 720)
# video-viewer:  captured 2492 frames (1280 x 720)
# video-viewer:  captured 2493 frames (1280 x 720)
# video-viewer:  captured 2494 frames (1280 x 720)
# video-viewer:  captured 2495 frames (1280 x 720)
# video-viewer:  captured 2496 frames (1280 x 720)
# video-viewer:  captured 2497 frames (1280 x 720)
# video-viewer:  captured 2498 frames (1280 x 720)
# video-viewer:  captured 2499 frames (1280 x 720)
# video-viewer:  captured 2500 frames (1280 x 720)
# video-viewer:  captured 2501 frames (1280 x 720)
# video-viewer:  captured 2502 frames (1280 x 720)
# video-viewer:  captured 2503 frames (1280 x 720)
# video-viewer:  captured 2504 frames (1280 x 720)
# video-viewer:  captured 2505 frames (1280 x 720)
# video-viewer:  captured 2506 frames (1280 x 720)
# video-viewer:  captured 2507 frames (1280 x 720)
# video-viewer:  captured 2508 frames (1280 x 720)
# video-viewer:  captured 2509 frames (1280 x 720)
# video-viewer:  captured 2510 frames (1280 x 720)
# video-viewer:  captured 2511 frames (1280 x 720)
# video-viewer:  captured 2512 frames (1280 x 720)
# video-viewer:  captured 2513 frames (1280 x 720)
# video-viewer:  captured 2514 frames (1280 x 720)
# video-viewer:  captured 2515 frames (1280 x 720)
# video-viewer:  captured 2516 frames (1280 x 720)
# video-viewer:  captured 2517 frames (1280 x 720)
# video-viewer:  captured 2518 frames (1280 x 720)
# video-viewer:  captured 2519 frames (1280 x 720)
# video-viewer:  captured 2520 frames (1280 x 720)
# video-viewer:  captured 2521 frames (1280 x 720)
# video-viewer:  captured 2522 frames (1280 x 720)
# video-viewer:  captured 2523 frames (1280 x 720)
# video-viewer:  captured 2524 frames (1280 x 720)
# video-viewer:  captured 2525 frames (1280 x 720)
# video-viewer:  captured 2526 frames (1280 x 720)
# video-viewer:  captured 2527 frames (1280 x 720)
# video-viewer:  captured 2528 frames (1280 x 720)
# video-viewer:  captured 2529 frames (1280 x 720)
# video-viewer:  captured 2530 frames (1280 x 720)
# video-viewer:  captured 2531 frames (1280 x 720)
# video-viewer:  captured 2532 frames (1280 x 720)
# video-viewer:  captured 2533 frames (1280 x 720)
# video-viewer:  captured 2534 frames (1280 x 720)
# video-viewer:  captured 2535 frames (1280 x 720)
# video-viewer:  captured 2536 frames (1280 x 720)
# video-viewer:  captured 2537 frames (1280 x 720)
# video-viewer:  captured 2538 frames (1280 x 720)
# video-viewer:  captured 2539 frames (1280 x 720)
# video-viewer:  captured 2540 frames (1280 x 720)
# video-viewer:  captured 2541 frames (1280 x 720)
# video-viewer:  captured 2542 frames (1280 x 720)
# video-viewer:  captured 2543 frames (1280 x 720)
# video-viewer:  captured 2544 frames (1280 x 720)
# video-viewer:  captured 2545 frames (1280 x 720)
# video-viewer:  captured 2546 frames (1280 x 720)
# video-viewer:  captured 2547 frames (1280 x 720)
# video-viewer:  captured 2548 frames (1280 x 720)
# video-viewer:  captured 2549 frames (1280 x 720)
# video-viewer:  captured 2550 frames (1280 x 720)
# video-viewer:  captured 2551 frames (1280 x 720)
# video-viewer:  captured 2552 frames (1280 x 720)
# video-viewer:  captured 2553 frames (1280 x 720)
# video-viewer:  captured 2554 frames (1280 x 720)
# video-viewer:  captured 2555 frames (1280 x 720)
# video-viewer:  captured 2557 frames (1280 x 720)
# ^C
# received SIGINT
# video-viewer:  captured 2558 frames (1280 x 720)
# video-viewer:  shutting down...
# [gstreamer] gstCamera -- stopping pipeline, transitioning to GST_STATE_NULL

# %%
# !detectnet /dev/video0 rtp://192.168.1.13:1234
# Out:
# [gstreamer] initialized gstreamer, version 1.14.5.0
# [gstreamer] gstCamera -- attempting to create device v4l2:///dev/video0
# [gstreamer] gstCamera -- found v4l2 device: USB Camera
# [gstreamer] v4l2-proplist, device.path=(string)/dev/video0, udev-probed=(boolean)false, device.api=(string)v4l2, v4l2.device.driver=(string)uvcvideo, v4l2.device.card=(string)"USB\ Camera", v4l2.device.bus_info=(string)usb-70090000.xusb-2.3, v4l2.device.version=(uint)264701, v4l2.device.capabilities=(uint)2216689665, v4l2.device.device_caps=(uint)69206017;
# [gstreamer] gstCamera -- found 26 caps for v4l2 device /dev/video0
# [gstreamer] [0] video/x-raw, format=(string)YUY2, width=(int)1920, height=(int)1080, pixel-aspect-ratio=(fraction)1/1, framerate=(fraction)5/1;
# [gstreamer] [1] video/x-raw, format=(string)YUY2, width=(int)1280, height=(int)960, pixel-aspect-ratio=(fraction)1/1, framerate=(fraction)5/1;
# [gstreamer] [2] video/x-raw, format=(string)YUY2, width=(int)1280, height=(int)720, pixel-aspect-ratio=(fraction)1/1, framerate=(fraction)10/1;
# [gstreamer] [3] video/x-raw, format=(string)YUY2, width=(int)1024, height=(int)768, pixel-aspect-ratio=(fraction)1/1, framerate=(fraction)15/1;
# [gstreamer] [4] video/x-raw, format=(string)YUY2, width=(int)1280, height=(int)480, pixel-aspect-ratio=(fraction)1/1, framerate=(fraction)10/1;
# [gstreamer] [5] video/x-raw, format=(string)YUY2, width=(int)800, height=(int)600, pixel-aspect-ratio=(fraction)1/1, framerate=(fraction)20/1;
# [gstreamer] [6] video/x-raw, format=(string)YUY2, width=(int)848, height=(int)480, pixel-aspect-ratio=(fraction)1/1, framerate=(fraction)20/1;
# [gstreamer] [7] video/x-raw, format=(string)YUY2, width=(int)640, height=(int)480, pixel-aspect-ratio=(fraction)1/1, framerate=(fraction)30/1;
# [gstreamer] [8] video/x-raw, format=(string)YUY2, width=(int)640, height=(int)400, pixel-aspect-ratio=(fraction)1/1, framerate=(fraction)30/1;
# [gstreamer] [9] video/x-raw, format=(string)YUY2, width=(int)352, height=(int)288, pixel-aspect-ratio=(fraction)1/1, framerate=(fraction)30/1;
# [gstreamer] [10] video/x-raw, format=(string)YUY2, width=(int)320, height=(int)240, pixel-aspect-ratio=(fraction)1/1, framerate=(fraction)30/1;
# [gstreamer] [11] video/x-raw, format=(string)YUY2, width=(int)176, height=(int)144, pixel-aspect-ratio=(fraction)1/1, framerate=(fraction)30/1;
# [gstreamer] [12] video/x-raw, format=(string)YUY2, width=(int)160, height=(int)120, pixel-aspect-ratio=(fraction)1/1, framerate=(fraction){ 30/1, 5/1 };
# [gstreamer] [13] image/jpeg, width=(int)1920, height=(int)1080, pixel-aspect-ratio=(fraction)1/1, framerate=(fraction)30/1;
# [gstreamer] [14] image/jpeg, width=(int)1280, height=(int)1024, pixel-aspect-ratio=(fraction)1/1, framerate=(fraction)30/1;
# [gstreamer] [15] image/jpeg, width=(int)1280, height=(int)960, pixel-aspect-ratio=(fraction)1/1, framerate=(fraction)30/1;
# [gstreamer] [16] image/jpeg, width=(int)1280, height=(int)720, pixel-aspect-ratio=(fraction)1/1, framerate=(fraction){ 30/1, 5/1 };
# [gstreamer] [17] image/jpeg, width=(int)1280, height=(int)480, pixel-aspect-ratio=(fraction)1/1, framerate=(fraction)30/1;
# [gstreamer] [18] image/jpeg, width=(int)800, height=(int)600, pixel-aspect-ratio=(fraction)1/1, framerate=(fraction){ 30/1, 5/1 };
# [gstreamer] [19] image/jpeg, width=(int)848, height=(int)480, pixel-aspect-ratio=(fraction)1/1, framerate=(fraction)30/1;
# [gstreamer] [20] image/jpeg, width=(int)640, height=(int)480, pixel-aspect-ratio=(fraction)1/1, framerate=(fraction){ 30/1, 5/1 };
# [gstreamer] [21] image/jpeg, width=(int)640, height=(int)400, pixel-aspect-ratio=(fraction)1/1, framerate=(fraction)30/1;
# [gstreamer] [22] image/jpeg, width=(int)352, height=(int)288, pixel-aspect-ratio=(fraction)1/1, framerate=(fraction)30/1;
# [gstreamer] [23] image/jpeg, width=(int)320, height=(int)240, pixel-aspect-ratio=(fraction)1/1, framerate=(fraction){ 30/1, 5/1 };
# [gstreamer] [24] image/jpeg, width=(int)176, height=(int)144, pixel-aspect-ratio=(fraction)1/1, framerate=(fraction)30/1;
# [gstreamer] [25] image/jpeg, width=(int)160, height=(int)120, pixel-aspect-ratio=(fraction)1/1, framerate=(fraction){ 30/1, 5/1 };
# [gstreamer] gstCamera -- selected device profile:  codec=mjpeg format=unknown width=1280 height=720
# [gstreamer] gstCamera pipeline string:
# [gstreamer] v4l2src device=/dev/video0 ! image/jpeg, width=(int)1280, height=(int)720 ! jpegdec ! video/x-raw ! appsink name=mysink
# [gstreamer] gstCamera successfully created device v4l2:///dev/video0
# [video]  created gstCamera from v4l2:///dev/video0
# ------------------------------------------------
# gstCamera video options:
# ------------------------------------------------
#   -- URI: v4l2:///dev/video0
#      - protocol:  v4l2
#      - location:  /dev/video0
#   -- deviceType: v4l2
#   -- ioType:     input
#   -- codec:      mjpeg
#   -- width:      1280
#   -- height:     720
#   -- frameRate:  30.000000
#   -- bitRate:    0
#   -- numBuffers: 4
#   -- zeroCopy:   true
#   -- flipMethod: none
#   -- loop:       0
#   -- rtspLatency 2000
# ------------------------------------------------
# [gstreamer] gstEncoder -- codec not specified, defaulting to H.264
# [gstreamer] gstEncoder -- pipeline launch string:
# [gstreamer] appsrc name=mysource is-live=true do-timestamp=true format=3 ! omxh264enc bitrate=4000000 ! video/x-h264 !  rtph264pay config-interval=1 ! udpsink host=192.168.1.13 port=1234 auto-multicast=true
# [video]  created gstEncoder from rtp://192.168.1.13:1234
# ------------------------------------------------
# gstEncoder video options:
# ------------------------------------------------
#   -- URI: rtp://192.168.1.13:1234
#      - protocol:  rtp
#      - location:  192.168.1.13
#      - port:      1234
#   -- deviceType: ip
#   -- ioType:     output
#   -- codec:      h264
#   -- width:      0
#   -- height:     0
#   -- frameRate:  30.000000
#   -- bitRate:    4000000
#   -- numBuffers: 4
#   -- zeroCopy:   true
#   -- flipMethod: none
#   -- loop:       0
#   -- rtspLatency 2000
# ------------------------------------------------
# [OpenGL] failed to open X11 server connection.
# [OpenGL] failed to create X11 Window.
#
# detectNet -- loading detection network model from:
#           -- model        networks/SSD-Mobilenet-v2/ssd_mobilenet_v2_coco.uff
#           -- input_blob   'Input'
#           -- output_blob  'NMS'
#           -- output_count 'NMS_1'
#           -- class_labels networks/SSD-Mobilenet-v2/ssd_coco_labels.txt
#           -- threshold    0.500000
#           -- batch_size   1
#
# [TRT]    TensorRT version 8.0.1
# [TRT]    loading NVIDIA plugins...
# [TRT]    Registered plugin creator - ::GridAnchor_TRT version 1
# [TRT]    Registered plugin creator - ::GridAnchorRect_TRT version 1
# [TRT]    Registered plugin creator - ::NMS_TRT version 1
# [TRT]    Registered plugin creator - ::Reorg_TRT version 1
# [TRT]    Registered plugin creator - ::Region_TRT version 1
# [TRT]    Registered plugin creator - ::Clip_TRT version 1
# [TRT]    Registered plugin creator - ::LReLU_TRT version 1
# [TRT]    Registered plugin creator - ::PriorBox_TRT version 1
# [TRT]    Registered plugin creator - ::Normalize_TRT version 1
# [TRT]    Registered plugin creator - ::ScatterND version 1
# [TRT]    Registered plugin creator - ::RPROI_TRT version 1
# [TRT]    Registered plugin creator - ::BatchedNMS_TRT version 1
# [TRT]    Registered plugin creator - ::BatchedNMSDynamic_TRT version 1
# [TRT]    Could not register plugin creator -  ::FlattenConcat_TRT version 1
# [TRT]    Registered plugin creator - ::CropAndResize version 1
# [TRT]    Registered plugin creator - ::DetectionLayer_TRT version 1
# [TRT]    Registered plugin creator - ::EfficientNMS_ONNX_TRT version 1
# [TRT]    Registered plugin creator - ::EfficientNMS_TRT version 1
# [TRT]    Registered plugin creator - ::Proposal version 1
# [TRT]    Registered plugin creator - ::ProposalLayer_TRT version 1
# [TRT]    Registered plugin creator - ::PyramidROIAlign_TRT version 1
# [TRT]    Registered plugin creator - ::ResizeNearest_TRT version 1
# [TRT]    Registered plugin creator - ::Split version 1
# [TRT]    Registered plugin creator - ::SpecialSlice_TRT version 1
# [TRT]    Registered plugin creator - ::InstanceNormalization_TRT version 1
# [TRT]    detected model format - UFF  (extension '.uff')
# [TRT]    desired precision specified for GPU: FASTEST
# [TRT]    requested fasted precision for device GPU without providing valid calibrator, disabling INT8
# [TRT]    [MemUsageChange] Init CUDA: CPU +203, GPU +0, now: CPU 226, GPU 2998 (MiB)
# [TRT]    native precisions detected for GPU:  FP32, FP16
# [TRT]    selecting fastest native precision for GPU:  FP16
# [TRT]    attempting to open engine cache file /usr/local/bin/networks/SSD-Mobilenet-v2/ssd_mobilenet_v2_coco.uff.1.1.8001.GPU.FP16.engine
# [TRT]    loading network plan from engine cache... /usr/local/bin/networks/SSD-Mobilenet-v2/ssd_mobilenet_v2_coco.uff.1.1.8001.GPU.FP16.engine
# [TRT]    device GPU, loaded /usr/local/bin/networks/SSD-Mobilenet-v2/ssd_mobilenet_v2_coco.uff
# [TRT]    [MemUsageChange] Init CUDA: CPU +0, GPU +0, now: CPU 260, GPU 3065 (MiB)
# [TRT]    Loaded engine size: 33 MB
# [TRT]    [MemUsageSnapshot] deserializeCudaEngine begin: CPU 260 MiB, GPU 3065 MiB
# [TRT]    Using cublas a tactic source
# [TRT]    [MemUsageChange] Init cuBLAS/cuBLASLt: CPU +158, GPU +246, now: CPU 436, GPU 3340 (MiB)
# [TRT]    Using cuDNN as a tactic source
# [TRT]    [MemUsageChange] Init cuDNN: CPU +240, GPU +347, now: CPU 676, GPU 3687 (MiB)
# [TRT]    [MemUsageChange] Init cuBLAS/cuBLASLt: CPU +0, GPU +0, now: CPU 676, GPU 3687 (MiB)
# [TRT]    Deserialization required 6029414 microseconds.
# [TRT]    [MemUsageSnapshot] deserializeCudaEngine end: CPU 676 MiB, GPU 3687 MiB
# [TRT]    [MemUsageSnapshot] ExecutionContext creation begin: CPU 676 MiB, GPU 3687 MiB
# [TRT]    Using cublas a tactic source
# [TRT]    [MemUsageChange] Init cuBLAS/cuBLASLt: CPU +1, GPU +0, now: CPU 677, GPU 3687 (MiB)
# [TRT]    Using cuDNN as a tactic source
# [TRT]    [MemUsageChange] Init cuDNN: CPU +0, GPU +0, now: CPU 677, GPU 3687 (MiB)
# [TRT]    Total per-runner device memory is 22143488
# [TRT]    Total per-runner host memory is 131872
# [TRT]    Allocated activation device memory of size 14261248
# [TRT]    [MemUsageSnapshot] ExecutionContext creation end: CPU 679 MiB, GPU 3459 MiB
# [TRT]
# [TRT]    CUDA engine context initialized on device GPU:
# [TRT]       -- layers       123
# [TRT]       -- maxBatchSize 1
# [TRT]       -- deviceMemory 14261248
# [TRT]       -- bindings     3
# [TRT]       binding 0
#                 -- index   0
#                 -- name    'Input'
#                 -- type    FP32
#                 -- in/out  INPUT
#                 -- # dims  3
#                 -- dim #0  3
#                 -- dim #1  300
#                 -- dim #2  300
# [TRT]       binding 1
#                 -- index   1
#                 -- name    'NMS'
#                 -- type    FP32
#                 -- in/out  OUTPUT
#                 -- # dims  3
#                 -- dim #0  1
#                 -- dim #1  100
#                 -- dim #2  7
# [TRT]       binding 2
#                 -- index   2
#                 -- name    'NMS_1'
#                 -- type    FP32
#                 -- in/out  OUTPUT
#                 -- # dims  3
#                 -- dim #0  1
#                 -- dim #1  1
#                 -- dim #2  1
# [TRT]
# [TRT]    binding to input 0 Input  binding index:  0
# [TRT]    binding to input 0 Input  dims (b=1 c=3 h=300 w=300) size=1080000
# [TRT]    binding to output 0 NMS  binding index:  1
# [TRT]    binding to output 0 NMS  dims (b=1 c=1 h=100 w=7) size=2800
# [TRT]    binding to output 1 NMS_1  binding index:  2
# [TRT]    binding to output 1 NMS_1  dims (b=1 c=1 h=1 w=1) size=4
# [TRT]
# [TRT]    device GPU, /usr/local/bin/networks/SSD-Mobilenet-v2/ssd_mobilenet_v2_coco.uff initialized.
# [TRT]    W = 7  H = 100  C = 1
# [TRT]    detectNet -- maximum bounding boxes:  100
# [TRT]    detectNet -- loaded 91 class info entries
# [TRT]    detectNet -- number of object classes:  91
# [gstreamer] opening gstCamera for streaming, transitioning pipeline to GST_STATE_PLAYING
# [gstreamer] gstreamer changed state from NULL to READY ==> mysink
# [gstreamer] gstreamer changed state from NULL to READY ==> capsfilter1
# [gstreamer] gstreamer changed state from NULL to READY ==> jpegdec0
# [gstreamer] gstreamer changed state from NULL to READY ==> capsfilter0
# [gstreamer] gstreamer changed state from NULL to READY ==> v4l2src0
# [gstreamer] gstreamer changed state from NULL to READY ==> pipeline0
# [gstreamer] gstreamer changed state from READY to PAUSED ==> capsfilter1
# [gstreamer] gstreamer changed state from READY to PAUSED ==> jpegdec0
# [gstreamer] gstreamer changed state from READY to PAUSED ==> capsfilter0
# [gstreamer] gstreamer stream status CREATE ==> src
# [gstreamer] gstreamer changed state from READY to PAUSED ==> v4l2src0
# [gstreamer] gstreamer stream status ENTER ==> src
# [gstreamer] gstreamer changed state from READY to PAUSED ==> pipeline0
# [gstreamer] gstreamer message new-clock ==> pipeline0
# [gstreamer] gstreamer message stream-start ==> pipeline0
# [gstreamer] gstreamer changed state from PAUSED to PLAYING ==> capsfilter1
# [gstreamer] gstreamer changed state from PAUSED to PLAYING ==> jpegdec0
# [gstreamer] gstreamer changed state from PAUSED to PLAYING ==> capsfilter0
# [gstreamer] gstreamer changed state from PAUSED to PLAYING ==> v4l2src0
# [gstreamer] gstCamera -- onPreroll
# [gstreamer] gstCamera -- map buffer size was less than max size (1382400 vs 1382407)
# [gstreamer] gstCamera recieve caps:  video/x-raw, format=(string)I420, width=(int)1280, height=(int)720, interlace-mode=(string)progressive, multiview-mode=(string)mono, multiview-flags=(GstVideoMultiviewFlagsSet)0:ffffffff:/right-view-first/left-flipped/left-flopped/right-flipped/right-flopped/half-aspect/mixed-mono, pixel-aspect-ratio=(fraction)1/1, chroma-site=(string)mpeg2, colorimetry=(string)1:4:0:0, framerate=(fraction)30/1
# [gstreamer] gstCamera -- recieved first frame, codec=mjpeg format=i420 width=1280 height=720 size=1382407
# RingBuffer -- allocated 4 buffers (1382407 bytes each, 5529628 bytes total)
# [gstreamer] gstreamer changed state from READY to PAUSED ==> mysink
# [gstreamer] gstreamer message async-done ==> pipeline0
# [gstreamer] gstreamer changed state from PAUSED to PLAYING ==> mysink
# [gstreamer] gstreamer changed state from PAUSED to PLAYING ==> pipeline0
# RingBuffer -- allocated 4 buffers (2764800 bytes each, 11059200 bytes total)
# RingBuffer -- allocated 2 buffers (1382400 bytes each, 2764800 bytes total)
# [gstreamer] gstEncoder-- starting pipeline, transitioning to GST_STATE_PLAYING
# [gstreamer] gstreamer changed state from NULL to READY ==> udpsink0
# [gstreamer] gstreamer changed state from NULL to READY ==> rtph264pay0
# [gstreamer] gstreamer changed state from NULL to READY ==> capsfilter2
# [gstreamer] gstreamer changed state from NULL to READY ==> omxh264enc-omxh264enc0
# [gstreamer] gstreamer changed state from NULL to READY ==> mysource
# [gstreamer] gstreamer changed state from NULL to READY ==> pipeline1
# [gstreamer] gstreamer changed state from READY to PAUSED ==> rtph264pay0
# [gstreamer] gstreamer changed state from READY to PAUSED ==> capsfilter2
# [gstreamer] gstreamer changed state from READY to PAUSED ==> omxh264enc-omxh264enc0
# [gstreamer] gstreamer stream status CREATE ==> src
# [gstreamer] gstreamer changed state from READY to PAUSED ==> mysource
# [gstreamer] gstreamer changed state from READY to PAUSED ==> pipeline1
# [gstreamer] gstreamer message new-clock ==> pipeline1
# [gstreamer] gstreamer stream status ENTER ==> src
# [gstreamer] gstreamer changed state from PAUSED to PLAYING ==> rtph264pay0
# [gstreamer] gstreamer changed state from PAUSED to PLAYING ==> capsfilter2
# [gstreamer] gstreamer changed state from PAUSED to PLAYING ==> omxh264enc-omxh264enc0
# [gstreamer] gstreamer changed state from PAUSED to PLAYING ==> mysource
# [gstreamer] gstEncoder -- new caps: video/x-raw, width=1280, height=720, format=(string)I420, framerate=30/1
# Framerate set to : 30 at NvxVideoEncoderSetParameter
# [TRT]    ------------------------------------------------
# [TRT]    Timing Report /usr/local/bin/networks/SSD-Mobilenet-v2/ssd_mobilenet_v2_coco.uff
# [TRT]    ------------------------------------------------
# [TRT]    Pre-Process   CPU   0.06901ms  CUDA   8.23526ms
# [TRT]    Network       CPU 3744.63574ms  CUDA 3710.17358ms
# [TRT]    Post-Process  CPU   0.03286ms  CUDA   0.03240ms
# [TRT]    Total         CPU 3744.73779ms  CUDA 3718.44141ms
# [TRT]    ------------------------------------------------
#
# [TRT]    note -- when processing a single image, run 'sudo jetson_clocks' before
#                 to disable DVFS for more accurate profiling/timing measurements
#
# NvMMLiteOpen : Block : BlockType = 4
# ===== NVMEDIA: NVENC =====
# NvMMLiteBlockCreate : Block : BlockType = 4
# H264: Profile = 66, Level = 40
# NVMEDIA_ENC: bBlitMode is set to TRUE
# 1 objects detected
# detected obj 0  class #1 (person)  confidence=0.856934
# bounding box 0  (786.250000, 153.281250)  (1271.250000, 714.375000)  w=485.000000  h=561.093750
# [gstreamer] gstreamer stream status CREATE ==> src
# [gstreamer] gstreamer stream status ENTER ==> src
# [gstreamer] gstreamer message stream-start ==> pipeline1
# [gstreamer] gstreamer changed state from READY to PAUSED ==> udpsink0
# [gstreamer] gstreamer message async-done ==> pipeline1
# [gstreamer] gstreamer changed state from PAUSED to PLAYING ==> udpsink0
# [gstreamer] gstreamer changed state from PAUSED to PLAYING ==> pipeline1
#
# [TRT]    ------------------------------------------------
# [TRT]    Timing Report /usr/local/bin/networks/SSD-Mobilenet-v2/ssd_mobilenet_v2_coco.uff
# [TRT]    ------------------------------------------------
# [TRT]    Pre-Process   CPU   0.05526ms  CUDA   1.27714ms
# [TRT]    Network       CPU  77.46090ms  CUDA  65.41151ms
# [TRT]    Post-Process  CPU   0.04927ms  CUDA   0.04875ms
# [TRT]    Visualize     CPU  12.15058ms  CUDA  12.41828ms
# [TRT]    Total         CPU  89.71601ms  CUDA  79.15568ms
# [TRT]    ------------------------------------------------
#
# 1 objects detected
# detected obj 0  class #1 (person)  confidence=0.820801
# bounding box 0  (805.000000, 158.027344)  (1268.750000, 716.484375)  w=463.750000  h=558.457031
#
# [TRT]    ------------------------------------------------
# [TRT]    Timing Report /usr/local/bin/networks/SSD-Mobilenet-v2/ssd_mobilenet_v2_coco.uff
# [TRT]    ------------------------------------------------
# [TRT]    Pre-Process   CPU   0.05708ms  CUDA   1.04354ms
# [TRT]    Network       CPU  59.63732ms  CUDA  49.05229ms
# [TRT]    Post-Process  CPU   0.04542ms  CUDA   0.04641ms
# [TRT]    Visualize     CPU   0.20938ms  CUDA   3.61250ms
# [TRT]    Total         CPU  59.94920ms  CUDA  53.75474ms
# [TRT]    ------------------------------------------------
#
# 1 objects detected
# detected obj 0  class #1 (person)  confidence=0.881836
# bounding box 0  (786.250000, 158.554688)  (1273.750000, 719.000000)  w=487.500000  h=560.445312
#
# [TRT]    ------------------------------------------------
# [TRT]    Timing Report /usr/local/bin/networks/SSD-Mobilenet-v2/ssd_mobilenet_v2_coco.uff
# [TRT]    ------------------------------------------------
# [TRT]    Pre-Process   CPU   0.11464ms  CUDA   1.11833ms
# [TRT]    Network       CPU  49.95362ms  CUDA  37.92219ms
# [TRT]    Post-Process  CPU   0.03026ms  CUDA   0.03052ms
# [TRT]    Visualize     CPU   0.15631ms  CUDA   3.76427ms
# [TRT]    Total         CPU  50.25483ms  CUDA  42.83531ms
# [TRT]    ------------------------------------------------
#
# 1 objects detected
# detected obj 0  class #1 (person)  confidence=0.849121
# bounding box 0  (837.500000, 159.785156)  (1265.000000, 719.000000)  w=427.500000  h=559.214844
#
# [TRT]    ------------------------------------------------
# [TRT]    Timing Report /usr/local/bin/networks/SSD-Mobilenet-v2/ssd_mobilenet_v2_coco.uff
# [TRT]    ------------------------------------------------
# [TRT]    Pre-Process   CPU   0.06927ms  CUDA   1.01651ms
# [TRT]    Network       CPU  48.13264ms  CUDA  37.17411ms
# [TRT]    Post-Process  CPU   0.03323ms  CUDA   0.03323ms
# [TRT]    Visualize     CPU   0.17287ms  CUDA   3.49651ms
# [TRT]    Total         CPU  48.40801ms  CUDA  41.72036ms
# [TRT]    ------------------------------------------------
#
# 1 objects detected
# detected obj 0  class #1 (person)  confidence=0.888184
# bounding box 0  (776.250000, 160.664062)  (1273.750000, 718.945312)  w=497.500000  h=558.281250
#
# [TRT]    ------------------------------------------------
# [TRT]    Timing Report /usr/local/bin/networks/SSD-Mobilenet-v2/ssd_mobilenet_v2_coco.uff
# [TRT]    ------------------------------------------------
# [TRT]    Pre-Process   CPU   0.10761ms  CUDA   1.03813ms
# [TRT]    Network       CPU  48.15123ms  CUDA  37.00057ms
# [TRT]    Post-Process  CPU   0.02792ms  CUDA   0.02761ms
# [TRT]    Visualize     CPU   0.14985ms  CUDA   4.15594ms
# [TRT]    Total         CPU  48.43660ms  CUDA  42.22224ms
# [TRT]    ------------------------------------------------
#
# 1 objects detected
# detected obj 0  class #1 (person)  confidence=0.914551
# bounding box 0  (788.125000, 164.179688)  (1268.125000, 718.945312)  w=480.000000  h=554.765625
#
# [TRT]    ------------------------------------------------
# [TRT]    Timing Report /usr/local/bin/networks/SSD-Mobilenet-v2/ssd_mobilenet_v2_coco.uff
# [TRT]    ------------------------------------------------
# [TRT]    Pre-Process   CPU   0.06776ms  CUDA   0.99568ms
# [TRT]    Network       CPU  48.16764ms  CUDA  37.31187ms
# [TRT]    Post-Process  CPU   0.02984ms  CUDA   0.03000ms
# [TRT]    Visualize     CPU   0.15985ms  CUDA   3.80255ms
# [TRT]    Total         CPU  48.42509ms  CUDA  42.14010ms
# [TRT]    ------------------------------------------------
#
# 1 objects detected
# detected obj 0  class #1 (person)  confidence=0.856934
# bounding box 0  (847.500000, 156.445312)  (1268.750000, 719.000000)  w=421.250000  h=562.554688
#
# [TRT]    ------------------------------------------------
# [TRT]    Timing Report /usr/local/bin/networks/SSD-Mobilenet-v2/ssd_mobilenet_v2_coco.uff
# [TRT]    ------------------------------------------------
# [TRT]    Pre-Process   CPU   0.09511ms  CUDA   1.00417ms
# [TRT]    Network       CPU  48.40019ms  CUDA  37.86344ms
# [TRT]    Post-Process  CPU   0.03031ms  CUDA   0.02958ms
# [TRT]    Visualize     CPU   0.15766ms  CUDA   3.45974ms
# [TRT]    Total         CPU  48.68327ms  CUDA  42.35693ms
# [TRT]    ------------------------------------------------
#
# 1 objects detected
# detected obj 0  class #1 (person)  confidence=0.841309
# bounding box 0  (840.000000, 154.687500)  (1266.250000, 719.000000)  w=426.250000  h=564.312500
#
# [TRT]    ------------------------------------------------
# [TRT]    Timing Report /usr/local/bin/networks/SSD-Mobilenet-v2/ssd_mobilenet_v2_coco.uff
# [TRT]    ------------------------------------------------
# [TRT]    Pre-Process   CPU   0.06641ms  CUDA   1.04349ms
# [TRT]    Network       CPU  48.20482ms  CUDA  37.25375ms
# [TRT]    Post-Process  CPU   0.02651ms  CUDA   0.02672ms
# [TRT]    Visualize     CPU   0.15344ms  CUDA   3.14630ms
# [TRT]    Total         CPU  48.45118ms  CUDA  41.47026ms
# [TRT]    ------------------------------------------------
#
# 1 objects detected
# detected obj 0  class #1 (person)  confidence=0.839355
# bounding box 0  (844.375000, 160.488281)  (1268.125000, 719.000000)  w=423.750000  h=558.511719
#
# [TRT]    ------------------------------------------------
# [TRT]    Timing Report /usr/local/bin/networks/SSD-Mobilenet-v2/ssd_mobilenet_v2_coco.uff
# [TRT]    ------------------------------------------------
# [TRT]    Pre-Process   CPU   0.14047ms  CUDA   1.01432ms
# [TRT]    Network       CPU  48.11686ms  CUDA  37.15828ms
# [TRT]    Post-Process  CPU   0.02958ms  CUDA   0.02948ms
# [TRT]    Visualize     CPU   0.15094ms  CUDA   3.33979ms
# [TRT]    Total         CPU  48.43785ms  CUDA  41.54187ms
# [TRT]    ------------------------------------------------
#
# 1 objects detected
# detected obj 0  class #1 (person)  confidence=0.790527
# bounding box 0  (796.875000, 148.886719)  (1268.125000, 719.000000)  w=471.250000  h=570.113281
#
# [TRT]    ------------------------------------------------
# [TRT]    Timing Report /usr/local/bin/networks/SSD-Mobilenet-v2/ssd_mobilenet_v2_coco.uff
# [TRT]    ------------------------------------------------
# [TRT]    Pre-Process   CPU   0.08505ms  CUDA   1.05333ms
# [TRT]    Network       CPU  48.15597ms  CUDA  37.19062ms
# [TRT]    Post-Process  CPU   0.04302ms  CUDA   0.04354ms
# [TRT]    Visualize     CPU   0.19183ms  CUDA   3.86161ms
# [TRT]    Total         CPU  48.47587ms  CUDA  42.14911ms
# [TRT]    ------------------------------------------------
#
# 1 objects detected
# detected obj 0  class #1 (person)  confidence=0.872070
# bounding box 0  (801.250000, 154.511719)  (1276.250000, 714.375000)  w=475.000000  h=559.863281
#
# [TRT]    ------------------------------------------------
# [TRT]    Timing Report /usr/local/bin/networks/SSD-Mobilenet-v2/ssd_mobilenet_v2_coco.uff
# [TRT]    ------------------------------------------------
# [TRT]    Pre-Process   CPU   0.08016ms  CUDA   1.03010ms
# [TRT]    Network       CPU  48.15284ms  CUDA  37.37047ms
# [TRT]    Post-Process  CPU   0.03057ms  CUDA   0.03078ms
# [TRT]    Visualize     CPU   0.17068ms  CUDA   4.06349ms
# [TRT]    Total         CPU  48.43426ms  CUDA  42.49484ms
# [TRT]    ------------------------------------------------
#
# 1 objects detected
# detected obj 0  class #1 (person)  confidence=0.830078
# bounding box 0  (784.375000, 166.816406)  (1274.375000, 719.000000)  w=490.000000  h=552.183594
#
# [TRT]    ------------------------------------------------
# [TRT]    Timing Report /usr/local/bin/networks/SSD-Mobilenet-v2/ssd_mobilenet_v2_coco.uff
# [TRT]    ------------------------------------------------
# [TRT]    Pre-Process   CPU   0.11542ms  CUDA   1.00896ms
# [TRT]    Network       CPU  48.13446ms  CUDA  37.37620ms
# [TRT]    Post-Process  CPU   0.02745ms  CUDA   0.02776ms
# [TRT]    Visualize     CPU   0.15448ms  CUDA   3.53161ms
# [TRT]    Total         CPU  48.43181ms  CUDA  41.94453ms
# [TRT]    ------------------------------------------------
#
# 1 objects detected
# detected obj 0  class #1 (person)  confidence=0.852539
# bounding box 0  (843.750000, 155.214844)  (1263.750000, 719.000000)  w=420.000000  h=563.785156
#
# [TRT]    ------------------------------------------------
# [TRT]    Timing Report /usr/local/bin/networks/SSD-Mobilenet-v2/ssd_mobilenet_v2_coco.uff
# [TRT]    ------------------------------------------------
# [TRT]    Pre-Process   CPU   0.06177ms  CUDA   1.04641ms
# [TRT]    Network       CPU  48.20930ms  CUDA  37.08620ms
# [TRT]    Post-Process  CPU   0.03537ms  CUDA   0.03516ms
# [TRT]    Visualize     CPU   0.19818ms  CUDA   3.35099ms
# [TRT]    Total         CPU  48.50462ms  CUDA  41.51875ms
# [TRT]    ------------------------------------------------
#
# 1 objects detected
# detected obj 0  class #1 (person)  confidence=0.824219
# bounding box 0  (791.875000, 155.917969)  (1268.125000, 719.000000)  w=476.250000  h=563.082031
#
# [TRT]    ------------------------------------------------
# [TRT]    Timing Report /usr/local/bin/networks/SSD-Mobilenet-v2/ssd_mobilenet_v2_coco.uff
# [TRT]    ------------------------------------------------
# [TRT]    Pre-Process   CPU   0.07151ms  CUDA   1.02510ms
# [TRT]    Network       CPU  48.16758ms  CUDA  37.14141ms
# [TRT]    Post-Process  CPU   0.02979ms  CUDA   0.03010ms
# [TRT]    Visualize     CPU   0.15995ms  CUDA   3.83031ms
# [TRT]    Total         CPU  48.42884ms  CUDA  42.02693ms
# [TRT]    ------------------------------------------------
#
# 1 objects detected
# detected obj 0  class #1 (person)  confidence=0.854004
# bounding box 0  (801.250000, 160.664062)  (1271.250000, 718.945312)  w=470.000000  h=558.281250
#
# [TRT]    ------------------------------------------------
# [TRT]    Timing Report /usr/local/bin/networks/SSD-Mobilenet-v2/ssd_mobilenet_v2_coco.uff
# [TRT]    ------------------------------------------------
# [TRT]    Pre-Process   CPU   0.13427ms  CUDA   1.02807ms
# [TRT]    Network       CPU  48.16092ms  CUDA  37.40094ms
# [TRT]    Post-Process  CPU   0.03417ms  CUDA   0.03417ms
# [TRT]    Visualize     CPU   0.17745ms  CUDA   3.79286ms
# [TRT]    Total         CPU  48.50681ms  CUDA  42.25604ms
# [TRT]    ------------------------------------------------
#
# 1 objects detected
# detected obj 0  class #1 (person)  confidence=0.826172
# bounding box 0  (793.750000, 157.148438)  (1271.250000, 719.000000)  w=477.500000  h=561.851562
#
# [TRT]    ------------------------------------------------
# [TRT]    Timing Report /usr/local/bin/networks/SSD-Mobilenet-v2/ssd_mobilenet_v2_coco.uff
# [TRT]    ------------------------------------------------
# [TRT]    Pre-Process   CPU   0.07703ms  CUDA   0.98677ms
# [TRT]    Network       CPU  49.19787ms  CUDA  38.80281ms
# [TRT]    Post-Process  CPU   0.03016ms  CUDA   0.03036ms
# [TRT]    Visualize     CPU   0.16193ms  CUDA   3.88240ms
# [TRT]    Total         CPU  49.46699ms  CUDA  43.70234ms
# [TRT]    ------------------------------------------------
#
# 1 objects detected
# detected obj 0  class #1 (person)  confidence=0.832520
# bounding box 0  (793.750000, 153.984375)  (1275.000000, 717.890625)  w=481.250000  h=563.906250
#
# [TRT]    ------------------------------------------------
# [TRT]    Timing Report /usr/local/bin/networks/SSD-Mobilenet-v2/ssd_mobilenet_v2_coco.uff
# [TRT]    ------------------------------------------------
# [TRT]    Pre-Process   CPU   0.06219ms  CUDA   0.97839ms
# [TRT]    Network       CPU  48.27795ms  CUDA  37.79911ms
# [TRT]    Post-Process  CPU   0.03094ms  CUDA   0.03109ms
# [TRT]    Visualize     CPU   0.16610ms  CUDA   3.84943ms
# [TRT]    Total         CPU  48.53717ms  CUDA  42.65802ms
# [TRT]    ------------------------------------------------
#
# 1 objects detected
# detected obj 0  class #1 (person)  confidence=0.755371
# bounding box 0  (800.000000, 151.699219)  (1272.500000, 717.890625)  w=472.500000  h=566.191406
#
# [TRT]    ------------------------------------------------
# [TRT]    Timing Report /usr/local/bin/networks/SSD-Mobilenet-v2/ssd_mobilenet_v2_coco.uff
# [TRT]    ------------------------------------------------
# [TRT]    Pre-Process   CPU   0.08854ms  CUDA   1.04109ms
# [TRT]    Network       CPU  48.15748ms  CUDA  37.44213ms
# [TRT]    Post-Process  CPU   0.03141ms  CUDA   0.03125ms
# [TRT]    Visualize     CPU   0.15349ms  CUDA   3.36625ms
# [TRT]    Total         CPU  48.43092ms  CUDA  41.88073ms
# [TRT]    ------------------------------------------------
#
# 1 objects detected
# detected obj 0  class #1 (person)  confidence=0.791504
# bounding box 0  (813.750000, 155.566406)  (1271.250000, 715.781250)  w=457.500000  h=560.214844
#
# [TRT]    ------------------------------------------------
# [TRT]    Timing Report /usr/local/bin/networks/SSD-Mobilenet-v2/ssd_mobilenet_v2_coco.uff
# [TRT]    ------------------------------------------------
# [TRT]    Pre-Process   CPU   0.08958ms  CUDA   1.02078ms
# [TRT]    Network       CPU  47.99263ms  CUDA  37.48380ms
# [TRT]    Post-Process  CPU   0.03115ms  CUDA   0.03104ms
# [TRT]    Visualize     CPU   0.18131ms  CUDA   3.86057ms
# [TRT]    Total         CPU  48.29467ms  CUDA  42.39620ms
# [TRT]    ------------------------------------------------
#
# 1 objects detected
# detected obj 0  class #1 (person)  confidence=0.836914
# bounding box 0  (792.500000, 154.687500)  (1275.000000, 719.000000)  w=482.500000  h=564.312500
#
# [TRT]    ------------------------------------------------
# [TRT]    Timing Report /usr/local/bin/networks/SSD-Mobilenet-v2/ssd_mobilenet_v2_coco.uff
# [TRT]    ------------------------------------------------
# [TRT]    Pre-Process   CPU   0.09500ms  CUDA   1.04938ms
# [TRT]    Network       CPU  47.97721ms  CUDA  37.37557ms
# [TRT]    Post-Process  CPU   0.02740ms  CUDA   0.02750ms
# [TRT]    Visualize     CPU   0.15735ms  CUDA   3.62766ms
# [TRT]    Total         CPU  48.25696ms  CUDA  42.08010ms
# [TRT]    ------------------------------------------------
#
# 1 objects detected
# detected obj 0  class #1 (person)  confidence=0.797852
# bounding box 0  (797.500000, 156.972656)  (1268.750000, 719.000000)  w=471.250000  h=562.027344
#
# [TRT]    ------------------------------------------------
# [TRT]    Timing Report /usr/local/bin/networks/SSD-Mobilenet-v2/ssd_mobilenet_v2_coco.uff
# [TRT]    ------------------------------------------------
# [TRT]    Pre-Process   CPU   0.10631ms  CUDA   1.05625ms
# [TRT]    Network       CPU  47.99821ms  CUDA  37.29458ms
# [TRT]    Post-Process  CPU   0.03031ms  CUDA   0.02995ms
# [TRT]    Visualize     CPU   0.15917ms  CUDA   3.42188ms
# [TRT]    Total         CPU  48.29399ms  CUDA  41.80266ms
# [TRT]    ------------------------------------------------
#
# 1 objects detected
# detected obj 0  class #1 (person)  confidence=0.773438
# bounding box 0  (797.500000, 150.820312)  (1273.750000, 718.945312)  w=476.250000  h=568.125000
#
# [TRT]    ------------------------------------------------
# [TRT]    Timing Report /usr/local/bin/networks/SSD-Mobilenet-v2/ssd_mobilenet_v2_coco.uff
# [TRT]    ------------------------------------------------
# [TRT]    Pre-Process   CPU   0.09412ms  CUDA   1.20203ms
# [TRT]    Network       CPU  47.98149ms  CUDA  37.04531ms
# [TRT]    Post-Process  CPU   0.04714ms  CUDA   0.04672ms
# [TRT]    Visualize     CPU   0.22928ms  CUDA   3.61432ms
# [TRT]    Total         CPU  48.35201ms  CUDA  41.90838ms
# [TRT]    ------------------------------------------------
#
# 1 objects detected
# detected obj 0  class #1 (person)  confidence=0.727051
# bounding box 0  (817.500000, 148.535156)  (1271.250000, 719.000000)  w=453.750000  h=570.464844
#
# [TRT]    ------------------------------------------------
# [TRT]    Timing Report /usr/local/bin/networks/SSD-Mobilenet-v2/ssd_mobilenet_v2_coco.uff
# [TRT]    ------------------------------------------------
# [TRT]    Pre-Process   CPU   0.06354ms  CUDA   1.06813ms
# [TRT]    Network       CPU  49.65444ms  CUDA  38.97432ms
# [TRT]    Post-Process  CPU   0.03260ms  CUDA   0.03271ms
# [TRT]    Visualize     CPU   0.17339ms  CUDA   3.79036ms
# [TRT]    Total         CPU  49.92397ms  CUDA  43.86552ms
# [TRT]    ------------------------------------------------
#
# 1 objects detected
# detected obj 0  class #1 (person)  confidence=0.772461
# bounding box 0  (807.500000, 148.886719)  (1272.500000, 719.296875)  w=465.000000  h=570.410156
#
# [TRT]    ------------------------------------------------
# [TRT]    Timing Report /usr/local/bin/networks/SSD-Mobilenet-v2/ssd_mobilenet_v2_coco.uff
# [TRT]    ------------------------------------------------
# [TRT]    Pre-Process   CPU   0.11422ms  CUDA   1.02859ms
# [TRT]    Network       CPU  48.03310ms  CUDA  38.08734ms
# [TRT]    Post-Process  CPU   0.07427ms  CUDA   0.06802ms
# [TRT]    Visualize     CPU   0.32042ms  CUDA   3.98901ms
# [TRT]    Total         CPU  48.54202ms  CUDA  43.17297ms
# [TRT]    ------------------------------------------------
#
# 1 objects detected
# detected obj 0  class #1 (person)  confidence=0.805664
# bounding box 0  (790.625000, 155.214844)  (1274.375000, 719.000000)  w=483.750000  h=563.785156
#
# [TRT]    ------------------------------------------------
# [TRT]    Timing Report /usr/local/bin/networks/SSD-Mobilenet-v2/ssd_mobilenet_v2_coco.uff
# [TRT]    ------------------------------------------------
# [TRT]    Pre-Process   CPU   0.17047ms  CUDA   0.99120ms
# [TRT]    Network       CPU  47.95914ms  CUDA  37.95161ms
# [TRT]    Post-Process  CPU   0.03083ms  CUDA   0.03083ms
# [TRT]    Visualize     CPU   0.17657ms  CUDA   3.78620ms
# [TRT]    Total         CPU  48.33702ms  CUDA  42.75985ms
# [TRT]    ------------------------------------------------
#
# 1 objects detected
# detected obj 0  class #1 (person)  confidence=0.805176
# bounding box 0  (807.500000, 150.820312)  (1277.500000, 714.726562)  w=470.000000  h=563.906250
#
# [TRT]    ------------------------------------------------
# [TRT]    Timing Report /usr/local/bin/networks/SSD-Mobilenet-v2/ssd_mobilenet_v2_coco.uff
# [TRT]    ------------------------------------------------
# [TRT]    Pre-Process   CPU   0.08401ms  CUDA   1.03922ms
# [TRT]    Network       CPU  47.98373ms  CUDA  37.06224ms
# [TRT]    Post-Process  CPU   0.02755ms  CUDA   0.02750ms
# [TRT]    Visualize     CPU   0.14839ms  CUDA   3.78901ms
# [TRT]    Total         CPU  48.24368ms  CUDA  41.91797ms
# [TRT]    ------------------------------------------------
#
# 1 objects detected
# detected obj 0  class #1 (person)  confidence=0.822266
# bounding box 0  (793.125000, 160.312500)  (1271.875000, 719.296875)  w=478.750000  h=558.984375
#
# [TRT]    ------------------------------------------------
# [TRT]    Timing Report /usr/local/bin/networks/SSD-Mobilenet-v2/ssd_mobilenet_v2_coco.uff
# [TRT]    ------------------------------------------------
# [TRT]    Pre-Process   CPU   0.08458ms  CUDA   1.09328ms
# [TRT]    Network       CPU  47.99664ms  CUDA  37.10094ms
# [TRT]    Post-Process  CPU   0.03156ms  CUDA   0.03125ms
# [TRT]    Visualize     CPU   0.17922ms  CUDA   4.06443ms
# [TRT]    Total         CPU  48.29201ms  CUDA  42.28989ms
# [TRT]    ------------------------------------------------
#
# 1 objects detected
# detected obj 0  class #1 (person)  confidence=0.769043
# bounding box 0  (795.625000, 147.128906)  (1273.125000, 717.890625)  w=477.500000  h=570.761719
#
# [TRT]    ------------------------------------------------
# [TRT]    Timing Report /usr/local/bin/networks/SSD-Mobilenet-v2/ssd_mobilenet_v2_coco.uff
# [TRT]    ------------------------------------------------
# [TRT]    Pre-Process   CPU   0.08474ms  CUDA   1.04802ms
# [TRT]    Network       CPU  48.08399ms  CUDA  37.59599ms
# [TRT]    Post-Process  CPU   0.03880ms  CUDA   0.03849ms
# [TRT]    Visualize     CPU   0.19084ms  CUDA   3.72417ms
# [TRT]    Total         CPU  48.39837ms  CUDA  42.40667ms
# [TRT]    ------------------------------------------------
#
# 1 objects detected
# detected obj 0  class #1 (person)  confidence=0.801270
# bounding box 0  (818.750000, 157.148438)  (1271.250000, 718.242188)  w=452.500000  h=561.093750
#
# [TRT]    ------------------------------------------------
# [TRT]    Timing Report /usr/local/bin/networks/SSD-Mobilenet-v2/ssd_mobilenet_v2_coco.uff
# [TRT]    ------------------------------------------------
# [TRT]    Pre-Process   CPU   0.07500ms  CUDA   0.99214ms
# [TRT]    Network       CPU  48.03445ms  CUDA  37.45776ms
# [TRT]    Post-Process  CPU   0.04234ms  CUDA   0.04359ms
# [TRT]    Visualize     CPU   0.19052ms  CUDA   3.47021ms
# [TRT]    Total         CPU  48.34232ms  CUDA  41.96370ms
# [TRT]    ------------------------------------------------
#
# 1 objects detected
# detected obj 0  class #1 (person)  confidence=0.824219
# bounding box 0  (796.250000, 159.433594)  (1276.250000, 719.296875)  w=480.000000  h=559.863281
#
# [TRT]    ------------------------------------------------
# [TRT]    Timing Report /usr/local/bin/networks/SSD-Mobilenet-v2/ssd_mobilenet_v2_coco.uff
# [TRT]    ------------------------------------------------
# [TRT]    Pre-Process   CPU   0.08209ms  CUDA   1.02271ms
# [TRT]    Network       CPU  48.03368ms  CUDA  37.40464ms
# [TRT]    Post-Process  CPU   0.02953ms  CUDA   0.02943ms
# [TRT]    Visualize     CPU   0.15271ms  CUDA   3.89234ms
# [TRT]    Total         CPU  48.29800ms  CUDA  42.34912ms
# [TRT]    ------------------------------------------------
#
# 1 objects detected
# detected obj 0  class #1 (person)  confidence=0.790527
# bounding box 0  (800.000000, 156.621094)  (1271.250000, 719.296875)  w=471.250000  h=562.675781
#
# [TRT]    ------------------------------------------------
# [TRT]    Timing Report /usr/local/bin/networks/SSD-Mobilenet-v2/ssd_mobilenet_v2_coco.uff
# [TRT]    ------------------------------------------------
# [TRT]    Pre-Process   CPU   0.09667ms  CUDA   1.13818ms
# [TRT]    Network       CPU  48.06347ms  CUDA  37.22250ms
# [TRT]    Post-Process  CPU   0.03156ms  CUDA   0.03156ms
# [TRT]    Visualize     CPU   0.16016ms  CUDA   3.34135ms
# [TRT]    Total         CPU  48.35186ms  CUDA  41.73359ms
# [TRT]    ------------------------------------------------
#
# 1 objects detected
# detected obj 0  class #1 (person)  confidence=0.842773
# bounding box 0  (802.500000, 153.632812)  (1272.500000, 718.242188)  w=470.000000  h=564.609375
#
# [TRT]    ------------------------------------------------
# [TRT]    Timing Report /usr/local/bin/networks/SSD-Mobilenet-v2/ssd_mobilenet_v2_coco.uff
# [TRT]    ------------------------------------------------
# [TRT]    Pre-Process   CPU   0.08781ms  CUDA   1.07516ms
# [TRT]    Network       CPU  48.03962ms  CUDA  37.17479ms
# [TRT]    Post-Process  CPU   0.03115ms  CUDA   0.03151ms
# [TRT]    Visualize     CPU   0.22204ms  CUDA   3.79573ms
# [TRT]    Total         CPU  48.38061ms  CUDA  42.07719ms
# [TRT]    ------------------------------------------------
#
# 1 objects detected
# detected obj 0  class #1 (person)  confidence=0.831055
# bounding box 0  (811.875000, 159.433594)  (1270.625000, 717.187500)  w=458.750000  h=557.753906
#
# [TRT]    ------------------------------------------------
# [TRT]    Timing Report /usr/local/bin/networks/SSD-Mobilenet-v2/ssd_mobilenet_v2_coco.uff
# [TRT]    ------------------------------------------------
# [TRT]    Pre-Process   CPU   0.09917ms  CUDA   1.03115ms
# [TRT]    Network       CPU  47.96883ms  CUDA  37.08719ms
# [TRT]    Post-Process  CPU   0.03078ms  CUDA   0.03083ms
# [TRT]    Visualize     CPU   0.15511ms  CUDA   3.78583ms
# [TRT]    Total         CPU  48.25388ms  CUDA  41.93500ms
# [TRT]    ------------------------------------------------
#
# 1 objects detected
# detected obj 0  class #1 (person)  confidence=0.743164
# bounding box 0  (802.500000, 154.511719)  (1275.000000, 718.593750)  w=472.500000  h=564.082031
#
# [TRT]    ------------------------------------------------
# [TRT]    Timing Report /usr/local/bin/networks/SSD-Mobilenet-v2/ssd_mobilenet_v2_coco.uff
# [TRT]    ------------------------------------------------
# [TRT]    Pre-Process   CPU   0.09396ms  CUDA   1.03057ms
# [TRT]    Network       CPU  47.95055ms  CUDA  37.13802ms
# [TRT]    Post-Process  CPU   0.03250ms  CUDA   0.03250ms
# [TRT]    Visualize     CPU   0.16407ms  CUDA   3.70859ms
# [TRT]    Total         CPU  48.24107ms  CUDA  41.90969ms
# [TRT]    ------------------------------------------------
#
# 1 objects detected
# detected obj 0  class #1 (person)  confidence=0.778320
# bounding box 0  (828.750000, 166.992188)  (1271.250000, 714.023438)  w=442.500000  h=547.031250
#
# [TRT]    ------------------------------------------------
# [TRT]    Timing Report /usr/local/bin/networks/SSD-Mobilenet-v2/ssd_mobilenet_v2_coco.uff
# [TRT]    ------------------------------------------------
# [TRT]    Pre-Process   CPU   0.08599ms  CUDA   1.01958ms
# [TRT]    Network       CPU  47.99659ms  CUDA  37.35510ms
# [TRT]    Post-Process  CPU   0.03151ms  CUDA   0.03208ms
# [TRT]    Visualize     CPU   0.18240ms  CUDA   3.69724ms
# [TRT]    Total         CPU  48.29649ms  CUDA  42.10401ms
# [TRT]    ------------------------------------------------
#
# 1 objects detected
# detected obj 0  class #1 (person)  confidence=0.873535
# bounding box 0  (852.500000, 159.609375)  (1268.750000, 718.593750)  w=416.250000  h=558.984375
#
# [TRT]    ------------------------------------------------
# [TRT]    Timing Report /usr/local/bin/networks/SSD-Mobilenet-v2/ssd_mobilenet_v2_coco.uff
# [TRT]    ------------------------------------------------
# [TRT]    Pre-Process   CPU   0.14281ms  CUDA   1.03927ms
# [TRT]    Network       CPU  48.01451ms  CUDA  37.48115ms
# [TRT]    Post-Process  CPU   0.03557ms  CUDA   0.03573ms
# [TRT]    Visualize     CPU   0.17771ms  CUDA   3.52141ms
# [TRT]    Total         CPU  48.37061ms  CUDA  42.07755ms
# [TRT]    ------------------------------------------------
#
# 1 objects detected
# detected obj 0  class #1 (person)  confidence=0.858887
# bounding box 0  (847.500000, 159.609375)  (1267.500000, 719.000000)  w=420.000000  h=559.390625
#
# [TRT]    ------------------------------------------------
# [TRT]    Timing Report /usr/local/bin/networks/SSD-Mobilenet-v2/ssd_mobilenet_v2_coco.uff
# [TRT]    ------------------------------------------------
# [TRT]    Pre-Process   CPU   0.08995ms  CUDA   1.02844ms
# [TRT]    Network       CPU  48.66671ms  CUDA  37.15609ms
# [TRT]    Post-Process  CPU   0.05052ms  CUDA   0.05057ms
# [TRT]    Visualize     CPU   0.20579ms  CUDA   3.28802ms
# [TRT]    Total         CPU  49.01297ms  CUDA  41.52312ms
# [TRT]    ------------------------------------------------
#
# 1 objects detected
# detected obj 0  class #1 (person)  confidence=0.774414
# bounding box 0  (806.250000, 144.492188)  (1276.250000, 718.945312)  w=470.000000  h=574.453125
#
# [TRT]    ------------------------------------------------
# [TRT]    Timing Report /usr/local/bin/networks/SSD-Mobilenet-v2/ssd_mobilenet_v2_coco.uff
# [TRT]    ------------------------------------------------
# [TRT]    Pre-Process   CPU   0.09344ms  CUDA   1.06896ms
# [TRT]    Network       CPU  47.98701ms  CUDA  37.14266ms
# [TRT]    Post-Process  CPU   0.03099ms  CUDA   0.03130ms
# [TRT]    Visualize     CPU   0.15521ms  CUDA   3.79604ms
# [TRT]    Total         CPU  48.26665ms  CUDA  42.03896ms
# [TRT]    ------------------------------------------------
#
# 1 objects detected
# detected obj 0  class #1 (person)  confidence=0.869629
# bounding box 0  (835.000000, 153.105469)  (1270.000000, 719.000000)  w=435.000000  h=565.894531
#
# [TRT]    ------------------------------------------------
# [TRT]    Timing Report /usr/local/bin/networks/SSD-Mobilenet-v2/ssd_mobilenet_v2_coco.uff
# [TRT]    ------------------------------------------------
# [TRT]    Pre-Process   CPU   0.08917ms  CUDA   1.01380ms
# [TRT]    Network       CPU  47.98550ms  CUDA  37.59766ms
# [TRT]    Post-Process  CPU   0.02813ms  CUDA   0.02812ms
# [TRT]    Visualize     CPU   0.16131ms  CUDA   3.57891ms
# [TRT]    Total         CPU  48.26410ms  CUDA  42.21849ms
# [TRT]    ------------------------------------------------
#
# 1 objects detected
# detected obj 0  class #1 (person)  confidence=0.828613
# bounding box 0  (805.625000, 152.929688)  (1269.375000, 716.835938)  w=463.750000  h=563.906250
#
# [TRT]    ------------------------------------------------
# [TRT]    Timing Report /usr/local/bin/networks/SSD-Mobilenet-v2/ssd_mobilenet_v2_coco.uff
# [TRT]    ------------------------------------------------
# [TRT]    Pre-Process   CPU   0.08625ms  CUDA   1.03083ms
# [TRT]    Network       CPU  48.00581ms  CUDA  37.79672ms
# [TRT]    Post-Process  CPU   0.03620ms  CUDA   0.03609ms
# [TRT]    Visualize     CPU   0.19370ms  CUDA   3.58802ms
# [TRT]    Total         CPU  48.32196ms  CUDA  42.45167ms
# [TRT]    ------------------------------------------------
#
# 1 objects detected
# detected obj 0  class #1 (person)  confidence=0.840820
# bounding box 0  (816.250000, 151.699219)  (1273.750000, 716.484375)  w=457.500000  h=564.785156
#
# [TRT]    ------------------------------------------------
# [TRT]    Timing Report /usr/local/bin/networks/SSD-Mobilenet-v2/ssd_mobilenet_v2_coco.uff
# [TRT]    ------------------------------------------------
# [TRT]    Pre-Process   CPU   0.07906ms  CUDA   0.99037ms
# [TRT]    Network       CPU  47.98852ms  CUDA  37.71766ms
# [TRT]    Post-Process  CPU   0.03234ms  CUDA   0.03260ms
# [TRT]    Visualize     CPU   0.15266ms  CUDA   3.66693ms
# [TRT]    Total         CPU  48.25259ms  CUDA  42.40755ms
# [TRT]    ------------------------------------------------
#
# 1 objects detected
# detected obj 0  class #1 (person)  confidence=0.751953
# bounding box 0  (791.250000, 143.789062)  (1277.500000, 719.000000)  w=486.250000  h=575.210938
#
# [TRT]    ------------------------------------------------
# [TRT]    Timing Report /usr/local/bin/networks/SSD-Mobilenet-v2/ssd_mobilenet_v2_coco.uff
# [TRT]    ------------------------------------------------
# [TRT]    Pre-Process   CPU   0.08219ms  CUDA   1.01677ms
# [TRT]    Network       CPU  47.99826ms  CUDA  37.38609ms
# [TRT]    Post-Process  CPU   0.02943ms  CUDA   0.02906ms
# [TRT]    Visualize     CPU   0.15485ms  CUDA   4.02005ms
# [TRT]    Total         CPU  48.26472ms  CUDA  42.45198ms
# [TRT]    ------------------------------------------------
#
# 1 objects detected
# detected obj 0  class #1 (person)  confidence=0.685547
# bounding box 0  (823.125000, 153.984375)  (1274.375000, 716.484375)  w=451.250000  h=562.500000
#
# [TRT]    ------------------------------------------------
# [TRT]    Timing Report /usr/local/bin/networks/SSD-Mobilenet-v2/ssd_mobilenet_v2_coco.uff
# [TRT]    ------------------------------------------------
# [TRT]    Pre-Process   CPU   0.08948ms  CUDA   1.06021ms
# [TRT]    Network       CPU  48.01049ms  CUDA  37.31516ms
# [TRT]    Post-Process  CPU   0.02667ms  CUDA   0.02661ms
# [TRT]    Visualize     CPU   0.15610ms  CUDA   3.64057ms
# ...
# bounding box 0  (587.187500, 0.000000)  (1278.750000, 715.781250)  w=691.562500  h=715.781250
# detected obj 1  class #1 (person)  confidence=0.629883
# bounding box 1  (78.281250, 356.484375)  (474.375000, 707.343750)  w=396.093750  h=350.859375
#
# [TRT]    ------------------------------------------------
# [TRT]    Timing Report /usr/local/bin/networks/SSD-Mobilenet-v2/ssd_mobilenet_v2_coco.uff
# [TRT]    ------------------------------------------------
# [TRT]    Pre-Process   CPU   0.08318ms  CUDA   1.53885ms
# [TRT]    Network       CPU  49.91304ms  CUDA  38.20625ms
# [TRT]    Post-Process  CPU   0.03792ms  CUDA   0.03906ms
# [TRT]    Visualize     CPU   0.18318ms  CUDA   8.33292ms
# [TRT]    Total         CPU  50.21732ms  CUDA  48.11708ms
# [TRT]    ------------------------------------------------
#
# 2 objects detected
# detected obj 0  class #1 (person)  confidence=0.930176
# bounding box 0  (590.937500, 0.000000)  (1277.500000, 718.593750)  w=686.562500  h=718.593750
# detected obj 1  class #1 (person)  confidence=0.723145
# bounding box 1  (44.687500, 351.210938)  (493.437500, 712.617188)  w=448.750000  h=361.406250
#
# [TRT]    ------------------------------------------------
# [TRT]    Timing Report /usr/local/bin/networks/SSD-Mobilenet-v2/ssd_mobilenet_v2_coco.uff
# [TRT]    ------------------------------------------------
# [TRT]    Pre-Process   CPU   0.11995ms  CUDA   1.03109ms
# [TRT]    Network       CPU  48.01617ms  CUDA  37.39812ms
# [TRT]    Post-Process  CPU   0.05703ms  CUDA   0.05427ms
# [TRT]    Visualize     CPU   0.22131ms  CUDA   9.62052ms
# [TRT]    Total         CPU  48.41446ms  CUDA  48.10401ms
# [TRT]    ------------------------------------------------
#
# 2 objects detected
# detected obj 0  class #1 (person)  confidence=0.926758
# bounding box 0  (588.437500, 0.000000)  (1277.500000, 718.593750)  w=689.062500  h=718.593750
# detected obj 1  class #1 (person)  confidence=0.739746
# bounding box 1  (56.562500, 353.320312)  (395.312500, 715.429688)  w=338.750000  h=362.109375
#
# [TRT]    ------------------------------------------------
# [TRT]    Timing Report /usr/local/bin/networks/SSD-Mobilenet-v2/ssd_mobilenet_v2_coco.uff
# [TRT]    ------------------------------------------------
# [TRT]    Pre-Process   CPU   0.11729ms  CUDA   1.05536ms
# [TRT]    Network       CPU  49.69007ms  CUDA  38.30708ms
# [TRT]    Post-Process  CPU   0.06084ms  CUDA   0.05500ms
# [TRT]    Visualize     CPU   0.22006ms  CUDA   8.78687ms
# [TRT]    Total         CPU  50.08826ms  CUDA  48.20432ms
# [TRT]    ------------------------------------------------
#
# 2 objects detected
# detected obj 0  class #1 (person)  confidence=0.926270
# bounding box 0  (584.687500, 0.000000)  (1279.000000, 716.484375)  w=694.312500  h=716.484375
# detected obj 1  class #1 (person)  confidence=0.654785
# bounding box 1  (53.281250, 353.144531)  (386.250000, 712.265625)  w=332.968750  h=359.121094
#
# [TRT]    ------------------------------------------------
# [TRT]    Timing Report /usr/local/bin/networks/SSD-Mobilenet-v2/ssd_mobilenet_v2_coco.uff
# [TRT]    ------------------------------------------------
# [TRT]    Pre-Process   CPU   0.12094ms  CUDA   1.09740ms
# [TRT]    Network       CPU  49.66767ms  CUDA  38.56813ms
# [TRT]    Post-Process  CPU   0.05625ms  CUDA   0.05630ms
# [TRT]    Visualize     CPU   0.22495ms  CUDA   9.58776ms
# [TRT]    Total         CPU  50.06982ms  CUDA  49.30959ms
# [TRT]    ------------------------------------------------
#
# 2 objects detected
# detected obj 0  class #1 (person)  confidence=0.937500
# bounding box 0  (578.437500, 22.148438)  (1279.000000, 702.773438)  w=700.562500  h=680.625000
# detected obj 1  class #1 (person)  confidence=0.687988
# bounding box 1  (60.625000, 360.351562)  (505.625000, 713.320312)  w=445.000000  h=352.968750
#
# [TRT]    ------------------------------------------------
# [TRT]    Timing Report /usr/local/bin/networks/SSD-Mobilenet-v2/ssd_mobilenet_v2_coco.uff
# [TRT]    ------------------------------------------------
# [TRT]    Pre-Process   CPU   0.08839ms  CUDA   1.08083ms
# [TRT]    Network       CPU  49.73788ms  CUDA  38.44708ms
# [TRT]    Post-Process  CPU   0.07245ms  CUDA   0.06120ms
# [TRT]    Visualize     CPU   0.24641ms  CUDA   8.75193ms
# [TRT]    Total         CPU  50.14513ms  CUDA  48.34104ms
# [TRT]    ------------------------------------------------
#
# 2 objects detected
# detected obj 0  class #1 (person)  confidence=0.938965
# bounding box 0  (589.062500, 20.039062)  (1279.000000, 711.210938)  w=689.937500  h=691.171875
# detected obj 1  class #1 (person)  confidence=0.713379
# bounding box 1  (84.218750, 350.859375)  (482.500000, 708.046875)  w=398.281250  h=357.187500
#
# [TRT]    ------------------------------------------------
# [TRT]    Timing Report /usr/local/bin/networks/SSD-Mobilenet-v2/ssd_mobilenet_v2_coco.uff
# [TRT]    ------------------------------------------------
# [TRT]    Pre-Process   CPU   0.19568ms  CUDA   1.09542ms
# [TRT]    Network       CPU  47.93774ms  CUDA  36.96693ms
# [TRT]    Post-Process  CPU   0.05745ms  CUDA   0.05505ms
# [TRT]    Visualize     CPU   0.21287ms  CUDA   8.44490ms
# [TRT]    Total         CPU  48.40374ms  CUDA  46.56229ms
# [TRT]    ------------------------------------------------
#
# 2 objects detected
# detected obj 0  class #1 (person)  confidence=0.957520
# bounding box 0  (585.312500, 23.906250)  (1279.000000, 700.312500)  w=693.687500  h=676.406250
# detected obj 1  class #1 (person)  confidence=0.581543
# bounding box 1  (74.375000, 351.562500)  (484.687500, 707.343750)  w=410.312500  h=355.781250
#
# [TRT]    ------------------------------------------------
# [TRT]    Timing Report /usr/local/bin/networks/SSD-Mobilenet-v2/ssd_mobilenet_v2_coco.uff
# [TRT]    ------------------------------------------------
# [TRT]    Pre-Process   CPU   0.11391ms  CUDA   1.09239ms
# [TRT]    Network       CPU  47.99810ms  CUDA  37.42521ms
# [TRT]    Post-Process  CPU   0.06136ms  CUDA   0.06177ms
# [TRT]    Visualize     CPU   0.33798ms  CUDA   8.95182ms
# [TRT]    Total         CPU  48.51134ms  CUDA  47.53120ms
# [TRT]    ------------------------------------------------
#
# 2 objects detected
# detected obj 0  class #1 (person)  confidence=0.924316
# bounding box 0  (581.562500, 18.984375)  (1279.000000, 701.015625)  w=697.437500  h=682.031250
# detected obj 1  class #1 (person)  confidence=0.716797
# bounding box 1  (37.812500, 348.925781)  (452.500000, 719.000000)  w=414.687500  h=370.074219
#
# [TRT]    ------------------------------------------------
# [TRT]    Timing Report /usr/local/bin/networks/SSD-Mobilenet-v2/ssd_mobilenet_v2_coco.uff
# [TRT]    ------------------------------------------------
# [TRT]    Pre-Process   CPU   0.10964ms  CUDA   1.04625ms
# [TRT]    Network       CPU  48.01389ms  CUDA  37.55437ms
# [TRT]    Post-Process  CPU   0.07615ms  CUDA   0.07578ms
# [TRT]    Visualize     CPU   0.24865ms  CUDA   9.26896ms
# [TRT]    Total         CPU  48.44832ms  CUDA  47.94537ms
# [TRT]    ------------------------------------------------
#
# 2 objects detected
# detected obj 0  class #1 (person)  confidence=0.933105
# bounding box 0  (586.250000, 0.000000)  (1277.500000, 716.835938)  w=691.250000  h=716.835938
# detected obj 1  class #1 (person)  confidence=0.518066
# bounding box 1  (61.562500, 348.750000)  (534.687500, 718.593750)  w=473.125000  h=369.843750
#
# [TRT]    ------------------------------------------------
# [TRT]    Timing Report /usr/local/bin/networks/SSD-Mobilenet-v2/ssd_mobilenet_v2_coco.uff
# [TRT]    ------------------------------------------------
# [TRT]    Pre-Process   CPU   0.11672ms  CUDA   1.04745ms
# [TRT]    Network       CPU  48.10035ms  CUDA  37.66865ms
# [TRT]    Post-Process  CPU   0.04516ms  CUDA   0.04563ms
# [TRT]    Visualize     CPU   0.22907ms  CUDA   9.18214ms
# [TRT]    Total         CPU  48.49129ms  CUDA  47.94386ms
# [TRT]    ------------------------------------------------
#
# 2 objects detected
# detected obj 0  class #1 (person)  confidence=0.927734
# bounding box 0  (583.437500, 0.000000)  (1279.000000, 714.375000)  w=695.562500  h=714.375000
# detected obj 1  class #1 (person)  confidence=0.599121
# bounding box 1  (87.968750, 352.089844)  (486.875000, 706.640625)  w=398.906250  h=354.550781
#
# [TRT]    ------------------------------------------------
# [TRT]    Timing Report /usr/local/bin/networks/SSD-Mobilenet-v2/ssd_mobilenet_v2_coco.uff
# [TRT]    ------------------------------------------------
# [TRT]    Pre-Process   CPU   0.08578ms  CUDA   1.01463ms
# [TRT]    Network       CPU  48.04487ms  CUDA  37.37000ms
# [TRT]    Post-Process  CPU   0.03906ms  CUDA   0.03875ms
# [TRT]    Visualize     CPU   0.33688ms  CUDA   9.61510ms
# [TRT]    Total         CPU  48.50660ms  CUDA  48.03849ms
# [TRT]    ------------------------------------------------
#
# 2 objects detected
# detected obj 0  class #1 (person)  confidence=0.918945
# bounding box 0  (587.500000, 0.000000)  (1279.000000, 715.429688)  w=691.500000  h=715.429688
# detected obj 1  class #1 (person)  confidence=0.563965
# bounding box 1  (78.906250, 352.617188)  (488.750000, 704.882812)  w=409.843750  h=352.265625
#
# [TRT]    ------------------------------------------------
# [TRT]    Timing Report /usr/local/bin/networks/SSD-Mobilenet-v2/ssd_mobilenet_v2_coco.uff
# [TRT]    ------------------------------------------------
# [TRT]    Pre-Process   CPU   0.07203ms  CUDA   1.03641ms
# [TRT]    Network       CPU  48.10758ms  CUDA  37.67802ms
# [TRT]    Post-Process  CPU   0.04464ms  CUDA   0.04448ms
# [TRT]    Visualize     CPU   0.26329ms  CUDA   9.04552ms
# [TRT]    Total         CPU  48.48754ms  CUDA  47.80443ms
# [TRT]    ------------------------------------------------
#
# 2 objects detected
# detected obj 0  class #1 (person)  confidence=0.924316
# bounding box 0  (585.937500, 0.000000)  (1279.000000, 715.078125)  w=693.062500  h=715.078125
# detected obj 1  class #1 (person)  confidence=0.629395
# bounding box 1  (80.000000, 351.562500)  (473.125000, 706.640625)  w=393.125000  h=355.078125
#
# [TRT]    ------------------------------------------------
# [TRT]    Timing Report /usr/local/bin/networks/SSD-Mobilenet-v2/ssd_mobilenet_v2_coco.uff
# [TRT]    ------------------------------------------------
# [TRT]    Pre-Process   CPU   0.08636ms  CUDA   1.02422ms
# [TRT]    Network       CPU  48.04383ms  CUDA  37.51495ms
# [TRT]    Post-Process  CPU   0.03203ms  CUDA   0.03240ms
# [TRT]    Visualize     CPU   0.18167ms  CUDA   9.25917ms
# [TRT]    Total         CPU  48.34389ms  CUDA  47.83073ms
# [TRT]    ------------------------------------------------
#
# 1 objects detected
# detected obj 0  class #1 (person)  confidence=0.911133
# bounding box 0  (581.250000, 0.000000)  (1279.000000, 715.078125)  w=697.750000  h=715.078125
#
# [TRT]    ------------------------------------------------
# [TRT]    Timing Report /usr/local/bin/networks/SSD-Mobilenet-v2/ssd_mobilenet_v2_coco.uff
# [TRT]    ------------------------------------------------
# [TRT]    Pre-Process   CPU   0.08302ms  CUDA   1.02594ms
# [TRT]    Network       CPU  49.70605ms  CUDA  38.94984ms
# [TRT]    Post-Process  CPU   0.03052ms  CUDA   0.03010ms
# [TRT]    Visualize     CPU   0.15193ms  CUDA   6.73844ms
# [TRT]    Total         CPU  49.97153ms  CUDA  46.74433ms
# [TRT]    ------------------------------------------------
#
# 2 objects detected
# detected obj 0  class #1 (person)  confidence=0.931641
# bounding box 0  (585.625000, 0.000000)  (1278.125000, 715.781250)  w=692.500000  h=715.781250
# detected obj 1  class #1 (person)  confidence=0.545898
# bounding box 1  (76.093750, 351.562500)  (486.250000, 705.937500)  w=410.156250  h=354.375000
#
# [TRT]    ------------------------------------------------
# [TRT]    Timing Report /usr/local/bin/networks/SSD-Mobilenet-v2/ssd_mobilenet_v2_coco.uff
# [TRT]    ------------------------------------------------
# [TRT]    Pre-Process   CPU   0.08078ms  CUDA   1.00646ms
# [TRT]    Network       CPU  48.04998ms  CUDA  37.31266ms
# [TRT]    Post-Process  CPU   0.03453ms  CUDA   0.03474ms
# [TRT]    Visualize     CPU   0.18553ms  CUDA   9.06906ms
# [TRT]    Total         CPU  48.35082ms  CUDA  47.42292ms
# [TRT]    ------------------------------------------------
#
# 1 objects detected
# detected obj 0  class #1 (person)  confidence=0.947266
# bounding box 0  (581.562500, 0.000000)  (1278.750000, 713.671875)  w=697.187500  h=713.671875
#
# [TRT]    ------------------------------------------------
# [TRT]    Timing Report /usr/local/bin/networks/SSD-Mobilenet-v2/ssd_mobilenet_v2_coco.uff
# [TRT]    ------------------------------------------------
# [TRT]    Pre-Process   CPU   0.08339ms  CUDA   1.00052ms
# [TRT]    Network       CPU  48.03164ms  CUDA  37.52505ms
# [TRT]    Post-Process  CPU   0.03156ms  CUDA   0.03161ms
# [TRT]    Visualize     CPU   0.15703ms  CUDA   6.56516ms
# [TRT]    Total         CPU  48.30363ms  CUDA  45.12234ms
# [TRT]    ------------------------------------------------
#
# 2 objects detected
# detected obj 0  class #1 (person)  confidence=0.941895
# bounding box 0  (587.187500, 24.960938)  (1279.000000, 697.851562)  w=691.812500  h=672.890625
# detected obj 1  class #1 (person)  confidence=0.759277
# bounding box 1  (67.812500, 349.804688)  (485.312500, 711.210938)  w=417.500000  h=361.406250
#
# [TRT]    ------------------------------------------------
# [TRT]    Timing Report /usr/local/bin/networks/SSD-Mobilenet-v2/ssd_mobilenet_v2_coco.uff
# [TRT]    ------------------------------------------------
# [TRT]    Pre-Process   CPU   0.08630ms  CUDA   1.03458ms
# [TRT]    Network       CPU  48.00128ms  CUDA  37.04792ms
# [TRT]    Post-Process  CPU   0.03584ms  CUDA   0.03583ms
# [TRT]    Visualize     CPU   0.23891ms  CUDA   9.11406ms
# [TRT]    Total         CPU  48.36233ms  CUDA  47.23240ms
# [TRT]    ------------------------------------------------
#
# 1 objects detected
# detected obj 0  class #1 (person)  confidence=0.933105
# bounding box 0  (584.062500, 0.000000)  (1279.000000, 714.023438)  w=694.937500  h=714.023438
#
# [TRT]    ------------------------------------------------
# [TRT]    Timing Report /usr/local/bin/networks/SSD-Mobilenet-v2/ssd_mobilenet_v2_coco.uff
# [TRT]    ------------------------------------------------
# [TRT]    Pre-Process   CPU   0.08766ms  CUDA   1.16823ms
# [TRT]    Network       CPU  49.72663ms  CUDA  38.11396ms
# [TRT]    Post-Process  CPU   0.03078ms  CUDA   0.03036ms
# [TRT]    Visualize     CPU   0.15844ms  CUDA   6.23875ms
# [TRT]    Total         CPU  50.00351ms  CUDA  45.55130ms
# [TRT]    ------------------------------------------------
#
# 1 objects detected
# detected obj 0  class #1 (person)  confidence=0.935059
# bounding box 0  (594.687500, 16.523438)  (1279.000000, 708.398438)  w=684.312500  h=691.875000
#
# [TRT]    ------------------------------------------------
# [TRT]    Timing Report /usr/local/bin/networks/SSD-Mobilenet-v2/ssd_mobilenet_v2_coco.uff
# [TRT]    ------------------------------------------------
# [TRT]    Pre-Process   CPU   0.10906ms  CUDA   1.08552ms
# [TRT]    Network       CPU  48.67161ms  CUDA  37.31193ms
# [TRT]    Post-Process  CPU   0.20266ms  CUDA   0.24250ms
# [TRT]    Visualize     CPU   0.35600ms  CUDA   7.10234ms
# [TRT]    Total         CPU  49.33933ms  CUDA  45.74229ms
# [TRT]    ------------------------------------------------
#
# ^C
# received SIGINT
# 2 objects detected
# detected obj 0  class #1 (person)  confidence=0.926270
# bounding box 0  (586.562500, 0.000000)  (1277.500000, 719.000000)  w=690.937500  h=719.000000
# detected obj 1  class #1 (person)  confidence=0.555176
# bounding box 1  (75.625000, 348.750000)  (497.187500, 708.046875)  w=421.562500  h=359.296875
#
# [TRT]    ------------------------------------------------
# [TRT]    Timing Report /usr/local/bin/networks/SSD-Mobilenet-v2/ssd_mobilenet_v2_coco.uff
# [TRT]    ------------------------------------------------
# [TRT]    Pre-Process   CPU   0.08938ms  CUDA   1.02463ms
# [TRT]    Network       CPU  48.03441ms  CUDA  37.80104ms
# [TRT]    Post-Process  CPU   0.03964ms  CUDA   0.04109ms
# [TRT]    Visualize     CPU   0.21235ms  CUDA   9.57719ms
# [TRT]    Total         CPU  48.37577ms  CUDA  48.44396ms
# [TRT]    ------------------------------------------------
#
# detectnet:  shutting down...
# [gstreamer] gstCamera -- stopping pipeline, transitioning to GST_STATE_NULL

# %%
# !python3 my-detection.py
# Out:
# jetson.inference -- detectNet loading build-in network 'ssd-mobilenet-v2'
#
# detectNet -- loading detection network model from:
#           -- model        networks/SSD-Mobilenet-v2/ssd_mobilenet_v2_coco.uff
#           -- input_blob   'Input'
#           -- output_blob  'NMS'
#           -- output_count 'NMS_1'
#           -- class_labels networks/SSD-Mobilenet-v2/ssd_coco_labels.txt
#           -- threshold    0.500000
#           -- batch_size   1
#
# [TRT]    TensorRT version 8.0.1
# [TRT]    loading NVIDIA plugins...
# [TRT]    Registered plugin creator - ::GridAnchor_TRT version 1
# [TRT]    Registered plugin creator - ::GridAnchorRect_TRT version 1
# [TRT]    Registered plugin creator - ::NMS_TRT version 1
# [TRT]    Registered plugin creator - ::Reorg_TRT version 1
# [TRT]    Registered plugin creator - ::Region_TRT version 1
# [TRT]    Registered plugin creator - ::Clip_TRT version 1
# [TRT]    Registered plugin creator - ::LReLU_TRT version 1
# [TRT]    Registered plugin creator - ::PriorBox_TRT version 1
# [TRT]    Registered plugin creator - ::Normalize_TRT version 1
# [TRT]    Registered plugin creator - ::ScatterND version 1
# [TRT]    Registered plugin creator - ::RPROI_TRT version 1
# [TRT]    Registered plugin creator - ::BatchedNMS_TRT version 1
# [TRT]    Registered plugin creator - ::BatchedNMSDynamic_TRT version 1
# [TRT]    Could not register plugin creator -  ::FlattenConcat_TRT version 1
# [TRT]    Registered plugin creator - ::CropAndResize version 1
# [TRT]    Registered plugin creator - ::DetectionLayer_TRT version 1
# [TRT]    Registered plugin creator - ::EfficientNMS_ONNX_TRT version 1
# [TRT]    Registered plugin creator - ::EfficientNMS_TRT version 1
# [TRT]    Registered plugin creator - ::Proposal version 1
# [TRT]    Registered plugin creator - ::ProposalLayer_TRT version 1
# [TRT]    Registered plugin creator - ::PyramidROIAlign_TRT version 1
# [TRT]    Registered plugin creator - ::ResizeNearest_TRT version 1
# [TRT]    Registered plugin creator - ::Split version 1
# [TRT]    Registered plugin creator - ::SpecialSlice_TRT version 1
# [TRT]    Registered plugin creator - ::InstanceNormalization_TRT version 1
# [TRT]    detected model format - UFF  (extension '.uff')
# [TRT]    desired precision specified for GPU: FASTEST
# [TRT]    requested fasted precision for device GPU without providing valid calibrator, disabling INT8
# [TRT]    [MemUsageChange] Init CUDA: CPU +203, GPU +0, now: CPU 226, GPU 3237 (MiB)
# [TRT]    native precisions detected for GPU:  FP32, FP16
# [TRT]    selecting fastest native precision for GPU:  FP16
# [TRT]    attempting to open engine cache file /usr/local/bin/networks/SSD-Mobilenet-v2/ssd_mobilenet_v2_coco.uff.1.1.8001.GPU.FP16.engine
# [TRT]    loading network plan from engine cache... /usr/local/bin/networks/SSD-Mobilenet-v2/ssd_mobilenet_v2_coco.uff.1.1.8001.GPU.FP16.engine
# [TRT]    device GPU, loaded /usr/local/bin/networks/SSD-Mobilenet-v2/ssd_mobilenet_v2_coco.uff
# [TRT]    [MemUsageChange] Init CUDA: CPU +0, GPU +0, now: CPU 260, GPU 3271 (MiB)
# [TRT]    Loaded engine size: 33 MB
# [TRT]    [MemUsageSnapshot] deserializeCudaEngine begin: CPU 260 MiB, GPU 3271 MiB
# [TRT]    Using cublas a tactic source
# [TRT]    [MemUsageChange] Init cuBLAS/cuBLASLt: CPU +158, GPU +162, now: CPU 436, GPU 3451 (MiB)
# [TRT]    Using cuDNN as a tactic source
# [TRT]    [MemUsageChange] Init cuDNN: CPU +240, GPU +238, now: CPU 676, GPU 3689 (MiB)
# [TRT]    [MemUsageChange] Init cuBLAS/cuBLASLt: CPU +0, GPU +0, now: CPU 677, GPU 3689 (MiB)
# [TRT]    Deserialization required 3843934 microseconds.
# [TRT]    [MemUsageSnapshot] deserializeCudaEngine end: CPU 677 MiB, GPU 3689 MiB
# [TRT]    [MemUsageSnapshot] ExecutionContext creation begin: CPU 677 MiB, GPU 3689 MiB
# [TRT]    Using cublas a tactic source
# [TRT]    [MemUsageChange] Init cuBLAS/cuBLASLt: CPU +0, GPU +0, now: CPU 677, GPU 3689 (MiB)
# [TRT]    Using cuDNN as a tactic source
# [TRT]    [MemUsageChange] Init cuDNN: CPU +0, GPU +0, now: CPU 677, GPU 3689 (MiB)
# [TRT]    Total per-runner device memory is 22143488
# [TRT]    Total per-runner host memory is 131872
# [TRT]    Allocated activation device memory of size 14261248
# [TRT]    [MemUsageSnapshot] ExecutionContext creation end: CPU 679 MiB, GPU 3694 MiB
# [TRT]
# [TRT]    CUDA engine context initialized on device GPU:
# [TRT]       -- layers       123
# [TRT]       -- maxBatchSize 1
# [TRT]       -- deviceMemory 14261248
# [TRT]       -- bindings     3
# [TRT]       binding 0
#                 -- index   0
#                 -- name    'Input'
#                 -- type    FP32
#                 -- in/out  INPUT
#                 -- # dims  3
#                 -- dim #0  3
#                 -- dim #1  300
#                 -- dim #2  300
# [TRT]       binding 1
#                 -- index   1
#                 -- name    'NMS'
#                 -- type    FP32
#                 -- in/out  OUTPUT
#                 -- # dims  3
#                 -- dim #0  1
#                 -- dim #1  100
#                 -- dim #2  7
# [TRT]       binding 2
#                 -- index   2
#                 -- name    'NMS_1'
#                 -- type    FP32
#                 -- in/out  OUTPUT
#                 -- # dims  3
#                 -- dim #0  1
#                 -- dim #1  1
#                 -- dim #2  1
# [TRT]
# [TRT]    binding to input 0 Input  binding index:  0
# [TRT]    binding to input 0 Input  dims (b=1 c=3 h=300 w=300) size=1080000
# [TRT]    binding to output 0 NMS  binding index:  1
# [TRT]    binding to output 0 NMS  dims (b=1 c=1 h=100 w=7) size=2800
# [TRT]    binding to output 1 NMS_1  binding index:  2
# [TRT]    binding to output 1 NMS_1  dims (b=1 c=1 h=1 w=1) size=4
# [TRT]
# [TRT]    device GPU, /usr/local/bin/networks/SSD-Mobilenet-v2/ssd_mobilenet_v2_coco.uff initialized.
# [TRT]    W = 7  H = 100  C = 1
# [TRT]    detectNet -- maximum bounding boxes:  100
# [TRT]    detectNet -- loaded 91 class info entries
# [TRT]    detectNet -- number of object classes:  91
# [gstreamer] initialized gstreamer, version 1.14.5.0
# [gstreamer] gstCamera -- attempting to create device v4l2:///dev/video0
# [gstreamer] gstCamera -- found v4l2 device: USB Camera
# [gstreamer] v4l2-proplist, device.path=(string)/dev/video0, udev-probed=(boolean)false, device.api=(string)v4l2, v4l2.device.driver=(string)uvcvideo, v4l2.device.card=(string)"USB\ Camera", v4l2.device.bus_info=(string)usb-70090000.xusb-2.3, v4l2.device.version=(uint)264701, v4l2.device.capabilities=(uint)2216689665, v4l2.device.device_caps=(uint)69206017;
# [gstreamer] gstCamera -- found 26 caps for v4l2 device /dev/video0
# [gstreamer] [0] video/x-raw, format=(string)YUY2, width=(int)1920, height=(int)1080, pixel-aspect-ratio=(fraction)1/1, framerate=(fraction)5/1;
# [gstreamer] [1] video/x-raw, format=(string)YUY2, width=(int)1280, height=(int)960, pixel-aspect-ratio=(fraction)1/1, framerate=(fraction)5/1;
# [gstreamer] [2] video/x-raw, format=(string)YUY2, width=(int)1280, height=(int)720, pixel-aspect-ratio=(fraction)1/1, framerate=(fraction)10/1;
# [gstreamer] [3] video/x-raw, format=(string)YUY2, width=(int)1024, height=(int)768, pixel-aspect-ratio=(fraction)1/1, framerate=(fraction)15/1;
# [gstreamer] [4] video/x-raw, format=(string)YUY2, width=(int)1280, height=(int)480, pixel-aspect-ratio=(fraction)1/1, framerate=(fraction)10/1;
# [gstreamer] [5] video/x-raw, format=(string)YUY2, width=(int)800, height=(int)600, pixel-aspect-ratio=(fraction)1/1, framerate=(fraction)20/1;
# [gstreamer] [6] video/x-raw, format=(string)YUY2, width=(int)848, height=(int)480, pixel-aspect-ratio=(fraction)1/1, framerate=(fraction)20/1;
# [gstreamer] [7] video/x-raw, format=(string)YUY2, width=(int)640, height=(int)480, pixel-aspect-ratio=(fraction)1/1, framerate=(fraction)30/1;
# [gstreamer] [8] video/x-raw, format=(string)YUY2, width=(int)640, height=(int)400, pixel-aspect-ratio=(fraction)1/1, framerate=(fraction)30/1;
# [gstreamer] [9] video/x-raw, format=(string)YUY2, width=(int)352, height=(int)288, pixel-aspect-ratio=(fraction)1/1, framerate=(fraction)30/1;
# [gstreamer] [10] video/x-raw, format=(string)YUY2, width=(int)320, height=(int)240, pixel-aspect-ratio=(fraction)1/1, framerate=(fraction)30/1;
# [gstreamer] [11] video/x-raw, format=(string)YUY2, width=(int)176, height=(int)144, pixel-aspect-ratio=(fraction)1/1, framerate=(fraction)30/1;
# [gstreamer] [12] video/x-raw, format=(string)YUY2, width=(int)160, height=(int)120, pixel-aspect-ratio=(fraction)1/1, framerate=(fraction){ 30/1, 5/1 };
# [gstreamer] [13] image/jpeg, width=(int)1920, height=(int)1080, pixel-aspect-ratio=(fraction)1/1, framerate=(fraction)30/1;
# [gstreamer] [14] image/jpeg, width=(int)1280, height=(int)1024, pixel-aspect-ratio=(fraction)1/1, framerate=(fraction)30/1;
# [gstreamer] [15] image/jpeg, width=(int)1280, height=(int)960, pixel-aspect-ratio=(fraction)1/1, framerate=(fraction)30/1;
# [gstreamer] [16] image/jpeg, width=(int)1280, height=(int)720, pixel-aspect-ratio=(fraction)1/1, framerate=(fraction){ 30/1, 5/1 };
# [gstreamer] [17] image/jpeg, width=(int)1280, height=(int)480, pixel-aspect-ratio=(fraction)1/1, framerate=(fraction)30/1;
# [gstreamer] [18] image/jpeg, width=(int)800, height=(int)600, pixel-aspect-ratio=(fraction)1/1, framerate=(fraction){ 30/1, 5/1 };
# [gstreamer] [19] image/jpeg, width=(int)848, height=(int)480, pixel-aspect-ratio=(fraction)1/1, framerate=(fraction)30/1;
# [gstreamer] [20] image/jpeg, width=(int)640, height=(int)480, pixel-aspect-ratio=(fraction)1/1, framerate=(fraction){ 30/1, 5/1 };
# [gstreamer] [21] image/jpeg, width=(int)640, height=(int)400, pixel-aspect-ratio=(fraction)1/1, framerate=(fraction)30/1;
# [gstreamer] [22] image/jpeg, width=(int)352, height=(int)288, pixel-aspect-ratio=(fraction)1/1, framerate=(fraction)30/1;
# [gstreamer] [23] image/jpeg, width=(int)320, height=(int)240, pixel-aspect-ratio=(fraction)1/1, framerate=(fraction){ 30/1, 5/1 };
# [gstreamer] [24] image/jpeg, width=(int)176, height=(int)144, pixel-aspect-ratio=(fraction)1/1, framerate=(fraction)30/1;
# [gstreamer] [25] image/jpeg, width=(int)160, height=(int)120, pixel-aspect-ratio=(fraction)1/1, framerate=(fraction){ 30/1, 5/1 };
# [gstreamer] gstCamera -- selected device profile:  codec=mjpeg format=unknown width=1280 height=720
# [gstreamer] gstCamera pipeline string:
# [gstreamer] v4l2src device=/dev/video0 ! image/jpeg, width=(int)1280, height=(int)720 ! jpegdec ! video/x-raw ! appsink name=mysink
# [gstreamer] gstCamera successfully created device v4l2:///dev/video0
# [video]  created gstCamera from v4l2:///dev/video0
# ------------------------------------------------
# gstCamera video options:
# ------------------------------------------------
#   -- URI: v4l2:///dev/video0
#      - protocol:  v4l2
#      - location:  /dev/video0
#   -- deviceType: v4l2
#   -- ioType:     input
#   -- codec:      mjpeg
#   -- width:      1280
#   -- height:     720
#   -- frameRate:  30.000000
#   -- bitRate:    0
#   -- numBuffers: 4
#   -- zeroCopy:   true
#   -- flipMethod: none
#   -- loop:       0
#   -- rtspLatency 2000
# ------------------------------------------------
# [gstreamer] gstEncoder -- codec not specified, defaulting to H.264
# [gstreamer] gstEncoder -- pipeline launch string:
# [gstreamer] appsrc name=mysource is-live=true do-timestamp=true format=3 ! omxh264enc bitrate=4000000 ! video/x-h264 !  rtph264pay config-interval=1 ! udpsink host=192.168.1.13 port=1234 auto-multicast=true
# [video]  created gstEncoder from rtp://192.168.1.13:1234
# ------------------------------------------------
# gstEncoder video options:
# ------------------------------------------------
#   -- URI: rtp://192.168.1.13:1234
#      - protocol:  rtp
#      - location:  192.168.1.13
#      - port:      1234
#   -- deviceType: ip
#   -- ioType:     output
#   -- codec:      h264
#   -- width:      0
#   -- height:     0
#   -- frameRate:  30.000000
#   -- bitRate:    4000000
#   -- numBuffers: 4
#   -- zeroCopy:   true
#   -- flipMethod: none
#   -- loop:       0
#   -- rtspLatency 2000
# ------------------------------------------------
# [OpenGL] failed to open X11 server connection.
# [OpenGL] failed to create X11 Window.
# [gstreamer] opening gstCamera for streaming, transitioning pipeline to GST_STATE_PLAYING
# [gstreamer] gstreamer changed state from NULL to READY ==> mysink
# [gstreamer] gstreamer changed state from NULL to READY ==> capsfilter1
# [gstreamer] gstreamer changed state from NULL to READY ==> jpegdec0
# [gstreamer] gstreamer changed state from NULL to READY ==> capsfilter0
# [gstreamer] gstreamer changed state from NULL to READY ==> v4l2src0
# [gstreamer] gstreamer changed state from NULL to READY ==> pipeline0
# [gstreamer] gstreamer changed state from READY to PAUSED ==> capsfilter1
# [gstreamer] gstreamer changed state from READY to PAUSED ==> jpegdec0
# [gstreamer] gstreamer changed state from READY to PAUSED ==> capsfilter0
# [gstreamer] gstreamer stream status CREATE ==> src
# [gstreamer] gstreamer changed state from READY to PAUSED ==> v4l2src0
# [gstreamer] gstreamer changed state from READY to PAUSED ==> pipeline0
# [gstreamer] gstreamer stream status ENTER ==> src
# [gstreamer] gstreamer message new-clock ==> pipeline0
# [gstreamer] gstreamer message stream-start ==> pipeline0
# [gstreamer] gstreamer changed state from PAUSED to PLAYING ==> capsfilter1
# [gstreamer] gstreamer changed state from PAUSED to PLAYING ==> jpegdec0
# [gstreamer] gstreamer changed state from PAUSED to PLAYING ==> capsfilter0
# [gstreamer] gstreamer changed state from PAUSED to PLAYING ==> v4l2src0
# [gstreamer] gstCamera -- onPreroll
# [gstreamer] gstCamera -- map buffer size was less than max size (1382400 vs 1382407)
# [gstreamer] gstCamera recieve caps:  video/x-raw, format=(string)I420, width=(int)1280, height=(int)720, interlace-mode=(string)progressive, multiview-mode=(string)mono, multiview-flags=(GstVideoMultiviewFlagsSet)0:ffffffff:/right-view-first/left-flipped/left-flopped/right-flipped/right-flopped/half-aspect/mixed-mono, pixel-aspect-ratio=(fraction)1/1, chroma-site=(string)mpeg2, colorimetry=(string)1:4:0:0, framerate=(fraction)30/1
# [gstreamer] gstCamera -- recieved first frame, codec=mjpeg format=i420 width=1280 height=720 size=1382407
# RingBuffer -- allocated 4 buffers (1382407 bytes each, 5529628 bytes total)
# [gstreamer] gstreamer changed state from READY to PAUSED ==> mysink
# [gstreamer] gstreamer message async-done ==> pipeline0
# [gstreamer] gstreamer changed state from PAUSED to PLAYING ==> mysink
# [gstreamer] gstreamer changed state from PAUSED to PLAYING ==> pipeline0
# RingBuffer -- allocated 4 buffers (2764800 bytes each, 11059200 bytes total)
# RingBuffer -- allocated 2 buffers (1382400 bytes each, 2764800 bytes total)
# [gstreamer] gstEncoder-- starting pipeline, transitioning to GST_STATE_PLAYING
# [gstreamer] gstreamer changed state from NULL to READY ==> udpsink0
# [gstreamer] gstreamer changed state from NULL to READY ==> rtph264pay0
# [gstreamer] gstreamer changed state from NULL to READY ==> capsfilter2
# [gstreamer] gstreamer changed state from NULL to READY ==> omxh264enc-omxh264enc0
# [gstreamer] gstreamer changed state from NULL to READY ==> mysource
# [gstreamer] gstreamer changed state from NULL to READY ==> pipeline1
# [gstreamer] gstreamer changed state from READY to PAUSED ==> rtph264pay0
# [gstreamer] gstreamer changed state from READY to PAUSED ==> capsfilter2
# [gstreamer] gstreamer changed state from READY to PAUSED ==> omxh264enc-omxh264enc0
# [gstreamer] gstreamer stream status CREATE ==> src
# [gstreamer] gstreamer changed state from READY to PAUSED ==> mysource
# [gstreamer] gstreamer changed state from READY to PAUSED ==> pipeline1
# [gstreamer] gstreamer stream status ENTER ==> src
# [gstreamer] gstreamer message new-clock ==> pipeline1
# [gstreamer] gstreamer changed state from PAUSED to PLAYING ==> rtph264pay0
# [gstreamer] gstreamer changed state from PAUSED to PLAYING ==> capsfilter2
# [gstreamer] gstreamer changed state from PAUSED to PLAYING ==> omxh264enc-omxh264enc0
# [gstreamer] gstreamer changed state from PAUSED to PLAYING ==> mysource
# [gstreamer] gstEncoder -- new caps: video/x-raw, width=1280, height=720, format=(string)I420, framerate=30/1
# Framerate set to : 30 at NvxVideoEncoderSetParameterNvMMLiteOpen : Block : BlockType = 4
# ===== NVMEDIA: NVENC =====
# NvMMLiteBlockCreate : Block : BlockType = 4
# H264: Profile = 66, Level = 40
# NVMEDIA_ENC: bBlitMode is set to TRUE
# [gstreamer] gstreamer stream status CREATE ==> src
# [gstreamer] gstreamer stream status ENTER ==> src
# [gstreamer] gstreamer message stream-start ==> pipeline1
# [gstreamer] gstreamer changed state from READY to PAUSED ==> udpsink0
# [gstreamer] gstreamer message async-done ==> pipeline1
# [gstreamer] gstreamer changed state from PAUSED to PLAYING ==> udpsink0
# [gstreamer] gstreamer changed state from PAUSED to PLAYING ==> pipeline1
# [gstreamer] gstreamer message qos ==> v4l2src0
# [gstreamer] gstreamer message qos ==> v4l2src0
# [gstreamer] gstreamer message qos ==> v4l2src0
# [gstreamer] gstreamer message qos ==> v4l2src0
# [gstreamer] gstreamer message qos ==> v4l2src0
# [gstreamer] gstreamer message qos ==> v4l2src0
# [gstreamer] gstreamer message qos ==> v4l2src0
# ^C
# Traceback (most recent call last):
#   File "my-detection.py", line 39, in <module>
#     detections = net.Detect(img)
# KeyboardInterrupt
# [gstreamer] gstCamera -- stopping pipeline, transitioning to GST_STATE_NULL

# %%
# !detectnet --tracking videos/pedestrians.mp4 videos/pedestrians_tracking.mp4
# Out:
# [gstreamer] initialized gstreamer, version 1.14.5.0
# [gstreamer] gstDecoder -- creating decoder for videos/pedestrians.mp4
# Opening in BLOCKING MODE
# NvMMLiteOpen : Block : BlockType = 261
# NVMEDIA: Reading vendor.tegra.display-size : status: 6
# NvMMLiteBlockCreate : Block : BlockType = 261
# [gstreamer] gstDecoder -- discovered video resolution: 960x540  (framerate 29.970030 Hz)
# [gstreamer] gstDecoder -- discovered video caps:  video/x-h264, stream-format=(string)byte-stream, alignment=(string)au, level=(string)3.1, profile=(string)high, width=(int)960, height=(int)540, framerate=(fraction)30000/1001, pixel-aspect-ratio=(fraction)1/1, interlace-mode=(string)progressive, chroma-format=(string)4:2:0, bit-depth-luma=(uint)8, bit-depth-chroma=(uint)8, parsed=(boolean)true
# [gstreamer] gstDecoder -- pipeline string:
# [gstreamer] filesrc location=videos/pedestrians.mp4 ! qtdemux ! queue ! h264parse ! omxh264dec ! video/x-raw ! appsink name=mysink
# [video]  created gstDecoder from file:///jetson_telloProject/videos/pedestrians.mp4
# ------------------------------------------------
# gstDecoder video options:
# ------------------------------------------------
#   -- URI: file:///jetson_telloProject/videos/pedestrians.mp4
#      - protocol:  file
#      - location:  videos/pedestrians.mp4
#      - extension: mp4
#   -- deviceType: file
#   -- ioType:     input
#   -- codec:      h264
#   -- width:      960
#   -- height:     540
#   -- frameRate:  29.970030
#   -- bitRate:    0
#   -- numBuffers: 4
#   -- zeroCopy:   true
#   -- flipMethod: none
#   -- loop:       0
#   -- rtspLatency 2000
# ------------------------------------------------
# [gstreamer] gstEncoder -- codec not specified, defaulting to H.264
# [gstreamer] gstEncoder -- pipeline launch string:
# [gstreamer] appsrc name=mysource is-live=true do-timestamp=true format=3 ! omxh264enc bitrate=4000000 ! video/x-h264 !  h264parse ! qtmux ! filesink location=videos/pedestrians_tracking.mp4
# [video]  created gstEncoder from file:///jetson_telloProject/videos/pedestrians_tracking.mp4
# ------------------------------------------------
# gstEncoder video options:
# ------------------------------------------------
#   -- URI: file:///jetson_telloProject/videos/pedestrians_tracking.mp4
#      - protocol:  file
#      - location:  videos/pedestrians_tracking.mp4
#      - extension: mp4
#   -- deviceType: file
#   -- ioType:     output
#   -- codec:      h264
#   -- width:      0
#   -- height:     0
#   -- frameRate:  30.000000
#   -- bitRate:    4000000
#   -- numBuffers: 4
#   -- zeroCopy:   true
#   -- flipMethod: none
#   -- loop:       0
#   -- rtspLatency 2000
# ------------------------------------------------
# [OpenGL] failed to open X11 server connection.
# [OpenGL] failed to create X11 Window.
#
# detectNet -- loading detection network model from:
#           -- model        networks/SSD-Mobilenet-v2/ssd_mobilenet_v2_coco.uff
#           -- input_blob   'Input'
#           -- output_blob  'NMS'
#           -- output_count 'NMS_1'
#           -- class_labels networks/SSD-Mobilenet-v2/ssd_coco_labels.txt
#           -- threshold    0.500000
#           -- batch_size   1
#
# [TRT]    TensorRT version 8.0.1
# [TRT]    loading NVIDIA plugins...
# [TRT]    Registered plugin creator - ::GridAnchor_TRT version 1
# [TRT]    Registered plugin creator - ::GridAnchorRect_TRT version 1
# [TRT]    Registered plugin creator - ::NMS_TRT version 1
# [TRT]    Registered plugin creator - ::Reorg_TRT version 1
# [TRT]    Registered plugin creator - ::Region_TRT version 1
# [TRT]    Registered plugin creator - ::Clip_TRT version 1
# [TRT]    Registered plugin creator - ::LReLU_TRT version 1
# [TRT]    Registered plugin creator - ::PriorBox_TRT version 1
# [TRT]    Registered plugin creator - ::Normalize_TRT version 1
# [TRT]    Registered plugin creator - ::ScatterND version 1
# [TRT]    Registered plugin creator - ::RPROI_TRT version 1
# [TRT]    Registered plugin creator - ::BatchedNMS_TRT version 1
# [TRT]    Registered plugin creator - ::BatchedNMSDynamic_TRT version 1
# [TRT]    Could not register plugin creator -  ::FlattenConcat_TRT version 1
# [TRT]    Registered plugin creator - ::CropAndResize version 1
# [TRT]    Registered plugin creator - ::DetectionLayer_TRT version 1
# [TRT]    Registered plugin creator - ::EfficientNMS_ONNX_TRT version 1
# [TRT]    Registered plugin creator - ::EfficientNMS_TRT version 1
# [TRT]    Registered plugin creator - ::Proposal version 1
# [TRT]    Registered plugin creator - ::ProposalLayer_TRT version 1
# [TRT]    Registered plugin creator - ::PyramidROIAlign_TRT version 1
# [TRT]    Registered plugin creator - ::ResizeNearest_TRT version 1
# [TRT]    Registered plugin creator - ::Split version 1
# [TRT]    Registered plugin creator - ::SpecialSlice_TRT version 1
# [TRT]    Registered plugin creator - ::InstanceNormalization_TRT version 1
# [TRT]    detected model format - UFF  (extension '.uff')
# [TRT]    desired precision specified for GPU: FASTEST
# [TRT]    requested fasted precision for device GPU without providing valid calibrator, disabling INT8
# [TRT]    [MemUsageChange] Init CUDA: CPU +202, GPU +0, now: CPU 225, GPU 3666 (MiB)
# [TRT]    native precisions detected for GPU:  FP32, FP16
# [TRT]    selecting fastest native precision for GPU:  FP16
# [TRT]    attempting to open engine cache file /usr/local/bin/networks/SSD-Mobilenet-v2/ssd_mobilenet_v2_coco.uff.1.1.8001.GPU.FP16.engine
# [TRT]    loading network plan from engine cache... /usr/local/bin/networks/SSD-Mobilenet-v2/ssd_mobilenet_v2_coco.uff.1.1.8001.GPU.FP16.engine
# [TRT]    device GPU, loaded /usr/local/bin/networks/SSD-Mobilenet-v2/ssd_mobilenet_v2_coco.uff
# [TRT]    [MemUsageChange] Init CUDA: CPU +0, GPU +0, now: CPU 259, GPU 3716 (MiB)
# [TRT]    Loaded engine size: 33 MB
# [TRT]    [MemUsageSnapshot] deserializeCudaEngine begin: CPU 259 MiB, GPU 3716 MiB
# [TRT]    Using cublas a tactic source
# [TRT]    [MemUsageChange] Init cuBLAS/cuBLASLt: CPU +158, GPU +71, now: CPU 435, GPU 3786 (MiB)
# [TRT]    Using cuDNN as a tactic source
# [TRT]    [MemUsageChange] Init cuDNN: CPU +241, GPU +90, now: CPU 676, GPU 3876 (MiB)
# [TRT]    [MemUsageChange] Init cuBLAS/cuBLASLt: CPU +0, GPU +0, now: CPU 676, GPU 3877 (MiB)
# [TRT]    Deserialization required 5996824 microseconds.
# [TRT]    [MemUsageSnapshot] deserializeCudaEngine end: CPU 676 MiB, GPU 3877 MiB
# [TRT]    [MemUsageSnapshot] ExecutionContext creation begin: CPU 676 MiB, GPU 3877 MiB
# [TRT]    Using cublas a tactic source
# [TRT]    [MemUsageChange] Init cuBLAS/cuBLASLt: CPU +0, GPU +0, now: CPU 676, GPU 3877 (MiB)
# [TRT]    Using cuDNN as a tactic source
# [TRT]    [MemUsageChange] Init cuDNN: CPU +0, GPU +0, now: CPU 676, GPU 3877 (MiB)
# [TRT]    Total per-runner device memory is 22143488
# [TRT]    Total per-runner host memory is 131872
# [TRT]    Allocated activation device memory of size 14261248
# [TRT]    [MemUsageSnapshot] ExecutionContext creation end: CPU 678 MiB, GPU 3863 MiB
# [TRT]
# [TRT]    CUDA engine context initialized on device GPU:
# [TRT]       -- layers       123
# [TRT]       -- maxBatchSize 1
# [TRT]       -- deviceMemory 14261248
# [TRT]       -- bindings     3
# [TRT]       binding 0
#                 -- index   0
#                 -- name    'Input'
#                 -- type    FP32
#                 -- in/out  INPUT
#                 -- # dims  3
#                 -- dim #0  3
#                 -- dim #1  300
#                 -- dim #2  300
# [TRT]       binding 1
#                 -- index   1
#                 -- name    'NMS'
#                 -- type    FP32
#                 -- in/out  OUTPUT
#                 -- # dims  3
#                 -- dim #0  1
#                 -- dim #1  100
#                 -- dim #2  7
# [TRT]       binding 2
#                 -- index   2
#                 -- name    'NMS_1'
#                 -- type    FP32
#                 -- in/out  OUTPUT
#                 -- # dims  3
#                 -- dim #0  1
#                 -- dim #1  1
#                 -- dim #2  1
# [TRT]
# [TRT]    binding to input 0 Input  binding index:  0
# [TRT]    binding to input 0 Input  dims (b=1 c=3 h=300 w=300) size=1080000
# [TRT]    binding to output 0 NMS  binding index:  1
# [TRT]    binding to output 0 NMS  dims (b=1 c=1 h=100 w=7) size=2800
# [TRT]    binding to output 1 NMS_1  binding index:  2
# [TRT]    binding to output 1 NMS_1  dims (b=1 c=1 h=1 w=1) size=4
# [TRT]
# [TRT]    device GPU, /usr/local/bin/networks/SSD-Mobilenet-v2/ssd_mobilenet_v2_coco.uff initialized.
# [TRT]    W = 7  H = 100  C = 1
# [TRT]    detectNet -- maximum bounding boxes:  100
# [TRT]    detectNet -- loaded 91 class info entries
# [TRT]    detectNet -- number of object classes:  91
# [gstreamer] opening gstDecoder for streaming, transitioning pipeline to GST_STATE_PLAYING
# [gstreamer] gstreamer changed state from NULL to READY ==> mysink
# [gstreamer] gstreamer changed state from NULL to READY ==> capsfilter1
# [gstreamer] gstreamer changed state from NULL to READY ==> omxh264dec-omxh264dec0
# [gstreamer] gstreamer changed state from NULL to READY ==> h264parse1
# [gstreamer] gstreamer changed state from NULL to READY ==> queue0
# [gstreamer] gstreamer changed state from NULL to READY ==> qtdemux1
# [gstreamer] gstreamer changed state from NULL to READY ==> filesrc0
# [gstreamer] gstreamer changed state from NULL to READY ==> pipeline0
# [gstreamer] gstreamer changed state from READY to PAUSED ==> capsfilter1
# [gstreamer] gstreamer changed state from READY to PAUSED ==> omxh264dec-omxh264dec0
# [gstreamer] gstreamer changed state from READY to PAUSED ==> h264parse1
# [gstreamer] gstreamer stream status CREATE ==> src
# [gstreamer] gstreamer changed state from READY to PAUSED ==> queue0
# [gstreamer] gstreamer stream status ENTER ==> src
# [gstreamer] gstreamer stream status CREATE ==> sink
# [gstreamer] gstreamer changed state from READY to PAUSED ==> qtdemux1
# [gstreamer] gstreamer changed state from READY to PAUSED ==> filesrc0
# [gstreamer] gstreamer stream status ENTER ==> sink
#
# (detectnet:1290): GStreamer-CRITICAL **: 20:51:15.986: gst_caps_is_empty: assertion 'GST_IS_CAPS (caps)' failed
#
# (detectnet:1290): GStreamer-CRITICAL **: 20:51:15.990: gst_caps_truncate: assertion 'GST_IS_CAPS (caps)' failed
#
# (detectnet:1290): GStreamer-CRITICAL **: 20:51:15.990: gst_caps_fixate: assertion 'GST_IS_CAPS (caps)' failed
#
# (detectnet:1290): GStreamer-CRITICAL **: 20:51:15.990: gst_caps_get_structure: assertion 'GST_IS_CAPS (caps)' failed
#
# (detectnet:1290): GStreamer-CRITICAL **: 20:51:15.990: gst_structure_get_string: assertion 'structure != NULL' failed
#
# (detectnet:1290): GStreamer-CRITICAL **: 20:51:15.990: gst_mini_object_unref: assertion 'mini_object != NULL' failed
# NvMMLiteOpen : Block : BlockType = 261
# NVMEDIA: Reading vendor.tegra.display-size : status: 6
# NvMMLiteBlockCreate : Block : BlockType = 261
# Allocating new output: 960x544 (x 11), ThumbnailMode = 0
# OPENMAX: HandleNewStreamFormat: 3605: Send OMX_EventPortSettingsChanged: nFrameWidth = 960, nFrameHeight = 540
# [gstreamer] gstDecoder -- onPreroll()
# [gstreamer] gstreamer message stream-start ==> pipeline0
# [gstreamer] gstreamer stream status CREATE ==> src
# [gstreamer] gstreamer stream status ENTER ==> src
# [gstreamer] gstreamer message duration-changed ==> h264parse1
# [gstreamer] gstreamer mysink taglist, video-codec=(string)"H.264\ /\ AVC", bitrate=(uint)720629;
# [gstreamer] gstreamer mysink taglist, encoder=(string)Lavf54.63.104, container-format=(string)"ISO\ MP4/M4A";
# [gstreamer] gstreamer mysink taglist, video-codec=(string)"H.264\ \(High\ Profile\)", bitrate=(uint)720629;
# [gstreamer] gstDecoder recieve caps:  video/x-raw, format=(string)NV12, width=(int)960, height=(int)540, interlace-mode=(string)progressive, multiview-mode=(string)mono, multiview-flags=(GstVideoMultiviewFlagsSet)0:ffffffff:/right-view-first/left-flipped/left-flopped/right-flipped/right-flopped/half-aspect/mixed-mono, pixel-aspect-ratio=(fraction)1/1, chroma-site=(string)jpeg, colorimetry=(string)bt601, framerate=(fraction)30000/1001
# [gstreamer] gstDecoder -- recieved first frame, codec=h264 format=nv12 width=960 height=540 size=777600
# RingBuffer -- allocated 4 buffers (777600 bytes each, 3110400 bytes total)
# [gstreamer] gstreamer changed state from READY to PAUSED ==> mysink
# [gstreamer] gstreamer changed state from READY to PAUSED ==> pipeline0
# [gstreamer] gstreamer message async-done ==> pipeline0
# [gstreamer] gstreamer message new-clock ==> pipeline0
# [gstreamer] gstreamer changed state from PAUSED to PLAYING ==> mysink
# [gstreamer] gstreamer changed state from PAUSED to PLAYING ==> capsfilter1
# [gstreamer] gstreamer changed state from PAUSED to PLAYING ==> omxh264dec-omxh264dec0
# [gstreamer] gstreamer changed state from PAUSED to PLAYING ==> h264parse1
# [gstreamer] gstreamer changed state from PAUSED to PLAYING ==> queue0
# [gstreamer] gstreamer changed state from PAUSED to PLAYING ==> qtdemux1
# [gstreamer] gstreamer changed state from PAUSED to PLAYING ==> filesrc0
# [gstreamer] gstreamer changed state from PAUSED to PLAYING ==> pipeline0
# RingBuffer -- allocated 4 buffers (1555200 bytes each, 6220800 bytes total)
# [gstreamer] gstreamer mysink taglist, video-codec=(string)"H.264\ \(High\ Profile\)", bitrate=(uint)720629, minimum-bitrate=(uint)166633, maximum-bitrate=(uint)166633;
# [gstreamer] gstreamer mysink taglist, video-codec=(string)"H.264\ \(High\ Profile\)", bitrate=(uint)720629, minimum-bitrate=(uint)127792, maximum-bitrate=(uint)166633;
# [gstreamer] gstreamer mysink taglist, video-codec=(string)"H.264\ \(High\ Profile\)", bitrate=(uint)720629, minimum-bitrate=(uint)127792, maximum-bitrate=(uint)1089470;
# [gstreamer] gstreamer mysink taglist, video-codec=(string)"H.264\ \(High\ Profile\)", bitrate=(uint)720629, minimum-bitrate=(uint)127792, maximum-bitrate=(uint)1291348;
# [gstreamer] gstreamer mysink taglist, video-codec=(string)"H.264\ \(High\ Profile\)", bitrate=(uint)720629, minimum-bitrate=(uint)127792, maximum-bitrate=(uint)1727472;
# [gstreamer] gstreamer mysink taglist, video-codec=(string)"H.264\ \(High\ Profile\)", bitrate=(uint)720629, minimum-bitrate=(uint)127792, maximum-bitrate=(uint)1764155;
# [gstreamer] gstreamer mysink taglist, video-codec=(string)"H.264\ \(High\ Profile\)", bitrate=(uint)720629, minimum-bitrate=(uint)127792, maximum-bitrate=(uint)1797482;
# [gstreamer] gstreamer mysink taglist, video-codec=(string)"H.264\ \(High\ Profile\)", bitrate=(uint)720629, minimum-bitrate=(uint)127792, maximum-bitrate=(uint)1818821;
# 4 objects detected
# detected obj 0  class #1 (person)  confidence=0.542480
# bounding box 0  (249.843750, 224.384766)  (315.000000, 386.279297)  w=65.156250  h=161.894531
# detected obj 1  class #1 (person)  confidence=0.858398
# bounding box 1  (634.218750, 56.755371)  (662.343750, 141.064453)  w=28.125000  h=84.309082
# detected obj 2  class #1 (person)  confidence=0.751953
# bounding box 2  (592.500000, 80.024414)  (617.812500, 153.852539)  w=25.312500  h=73.828125
# detected obj 3  class #1 (person)  confidence=0.790039
# bounding box 3  (676.406250, 65.456543)  (700.781250, 138.427734)  w=24.375000  h=72.971191
# RingBuffer -- allocated 2 buffers (777600 bytes each, 1555200 bytes total)
# [gstreamer] gstEncoder-- starting pipeline, transitioning to GST_STATE_PLAYING
# [gstreamer] gstreamer changed state from NULL to READY ==> filesink0
# [gstreamer] gstreamer changed state from NULL to READY ==> qtmux0
# [gstreamer] gstreamer changed state from NULL to READY ==> h264parse2
# [gstreamer] gstreamer changed state from NULL to READY ==> capsfilter2
# [gstreamer] gstreamer changed state from NULL to READY ==> omxh264enc-omxh264enc0
# [gstreamer] gstreamer changed state from NULL to READY ==> mysource
# [gstreamer] gstreamer changed state from NULL to READY ==> pipeline1
# [gstreamer] gstreamer changed state from READY to PAUSED ==> qtmux0
# [gstreamer] gstreamer changed state from READY to PAUSED ==> h264parse2
# [gstreamer] gstreamer changed state from READY to PAUSED ==> capsfilter2
# [gstreamer] gstreamer changed state from READY to PAUSED ==> omxh264enc-omxh264enc0
# [gstreamer] gstreamer stream status CREATE ==> src
# [gstreamer] gstreamer changed state from READY to PAUSED ==> mysource
# [gstreamer] gstreamer changed state from READY to PAUSED ==> pipeline1
# [gstreamer] gstreamer message new-clock ==> pipeline1
# [gstreamer] gstreamer stream status ENTER ==> src
# [gstreamer] gstreamer changed state from PAUSED to PLAYING ==> qtmux0
# [gstreamer] gstreamer changed state from PAUSED to PLAYING ==> h264parse2
# [gstreamer] gstreamer changed state from PAUSED to PLAYING ==> capsfilter2
# [gstreamer] gstreamer changed state from PAUSED to PLAYING ==> omxh264enc-omxh264enc0
# [gstreamer] gstreamer changed state from PAUSED to PLAYING ==> mysource
# [gstreamer] gstEncoder -- new caps: video/x-raw, width=960, height=540, format=(string)I420, framerate=30/1
# Framerate set to : 30 at NvxVideoEncoderSetParameterNvMMLiteOpen : Block : BlockType = 4
# ===== NVMEDIA: NVENC =====
#
# [TRT]    ------------------------------------------------
# [TRT]    Timing Report /usr/local/bin/networks/SSD-Mobilenet-v2/ssd_mobilenet_v2_coco.uff
# [TRT]    ------------------------------------------------
# [TRT]    Pre-Process   CPU   0.06745ms  CUDA   1.61755ms
# [TRT]    Network       CPU 3921.33594ms  CUDA 3915.10327ms
# [TRT]    Post-Process  CPU   0.08922ms  CUDA   0.08391ms
# [TRT]    Visualize     CPU  14.18886ms  CUDA  14.76937ms
# [TRT]    Total         CPU 3935.68140ms  CUDA 3931.57397ms
# [TRT]    ------------------------------------------------
#
# [TRT]    note -- when processing a single image, run 'sudo jetson_clocks' before
#                 to disable DVFS for more accurate profiling/timing measurements
#
# NvMMLiteBlockCreate : Block : BlockType = 4
# H264: Profile = 66, Level = 40
# NVMEDIA_ENC: bBlitMode is set to TRUE
# 5 objects detected
# detected obj 0  class #1 (person)  confidence=0.809082
# bounding box 0  (201.445312, 220.429688)  (296.953125, 379.160156)  w=95.507812  h=158.730469
# detected obj 1  class #1 (person)  confidence=0.546387
# bounding box 1  (666.562500, 195.776367)  (709.687500, 321.679688)  w=43.125000  h=125.903320
# detected obj 2  class #1 (person)  confidence=0.632324
# bounding box 2  (818.906250, 240.732422)  (856.406250, 382.060547)  w=37.500000  h=141.328125
# detected obj 3  class #1 (person)  confidence=0.730469
# bounding box 3  (445.546875, 160.839844)  (490.312500, 265.781250)  w=44.765625  h=104.941406
# detected obj 4  class #1 (person)  confidence=0.562988
# bounding box 4  (621.093750, 112.390137)  (645.468750, 180.878906)  w=24.375000  h=68.488770
# [gstreamer] gstreamer stream status CREATE ==> src
# [gstreamer] gstreamer stream status ENTER ==> src
# [gstreamer] gstreamer message stream-start ==> pipeline1
# [gstreamer] gstreamer changed state from READY to PAUSED ==> filesink0
# [gstreamer] gstreamer message async-done ==> pipeline1
# [gstreamer] gstreamer changed state from PAUSED to PLAYING ==> filesink0
# [gstreamer] gstreamer changed state from PAUSED to PLAYING ==> pipeline1
#
# [TRT]    ------------------------------------------------
# [TRT]    Timing Report /usr/local/bin/networks/SSD-Mobilenet-v2/ssd_mobilenet_v2_coco.uff
# [TRT]    ------------------------------------------------
# [TRT]    Pre-Process   CPU   0.09698ms  CUDA   1.09474ms
# [TRT]    Network       CPU  58.50314ms  CUDA  54.85625ms
# [TRT]    Post-Process  CPU   0.05422ms  CUDA   0.05354ms
# [TRT]    Visualize     CPU   0.30386ms  CUDA   0.96458ms
# [TRT]    Total         CPU  58.95820ms  CUDA  56.96911ms
# [TRT]    ------------------------------------------------
#
# 6 objects detected
# detected obj 0  class #1 (person)  confidence=0.721191
# bounding box 0  (204.843750, 220.166016)  (300.000000, 374.150391)  w=95.156250  h=153.984375
# detected obj 1  class #1 (person)  confidence=0.653809
# bounding box 1  (812.812500, 238.886719)  (854.062500, 384.433594)  w=41.250000  h=145.546875
# detected obj 2  class #1 (person)  confidence=0.547852
# bounding box 2  (670.312500, 197.490234)  (715.312500, 317.460938)  w=45.000000  h=119.970703
# detected obj 3  class #1 (person)  confidence=0.716797
# bounding box 3  (446.015625, 163.740234)  (492.656250, 264.462891)  w=46.640625  h=100.722656
# detected obj 4  class #1 (person)  confidence=0.630859
# bounding box 4  (617.343750, 98.876953)  (649.218750, 169.672852)  w=31.875000  h=70.795898
# detected obj 5  class #1 (person)  confidence=0.529297
# bounding box 5  (533.437500, 114.433594)  (563.437500, 187.734375)  w=30.000000  h=73.300781
#
# [TRT]    ------------------------------------------------
# [TRT]    Timing Report /usr/local/bin/networks/SSD-Mobilenet-v2/ssd_mobilenet_v2_coco.uff
# [TRT]    ------------------------------------------------
# [TRT]    Pre-Process   CPU   0.06542ms  CUDA   1.03833ms
# [TRT]    Network       CPU  46.52438ms  CUDA  42.70438ms
# [TRT]    Post-Process  CPU   0.05083ms  CUDA   0.05141ms
# [TRT]    Visualize     CPU   0.29011ms  CUDA   1.04896ms
# [TRT]    Total         CPU  46.93074ms  CUDA  44.84307ms
# [TRT]    ------------------------------------------------
#
# 5 objects detected
# detected obj 0  class #1 (person)  confidence=0.613281
# bounding box 0  (208.125000, 218.056641)  (307.968750, 370.458984)  w=99.843750  h=152.402344
# detected obj 1  class #1 (person)  confidence=0.637207
# bounding box 1  (675.937500, 198.808594)  (720.000000, 322.207031)  w=44.062500  h=123.398438
# detected obj 2  class #1 (person)  confidence=0.632812
# bounding box 2  (450.468750, 158.466797)  (496.406250, 262.353516)  w=45.937500  h=103.886719
# detected obj 3  class #1 (person)  confidence=0.631348
# bounding box 3  (618.281250, 98.811035)  (649.218750, 166.376953)  w=30.937500  h=67.565918
# detected obj 4  class #1 (person)  confidence=0.520508
# bounding box 4  (532.500000, 120.498047)  (561.562500, 188.261719)  w=29.062500  h=67.763672
#
# [TRT]    ------------------------------------------------
# [TRT]    Timing Report /usr/local/bin/networks/SSD-Mobilenet-v2/ssd_mobilenet_v2_coco.uff
# [TRT]    ------------------------------------------------
# [TRT]    Pre-Process   CPU   0.06333ms  CUDA   1.05396ms
# [TRT]    Network       CPU  41.30886ms  CUDA  37.52562ms
# [TRT]    Post-Process  CPU   0.05115ms  CUDA   0.05068ms
# [TRT]    Visualize     CPU   0.48563ms  CUDA   0.85677ms
# [TRT]    Total         CPU  41.90898ms  CUDA  39.48703ms
# [TRT]    ------------------------------------------------
#
# 4 objects detected
# detected obj 0  class #1 (person)  confidence=0.586426
# bounding box 0  (219.609375, 217.397461)  (313.828125, 372.304688)  w=94.218750  h=154.907227
# detected obj 1  class #1 (person)  confidence=0.638184
# bounding box 1  (679.687500, 198.544922)  (720.937500, 322.470703)  w=41.250000  h=123.925781
# detected obj 2  class #1 (person)  confidence=0.747559
# bounding box 2  (452.109375, 158.730469)  (497.812500, 261.826172)  w=45.703125  h=103.095703
# detected obj 3  class #1 (person)  confidence=0.620605
# bounding box 3  (617.343750, 98.349609)  (648.281250, 165.717773)  w=30.937500  h=67.368164
#
# [TRT]    ------------------------------------------------
# [TRT]    Timing Report /usr/local/bin/networks/SSD-Mobilenet-v2/ssd_mobilenet_v2_coco.uff
# [TRT]    ------------------------------------------------
# [TRT]    Pre-Process   CPU   0.05896ms  CUDA   1.04760ms
# [TRT]    Network       CPU  41.47318ms  CUDA  37.76969ms
# [TRT]    Post-Process  CPU   0.05656ms  CUDA   0.05542ms
# [TRT]    Visualize     CPU   0.33891ms  CUDA   0.78323ms
# [TRT]    Total         CPU  41.92762ms  CUDA  39.65594ms
# [TRT]    ------------------------------------------------
#
# 4 objects detected
# detected obj 0  class #1 (person)  confidence=0.512695
# bounding box 0  (230.859375, 221.220703)  (311.953125, 368.876953)  w=81.093750  h=147.656250
# detected obj 1  class #1 (person)  confidence=0.794434
# bounding box 1  (453.281250, 159.257812)  (497.812500, 259.980469)  w=44.531250  h=100.722656
# detected obj 2  class #1 (person)  confidence=0.551758
# bounding box 2  (685.312500, 197.622070)  (721.875000, 319.042969)  w=36.562500  h=121.420898
# detected obj 3  class #1 (person)  confidence=0.604004
# bounding box 3  (619.218750, 97.229004)  (649.218750, 164.531250)  w=30.000000  h=67.302246
#
# [TRT]    ------------------------------------------------
# [TRT]    Timing Report /usr/local/bin/networks/SSD-Mobilenet-v2/ssd_mobilenet_v2_coco.uff
# [TRT]    ------------------------------------------------
# [TRT]    Pre-Process   CPU   0.06297ms  CUDA   1.02302ms
# [TRT]    Network       CPU  43.03374ms  CUDA  39.60979ms
# [TRT]    Post-Process  CPU   0.05229ms  CUDA   0.00052ms
# [TRT]    Visualize     CPU   0.39219ms  CUDA   0.68109ms
# [TRT]    Total         CPU  43.54119ms  CUDA  41.31443ms
# [TRT]    ------------------------------------------------
#
# 2 objects detected
# detected obj 0  class #1 (person)  confidence=0.592773
# bounding box 0  (239.531250, 224.384766)  (311.718750, 368.349609)  w=72.187500  h=143.964844
# detected obj 1  class #1 (person)  confidence=0.619629
# bounding box 1  (619.687500, 92.812500)  (649.687500, 163.212891)  w=30.000000  h=70.400391
#
# [TRT]    ------------------------------------------------
# [TRT]    Timing Report /usr/local/bin/networks/SSD-Mobilenet-v2/ssd_mobilenet_v2_coco.uff
# [TRT]    ------------------------------------------------
# [TRT]    Pre-Process   CPU   0.11964ms  CUDA   1.12714ms
# [TRT]    Network       CPU  41.25204ms  CUDA  37.48760ms
# [TRT]    Post-Process  CPU   0.04208ms  CUDA   0.04214ms
# [TRT]    Visualize     CPU   0.20823ms  CUDA   0.42052ms
# [TRT]    Total         CPU  41.62199ms  CUDA  39.07740ms
# [TRT]    ------------------------------------------------
#
# 2 objects detected
# detected obj 0  class #1 (person)  confidence=0.598633
# bounding box 0  (245.156250, 223.857422)  (320.625000, 370.458984)  w=75.468750  h=146.601562
# detected obj 1  class #1 (person)  confidence=0.560059
# bounding box 1  (618.281250, 92.944336)  (646.406250, 164.003906)  w=28.125000  h=71.059570
#
# [TRT]    ------------------------------------------------
# [TRT]    Timing Report /usr/local/bin/networks/SSD-Mobilenet-v2/ssd_mobilenet_v2_coco.uff
# [TRT]    ------------------------------------------------
# [TRT]    Pre-Process   CPU   0.13631ms  CUDA   1.22625ms
# [TRT]    Network       CPU  41.24360ms  CUDA  37.44938ms
# [TRT]    Post-Process  CPU   0.05047ms  CUDA   0.04068ms
# [TRT]    Visualize     CPU   0.24969ms  CUDA   0.43437ms
# [TRT]    Total         CPU  41.68006ms  CUDA  39.15068ms
# [TRT]    ------------------------------------------------
#
# 2 objects detected
# detected obj 0  class #1 (person)  confidence=0.746094
# bounding box 0  (246.093750, 226.494141)  (322.500000, 367.294922)  w=76.406250  h=140.800781
# detected obj 1  class #1 (person)  confidence=0.501953
# bounding box 1  (459.843750, 158.994141)  (502.968750, 260.771484)  w=43.125000  h=101.777344
#
# [TRT]    ------------------------------------------------
# [TRT]    Timing Report /usr/local/bin/networks/SSD-Mobilenet-v2/ssd_mobilenet_v2_coco.uff
# [TRT]    ------------------------------------------------
# [TRT]    Pre-Process   CPU   0.20922ms  CUDA   1.19943ms
# [TRT]    Network       CPU  41.16422ms  CUDA  37.53432ms
# [TRT]    Post-Process  CPU   0.06672ms  CUDA   0.06661ms
# [TRT]    Visualize     CPU   0.33344ms  CUDA   0.48948ms
# [TRT]    Total         CPU  41.77361ms  CUDA  39.28984ms
# [TRT]    ------------------------------------------------
#
# 2 objects detected
# detected obj 0  class #1 (person)  confidence=0.763672
# bounding box 0  (250.781250, 229.130859)  (322.500000, 367.822266)  w=71.718750  h=138.691406
# detected obj 1  class #1 (person)  confidence=0.675293
# bounding box 1  (699.843750, 190.239258)  (739.218750, 321.416016)  w=39.375000  h=131.176758
#
# [TRT]    ------------------------------------------------
# [TRT]    Timing Report /usr/local/bin/networks/SSD-Mobilenet-v2/ssd_mobilenet_v2_coco.uff
# [TRT]    ------------------------------------------------
# [TRT]    Pre-Process   CPU   0.15250ms  CUDA   1.22521ms
# [TRT]    Network       CPU  41.56673ms  CUDA  37.77214ms
# [TRT]    Post-Process  CPU   0.08912ms  CUDA   0.03870ms
# [TRT]    Visualize     CPU   0.21094ms  CUDA   0.46844ms
# [TRT]    Total         CPU  42.01929ms  CUDA  39.50448ms
# [TRT]    ------------------------------------------------
#
# 3 objects detected
# detected obj 0  class #1 (person)  confidence=0.717285
# bounding box 0  (254.765625, 229.130859)  (323.203125, 367.822266)  w=68.437500  h=138.691406
# detected obj 1  class #1 (person)  confidence=0.728027
# bounding box 1  (703.593750, 191.689453)  (743.906250, 325.634766)  w=40.312500  h=133.945312
# detected obj 2  class #1 (person)  confidence=0.545410
# bounding box 2  (467.343750, 158.466797)  (505.781250, 239.941406)  w=38.437500  h=81.474609
#
# [TRT]    ------------------------------------------------
# [TRT]    Timing Report /usr/local/bin/networks/SSD-Mobilenet-v2/ssd_mobilenet_v2_coco.uff
# [TRT]    ------------------------------------------------
# [TRT]    Pre-Process   CPU   0.06813ms  CUDA   1.15583ms
# [TRT]    Network       CPU  42.65373ms  CUDA  38.76719ms
# [TRT]    Post-Process  CPU   0.04261ms  CUDA   0.04260ms
# [TRT]    Visualize     CPU   0.23375ms  CUDA   0.57594ms
# [TRT]    Total         CPU  42.99821ms  CUDA  40.54156ms
# [TRT]    ------------------------------------------------
#
# 3 objects detected
# detected obj 0  class #1 (person)  confidence=0.820312
# bounding box 0  (255.468750, 225.439453)  (318.750000, 365.712891)  w=63.281250  h=140.273438
# detected obj 1  class #1 (person)  confidence=0.725098
# bounding box 1  (711.562500, 187.470703)  (753.750000, 326.689453)  w=42.187500  h=139.218750
# detected obj 2  class #1 (person)  confidence=0.560059
# bounding box 2  (469.218750, 159.916992)  (507.656250, 242.709961)  w=38.437500  h=82.792969
#
# [TRT]    ------------------------------------------------
# [TRT]    Timing Report /usr/local/bin/networks/SSD-Mobilenet-v2/ssd_mobilenet_v2_coco.uff
# [TRT]    ------------------------------------------------
# [TRT]    Pre-Process   CPU   0.11604ms  CUDA   1.08104ms
# [TRT]    Network       CPU  41.31047ms  CUDA  37.38495ms
# [TRT]    Post-Process  CPU   0.04104ms  CUDA   0.04078ms
# [TRT]    Visualize     CPU   0.23079ms  CUDA   0.57208ms
# [TRT]    Total         CPU  41.69834ms  CUDA  39.07885ms
# [TRT]    ------------------------------------------------
#
# 3 objects detected
# detected obj 0  class #1 (person)  confidence=0.761719
# bounding box 0  (262.734375, 227.021484)  (322.734375, 362.548828)  w=60.000000  h=135.527344
# detected obj 1  class #1 (person)  confidence=0.650391
# bounding box 1  (711.562500, 189.448242)  (757.500000, 321.679688)  w=45.937500  h=132.231445
# detected obj 2  class #1 (person)  confidence=0.578613
# bounding box 2  (470.390625, 155.830078)  (509.062500, 251.542969)  w=38.671875  h=95.712891
#
# [TRT]    ------------------------------------------------
# [TRT]    Timing Report /usr/local/bin/networks/SSD-Mobilenet-v2/ssd_mobilenet_v2_coco.uff
# [TRT]    ------------------------------------------------
# [TRT]    Pre-Process   CPU   0.06328ms  CUDA   1.08031ms
# [TRT]    Network       CPU  41.52225ms  CUDA  37.62963ms
# [TRT]    Post-Process  CPU   0.08979ms  CUDA   0.08875ms
# [TRT]    Visualize     CPU   0.30777ms  CUDA   0.56156ms
# [TRT]    Total         CPU  41.98309ms  CUDA  39.36026ms
# [TRT]    ------------------------------------------------
#
# 1 objects detected
# detected obj 0  class #1 (person)  confidence=0.645020
# bounding box 0  (472.500000, 148.051758)  (514.687500, 257.475586)  w=42.187500  h=109.423828
#
# [TRT]    ------------------------------------------------
# [TRT]    Timing Report /usr/local/bin/networks/SSD-Mobilenet-v2/ssd_mobilenet_v2_coco.uff
# [TRT]    ------------------------------------------------
# [TRT]    Pre-Process   CPU   0.09552ms  CUDA   1.07641ms
# [TRT]    Network       CPU  41.28464ms  CUDA  37.49865ms
# [TRT]    Post-Process  CPU   0.03422ms  CUDA   0.03391ms
# [TRT]    Visualize     CPU   0.17438ms  CUDA   0.25521ms
# [TRT]    Total         CPU  41.58876ms  CUDA  38.86417ms
# [TRT]    ------------------------------------------------
#
# 1 objects detected
# detected obj 0  class #1 (person)  confidence=0.766113
# bounding box 0  (472.734375, 147.392578)  (513.281250, 257.080078)  w=40.546875  h=109.687500
#
# [TRT]    ------------------------------------------------
# [TRT]    Timing Report /usr/local/bin/networks/SSD-Mobilenet-v2/ssd_mobilenet_v2_coco.uff
# [TRT]    ------------------------------------------------
# [TRT]    Pre-Process   CPU   0.07953ms  CUDA   1.19375ms
# [TRT]    Network       CPU  41.30782ms  CUDA  37.52662ms
# [TRT]    Post-Process  CPU   0.07162ms  CUDA   0.07115ms
# [TRT]    Visualize     CPU   0.29969ms  CUDA   0.31922ms
# [TRT]    Total         CPU  41.75866ms  CUDA  39.11073ms
# [TRT]    ------------------------------------------------
#
# 2 objects detected
# detected obj 0  class #1 (person)  confidence=0.645508
# bounding box 0  (721.406250, 199.599609)  (769.218750, 314.560547)  w=47.812500  h=114.960938
# detected obj 1  class #1 (person)  confidence=0.734863
# bounding box 1  (472.031250, 146.601562)  (515.156250, 258.925781)  w=43.125000  h=112.324219
#
# [TRT]    ------------------------------------------------
# [TRT]    Timing Report /usr/local/bin/networks/SSD-Mobilenet-v2/ssd_mobilenet_v2_coco.uff
# [TRT]    ------------------------------------------------
# [TRT]    Pre-Process   CPU   0.07995ms  CUDA   1.19641ms
# [TRT]    Network       CPU  41.35323ms  CUDA  37.62938ms
# [TRT]    Post-Process  CPU   0.08781ms  CUDA   0.09005ms
# [TRT]    Visualize     CPU   0.43235ms  CUDA   0.53729ms
# [TRT]    Total         CPU  41.95335ms  CUDA  39.45313ms
# [TRT]    ------------------------------------------------
#
# 2 objects detected
# detected obj 0  class #64 (potted plant)  confidence=0.501465
# bounding box 0  (183.398438, 210.673828)  (284.765625, 285.556641)  w=101.367188  h=74.882812
# detected obj 1  class #1 (person)  confidence=0.647949
# bounding box 1  (476.015625, 143.964844)  (518.437500, 260.507812)  w=42.421875  h=116.542969
#
# [TRT]    ------------------------------------------------
# [TRT]    Timing Report /usr/local/bin/networks/SSD-Mobilenet-v2/ssd_mobilenet_v2_coco.uff
# [TRT]    ------------------------------------------------
# [TRT]    Pre-Process   CPU   0.07141ms  CUDA   1.05505ms
# [TRT]    Network       CPU  41.31630ms  CUDA  37.52781ms
# [TRT]    Post-Process  CPU   0.05302ms  CUDA   0.05234ms
# [TRT]    Visualize     CPU   0.25225ms  CUDA   0.48302ms
# [TRT]    Total         CPU  41.69298ms  CUDA  39.11823ms
# [TRT]    ------------------------------------------------
#
# 1 objects detected
# detected obj 0  class #1 (person)  confidence=0.528320
# bounding box 0  (477.656250, 145.546875)  (520.781250, 250.488281)  w=43.125000  h=104.941406
#
# [TRT]    ------------------------------------------------
# [TRT]    Timing Report /usr/local/bin/networks/SSD-Mobilenet-v2/ssd_mobilenet_v2_coco.uff
# [TRT]    ------------------------------------------------
# [TRT]    Pre-Process   CPU   0.09521ms  CUDA   1.17526ms
# [TRT]    Network       CPU  41.28193ms  CUDA  37.52047ms
# [TRT]    Post-Process  CPU   0.05865ms  CUDA   0.05932ms
# [TRT]    Visualize     CPU   0.27037ms  CUDA   0.30042ms
# [TRT]    Total         CPU  41.70616ms  CUDA  39.05547ms
# [TRT]    ------------------------------------------------
#
# 2 objects detected
# detected obj 0  class #1 (person)  confidence=0.549316
# bounding box 0  (749.531250, 201.049805)  (825.468750, 343.300781)  w=75.937500  h=142.250977
# detected obj 1  class #1 (person)  confidence=0.544922
# bounding box 1  (480.000000, 144.096680)  (517.500000, 244.819336)  w=37.500000  h=100.722656
#
# [TRT]    ------------------------------------------------
# [TRT]    Timing Report /usr/local/bin/networks/SSD-Mobilenet-v2/ssd_mobilenet_v2_coco.uff
# [TRT]    ------------------------------------------------
# [TRT]    Pre-Process   CPU   0.06313ms  CUDA   1.16422ms
# [TRT]    Network       CPU  43.15900ms  CUDA  39.05427ms
# [TRT]    Post-Process  CPU   0.07490ms  CUDA   0.07474ms
# [TRT]    Visualize     CPU   0.43235ms  CUDA   0.57219ms
# [TRT]    Total         CPU  43.72937ms  CUDA  40.86542ms
# [TRT]    ------------------------------------------------
#
# 1 objects detected
# detected obj 0  class #1 (person)  confidence=0.507324
# bounding box 0  (755.625000, 188.789062)  (833.437500, 339.609375)  w=77.812500  h=150.820312
#
# [TRT]    ------------------------------------------------
# [TRT]    Timing Report /usr/local/bin/networks/SSD-Mobilenet-v2/ssd_mobilenet_v2_coco.uff
# [TRT]    ------------------------------------------------
# [TRT]    Pre-Process   CPU   0.08985ms  CUDA   1.09896ms
# [TRT]    Network       CPU  41.22355ms  CUDA  37.55797ms
# [TRT]    Post-Process  CPU   0.04724ms  CUDA   0.04646ms
# [TRT]    Visualize     CPU   0.24964ms  CUDA   0.32391ms
# [TRT]    Total         CPU  41.61027ms  CUDA  39.02729ms
# [TRT]    ------------------------------------------------
#
#
# [TRT]    ------------------------------------------------
# [TRT]    Timing Report /usr/local/bin/networks/SSD-Mobilenet-v2/ssd_mobilenet_v2_coco.uff
# [TRT]    ------------------------------------------------
# [TRT]    Pre-Process   CPU   0.08396ms  CUDA   1.25995ms
# [TRT]    Network       CPU  41.18855ms  CUDA  37.42703ms
# [TRT]    Post-Process  CPU   0.02958ms  CUDA   0.02990ms
# [TRT]    Visualize     CPU   0.24964ms  CUDA   0.32391ms
# [TRT]    Total         CPU  41.55173ms  CUDA  39.04078ms
# [TRT]    ------------------------------------------------
#
# 2 objects detected
# detected obj 0  class #64 (potted plant)  confidence=0.541504
# bounding box 0  (186.093750, 210.278320)  (284.765625, 286.875000)  w=98.671875  h=76.596680
# detected obj 1  class #1 (person)  confidence=0.523438
# bounding box 1  (584.531250, 118.652344)  (621.093750, 210.673828)  w=36.562500  h=92.021484
#
# [TRT]    ------------------------------------------------
# [TRT]    Timing Report /usr/local/bin/networks/SSD-Mobilenet-v2/ssd_mobilenet_v2_coco.uff
# [TRT]    ------------------------------------------------
# [TRT]    Pre-Process   CPU   0.10109ms  CUDA   1.18276ms
# [TRT]    Network       CPU  41.00610ms  CUDA  37.53735ms
# [TRT]    Post-Process  CPU   0.03235ms  CUDA   0.03229ms
# [TRT]    Visualize     CPU   0.19282ms  CUDA   0.44094ms
# [TRT]    Total         CPU  41.33235ms  CUDA  39.19333ms
# [TRT]    ------------------------------------------------
#
# 2 objects detected
# detected obj 0  class #64 (potted plant)  confidence=0.550293
# bounding box 0  (186.210938, 209.355469)  (286.875000, 287.929688)  w=100.664062  h=78.574219
# detected obj 1  class #1 (person)  confidence=0.510254
# bounding box 1  (581.718750, 116.147461)  (619.218750, 214.233398)  w=37.500000  h=98.085938
#
# [TRT]    ------------------------------------------------
# [TRT]    Timing Report /usr/local/bin/networks/SSD-Mobilenet-v2/ssd_mobilenet_v2_coco.uff
# [TRT]    ------------------------------------------------
# [TRT]    Pre-Process   CPU   0.09037ms  CUDA   1.05708ms
# [TRT]    Network       CPU  41.17771ms  CUDA  37.87656ms
# [TRT]    Post-Process  CPU   0.05458ms  CUDA   0.04359ms
# [TRT]    Visualize     CPU   0.32339ms  CUDA   0.48833ms
# [TRT]    Total         CPU  41.64605ms  CUDA  39.46557ms
# [TRT]    ------------------------------------------------
#
# 2 objects detected
# detected obj 0  class #64 (potted plant)  confidence=0.612793
# bounding box 0  (186.328125, 208.696289)  (287.578125, 288.720703)  w=101.250000  h=80.024414
# detected obj 1  class #1 (person)  confidence=0.502930
# bounding box 1  (582.656250, 117.795410)  (618.281250, 214.101562)  w=35.625000  h=96.306152
#
# [TRT]    ------------------------------------------------
# [TRT]    Timing Report /usr/local/bin/networks/SSD-Mobilenet-v2/ssd_mobilenet_v2_coco.uff
# [TRT]    ------------------------------------------------
# [TRT]    Pre-Process   CPU   0.08807ms  CUDA   1.14391ms
# [TRT]    Network       CPU  41.13771ms  CUDA  37.64479ms
# [TRT]    Post-Process  CPU   0.07073ms  CUDA   0.07167ms
# [TRT]    Visualize     CPU   0.34954ms  CUDA   0.54307ms
# [TRT]    Total         CPU  41.64605ms  CUDA  39.40343ms
# [TRT]    ------------------------------------------------
#
# 1 objects detected
# detected obj 0  class #64 (potted plant)  confidence=0.582520
# bounding box 0  (186.210938, 209.223633)  (285.937500, 288.193359)  w=99.726562  h=78.969727
#
# [TRT]    ------------------------------------------------
# [TRT]    Timing Report /usr/local/bin/networks/SSD-Mobilenet-v2/ssd_mobilenet_v2_coco.uff
# [TRT]    ------------------------------------------------
# [TRT]    Pre-Process   CPU   0.09323ms  CUDA   1.25802ms
# [TRT]    Network       CPU  41.34600ms  CUDA  37.80880ms
# [TRT]    Post-Process  CPU   0.06323ms  CUDA   0.06328ms
# [TRT]    Visualize     CPU   0.35230ms  CUDA   0.43443ms
# [TRT]    Total         CPU  41.85476ms  CUDA  39.56454ms
# [TRT]    ------------------------------------------------
#
# 1 objects detected
# detected obj 0  class #64 (potted plant)  confidence=0.616699
# bounding box 0  (186.093750, 210.146484)  (285.468750, 286.875000)  w=99.375000  h=76.728516
#
# [TRT]    ------------------------------------------------
# [TRT]    Timing Report /usr/local/bin/networks/SSD-Mobilenet-v2/ssd_mobilenet_v2_coco.uff
# [TRT]    ------------------------------------------------
# [TRT]    Pre-Process   CPU   0.11594ms  CUDA   1.21214ms
# [TRT]    Network       CPU  41.13995ms  CUDA  37.56807ms
# [TRT]    Post-Process  CPU   0.05078ms  CUDA   0.05052ms
# [TRT]    Visualize     CPU   0.29428ms  CUDA   0.38328ms
# [TRT]    Total         CPU  41.60095ms  CUDA  39.21401ms
# [TRT]    ------------------------------------------------
#
# 2 objects detected
# detected obj 0  class #64 (potted plant)  confidence=0.604492
# bounding box 0  (184.687500, 209.882812)  (287.109375, 287.666016)  w=102.421875  h=77.783203
# detected obj 1  class #1 (person)  confidence=0.547363
# bounding box 1  (583.593750, 114.038086)  (620.156250, 210.278320)  w=36.562500  h=96.240234
#
# [TRT]    ------------------------------------------------
# [TRT]    Timing Report /usr/local/bin/networks/SSD-Mobilenet-v2/ssd_mobilenet_v2_coco.uff
# [TRT]    ------------------------------------------------
# [TRT]    Pre-Process   CPU   0.10948ms  CUDA   1.28146ms
# [TRT]    Network       CPU  41.10041ms  CUDA  37.50333ms
# [TRT]    Post-Process  CPU   0.04615ms  CUDA   0.04599ms
# [TRT]    Visualize     CPU   0.23579ms  CUDA   0.44203ms
# [TRT]    Total         CPU  41.49183ms  CUDA  39.27282ms
# [TRT]    ------------------------------------------------
#
# 2 objects detected
# detected obj 0  class #64 (potted plant)  confidence=0.596191
# bounding box 0  (184.453125, 209.487305)  (286.406250, 287.666016)  w=101.953125  h=78.178711
# detected obj 1  class #1 (person)  confidence=0.538086
# bounding box 1  (584.531250, 117.465820)  (621.093750, 207.377930)  w=36.562500  h=89.912109
#
# [TRT]    ------------------------------------------------
# [TRT]    Timing Report /usr/local/bin/networks/SSD-Mobilenet-v2/ssd_mobilenet_v2_coco.uff
# [TRT]    ------------------------------------------------
# [TRT]    Pre-Process   CPU   0.08302ms  CUDA   1.21203ms
# [TRT]    Network       CPU  41.14563ms  CUDA  37.42047ms
# [TRT]    Post-Process  CPU   0.04432ms  CUDA   0.04422ms
# [TRT]    Visualize     CPU   0.24537ms  CUDA   0.43516ms
# [TRT]    Total         CPU  41.51834ms  CUDA  39.11187ms
# [TRT]    ------------------------------------------------
#
# 2 objects detected
# detected obj 0  class #1 (person)  confidence=0.517578
# bounding box 0  (316.640625, 200.126953)  (382.734375, 343.564453)  w=66.093750  h=143.437500
# detected obj 1  class #64 (potted plant)  confidence=0.595215
# bounding box 1  (183.984375, 209.750977)  (285.937500, 286.875000)  w=101.953125  h=77.124023
#
# [TRT]    ------------------------------------------------
# [TRT]    Timing Report /usr/local/bin/networks/SSD-Mobilenet-v2/ssd_mobilenet_v2_coco.uff
# [TRT]    ------------------------------------------------
# [TRT]    Pre-Process   CPU   0.08719ms  CUDA   1.25516ms
# [TRT]    Network       CPU  41.17693ms  CUDA  37.33167ms
# [TRT]    Post-Process  CPU   0.03162ms  CUDA   0.03156ms
# [TRT]    Visualize     CPU   0.18839ms  CUDA   0.53990ms
# [TRT]    Total         CPU  41.48412ms  CUDA  39.15829ms
# [TRT]    ------------------------------------------------
#
# 3 objects detected
# detected obj 0  class #1 (person)  confidence=0.503418
# bounding box 0  (317.578125, 190.634766)  (412.265625, 349.892578)  w=94.687500  h=159.257812
# detected obj 1  class #1 (person)  confidence=0.694824
# bounding box 1  (320.156250, 201.445312)  (382.500000, 343.300781)  w=62.343750  h=141.855469
# detected obj 2  class #64 (potted plant)  confidence=0.545898
# bounding box 2  (183.164062, 211.464844)  (283.125000, 285.556641)  w=99.960938  h=74.091797
#
# [TRT]    ------------------------------------------------
# [TRT]    Timing Report /usr/local/bin/networks/SSD-Mobilenet-v2/ssd_mobilenet_v2_coco.uff
# [TRT]    ------------------------------------------------
# [TRT]    Pre-Process   CPU   0.08526ms  CUDA   1.18333ms
# [TRT]    Network       CPU  41.22891ms  CUDA  37.57120ms
# [TRT]    Post-Process  CPU   0.06380ms  CUDA   0.06307ms
# [TRT]    Visualize     CPU   0.22417ms  CUDA   0.84510ms
# [TRT]    Total         CPU  41.60215ms  CUDA  39.66271ms
# [TRT]    ------------------------------------------------
#
# 3 objects detected
# detected obj 0  class #1 (person)  confidence=0.511230
# bounding box 0  (316.406250, 187.998047)  (407.812500, 348.310547)  w=91.406250  h=160.312500
# detected obj 1  class #1 (person)  confidence=0.595215
# bounding box 1  (323.437500, 201.313477)  (384.843750, 342.246094)  w=61.406250  h=140.932617
# detected obj 2  class #64 (potted plant)  confidence=0.569824
# bounding box 2  (184.218750, 211.333008)  (283.125000, 285.292969)  w=98.906250  h=73.959961
#
# [TRT]    ------------------------------------------------
# [TRT]    Timing Report /usr/local/bin/networks/SSD-Mobilenet-v2/ssd_mobilenet_v2_coco.uff
# [TRT]    ------------------------------------------------
# [TRT]    Pre-Process   CPU   0.08141ms  CUDA   1.22214ms
# [TRT]    Network       CPU  41.16787ms  CUDA  37.40391ms
# [TRT]    Post-Process  CPU   0.06568ms  CUDA   0.06458ms
# [TRT]    Visualize     CPU   0.51584ms  CUDA   0.81177ms
# [TRT]    Total         CPU  41.83080ms  CUDA  39.50240ms
# [TRT]    ------------------------------------------------
#
# 3 objects detected
# detected obj 0  class #1 (person)  confidence=0.687012
# bounding box 0  (319.921875, 188.129883)  (408.046875, 346.464844)  w=88.125000  h=158.334961
# detected obj 1  class #64 (potted plant)  confidence=0.575195
# bounding box 1  (184.218750, 211.596680)  (283.828125, 285.029297)  w=99.609375  h=73.432617
# detected obj 2  class #1 (person)  confidence=0.559082
# bounding box 2  (585.468750, 124.189453)  (620.156250, 192.216797)  w=34.687500  h=68.027344
#
# [TRT]    ------------------------------------------------
# [TRT]    Timing Report /usr/local/bin/networks/SSD-Mobilenet-v2/ssd_mobilenet_v2_coco.uff
# [TRT]    ------------------------------------------------
# [TRT]    Pre-Process   CPU   0.08958ms  CUDA   1.19297ms
# [TRT]    Network       CPU  41.16234ms  CUDA  37.39943ms
# [TRT]    Post-Process  CPU   0.04073ms  CUDA   0.04089ms
# [TRT]    Visualize     CPU   0.23573ms  CUDA   0.70240ms
# [TRT]    Total         CPU  41.52839ms  CUDA  39.33568ms
# [TRT]    ------------------------------------------------
#
# 5 objects detected
# detected obj 0  class #1 (person)  confidence=0.595215
# bounding box 0  (322.265625, 189.316406)  (408.984375, 343.564453)  w=86.718750  h=154.248047
# detected obj 1  class #64 (potted plant)  confidence=0.576660
# bounding box 1  (183.515625, 211.464844)  (283.593750, 285.029297)  w=100.078125  h=73.564453
# detected obj 2  class #1 (person)  confidence=0.503418
# bounding box 2  (802.031250, 199.204102)  (847.031250, 311.923828)  w=45.000000  h=112.719727
# detected obj 3  class #1 (person)  confidence=0.520996
# bounding box 3  (501.093750, 124.057617)  (537.656250, 209.487305)  w=36.562500  h=85.429688
# detected obj 4  class #1 (person)  confidence=0.667969
# bounding box 4  (587.343750, 122.277832)  (619.218750, 193.798828)  w=31.875000  h=71.520996
#
# [TRT]    ------------------------------------------------
# [TRT]    Timing Report /usr/local/bin/networks/SSD-Mobilenet-v2/ssd_mobilenet_v2_coco.uff
# [TRT]    ------------------------------------------------
# [TRT]    Pre-Process   CPU   0.06917ms  CUDA   1.19750ms
# [TRT]    Network       CPU  41.14463ms  CUDA  37.45578ms
# [TRT]    Post-Process  CPU   0.04448ms  CUDA   0.04427ms
# [TRT]    Visualize     CPU   0.26745ms  CUDA   0.95495ms
# [TRT]    Total         CPU  41.52573ms  CUDA  39.65250ms
# [TRT]    ------------------------------------------------
#
# ...
#
# 5 objects detected
# detected obj 0  class #1 (person)  confidence=0.540527
# bounding box 0  (82.148438, 261.826172)  (145.546875, 422.666016)  w=63.398438  h=160.839844
# detected obj 1  class #64 (potted plant)  confidence=0.723633
# bounding box 1  (181.523438, 207.773438)  (282.187500, 290.039062)  w=100.664062  h=82.265625
# detected obj 2  class #1 (person)  confidence=0.586914
# bounding box 2  (311.015625, 158.730469)  (360.234375, 285.029297)  w=49.218750  h=126.298828
# detected obj 3  class #1 (person)  confidence=0.831543
# bounding box 3  (577.500000, 81.870117)  (620.625000, 210.541992)  w=43.125000  h=128.671875
# detected obj 4  class #1 (person)  confidence=0.803223
# bounding box 4  (655.312500, 62.885742)  (692.812500, 141.459961)  w=37.500000  h=78.574219
#
# [TRT]    ------------------------------------------------
# [TRT]    Timing Report /usr/local/bin/networks/SSD-Mobilenet-v2/ssd_mobilenet_v2_coco.uff
# [TRT]    ------------------------------------------------
# [TRT]    Pre-Process   CPU   0.08761ms  CUDA   1.17729ms
# [TRT]    Network       CPU  42.02206ms  CUDA  38.50281ms
# [TRT]    Post-Process  CPU   0.05974ms  CUDA   0.05995ms
# [TRT]    Visualize     CPU   0.30131ms  CUDA   1.01714ms
# [TRT]    Total         CPU  42.47071ms  CUDA  40.75719ms
# [TRT]    ------------------------------------------------
#
# 4 objects detected
# detected obj 0  class #1 (person)  confidence=0.670410
# bounding box 0  (78.750000, 266.308594)  (142.968750, 423.457031)  w=64.218750  h=157.148438
# detected obj 1  class #64 (potted plant)  confidence=0.735840
# bounding box 1  (182.109375, 208.168945)  (281.718750, 289.511719)  w=99.609375  h=81.342773
# detected obj 2  class #1 (person)  confidence=0.827637
# bounding box 2  (577.031250, 80.288086)  (621.093750, 211.069336)  w=44.062500  h=130.781250
# detected obj 3  class #1 (person)  confidence=0.853516
# bounding box 3  (654.375000, 61.831055)  (693.750000, 143.964844)  w=39.375000  h=82.133789
#
# [TRT]    ------------------------------------------------
# [TRT]    Timing Report /usr/local/bin/networks/SSD-Mobilenet-v2/ssd_mobilenet_v2_coco.uff
# [TRT]    ------------------------------------------------
# [TRT]    Pre-Process   CPU   0.07990ms  CUDA   1.14224ms
# [TRT]    Network       CPU  41.24417ms  CUDA  37.58859ms
# [TRT]    Post-Process  CPU   0.06391ms  CUDA   0.06531ms
# [TRT]    Visualize     CPU   0.32490ms  CUDA   0.84365ms
# [TRT]    Total         CPU  41.71288ms  CUDA  39.63979ms
# [TRT]    ------------------------------------------------
#
# 5 objects detected
# detected obj 0  class #1 (person)  confidence=0.658203
# bounding box 0  (66.328125, 262.880859)  (138.984375, 427.939453)  w=72.656250  h=165.058594
# detected obj 1  class #64 (potted plant)  confidence=0.685547
# bounding box 1  (182.226562, 209.355469)  (280.781250, 288.193359)  w=98.554688  h=78.837891
# detected obj 2  class #1 (person)  confidence=0.596191
# bounding box 2  (303.750000, 164.267578)  (353.437500, 284.238281)  w=49.687500  h=119.970703
# detected obj 3  class #1 (person)  confidence=0.870605
# bounding box 3  (579.375000, 80.947266)  (620.625000, 209.091797)  w=41.250000  h=128.144531
# detected obj 4  class #1 (person)  confidence=0.896484
# bounding box 4  (660.468750, 67.203369)  (694.218750, 139.482422)  w=33.750000  h=72.279053
#
# [TRT]    ------------------------------------------------
# [TRT]    Timing Report /usr/local/bin/networks/SSD-Mobilenet-v2/ssd_mobilenet_v2_coco.uff
# [TRT]    ------------------------------------------------
# [TRT]    Pre-Process   CPU   0.07912ms  CUDA   1.17891ms
# [TRT]    Network       CPU  41.19225ms  CUDA  37.43661ms
# [TRT]    Post-Process  CPU   0.07172ms  CUDA   0.06261ms
# [TRT]    Visualize     CPU   0.40475ms  CUDA   1.01573ms
# [TRT]    Total         CPU  41.74783ms  CUDA  39.69386ms
# [TRT]    ------------------------------------------------
#
# 5 objects detected
# detected obj 0  class #1 (person)  confidence=0.775879
# bounding box 0  (62.460938, 272.636719)  (136.875000, 427.148438)  w=74.414062  h=154.511719
# detected obj 1  class #64 (potted plant)  confidence=0.638184
# bounding box 1  (181.757812, 210.673828)  (283.125000, 287.929688)  w=101.367188  h=77.255859
# detected obj 2  class #1 (person)  confidence=0.685059
# bounding box 2  (299.531250, 165.849609)  (349.687500, 282.919922)  w=50.156250  h=117.070312
# detected obj 3  class #1 (person)  confidence=0.875977
# bounding box 3  (579.375000, 81.079102)  (620.625000, 206.323242)  w=41.250000  h=125.244141
# detected obj 4  class #1 (person)  confidence=0.865234
# bounding box 4  (659.531250, 65.159912)  (694.218750, 139.746094)  w=34.687500  h=74.586182
#
# [TRT]    ------------------------------------------------
# [TRT]    Timing Report /usr/local/bin/networks/SSD-Mobilenet-v2/ssd_mobilenet_v2_coco.uff
# [TRT]    ------------------------------------------------
# [TRT]    Pre-Process   CPU   0.08349ms  CUDA   1.24328ms
# [TRT]    Network       CPU  41.18084ms  CUDA  37.43604ms
# [TRT]    Post-Process  CPU   0.06693ms  CUDA   0.06677ms
# [TRT]    Visualize     CPU   0.48516ms  CUDA   0.99599ms
# [TRT]    Total         CPU  41.81643ms  CUDA  39.74209ms
# [TRT]    ------------------------------------------------
#
# 5 objects detected
# detected obj 0  class #1 (person)  confidence=0.764648
# bounding box 0  (63.164062, 278.701172)  (136.875000, 431.630859)  w=73.710938  h=152.929688
# detected obj 1  class #64 (potted plant)  confidence=0.677734
# bounding box 1  (182.578125, 211.728516)  (283.359375, 287.138672)  w=100.781250  h=75.410156
# detected obj 2  class #1 (person)  confidence=0.662598
# bounding box 2  (299.062500, 164.663086)  (349.218750, 283.183594)  w=50.156250  h=118.520508
# detected obj 3  class #1 (person)  confidence=0.859863
# bounding box 3  (579.375000, 81.342773)  (620.625000, 207.114258)  w=41.250000  h=125.771484
# detected obj 4  class #1 (person)  confidence=0.872070
# bounding box 4  (660.000000, 63.577881)  (694.687500, 140.537109)  w=34.687500  h=76.959229
#
# [TRT]    ------------------------------------------------
# [TRT]    Timing Report /usr/local/bin/networks/SSD-Mobilenet-v2/ssd_mobilenet_v2_coco.uff
# [TRT]    ------------------------------------------------
# [TRT]    Pre-Process   CPU   0.14724ms  CUDA   1.17625ms
# [TRT]    Network       CPU  41.10818ms  CUDA  37.80339ms
# [TRT]    Post-Process  CPU   0.08026ms  CUDA   0.08078ms
# [TRT]    Visualize     CPU   0.50564ms  CUDA   0.99552ms
# [TRT]    Total         CPU  41.84132ms  CUDA  40.05594ms
# [TRT]    ------------------------------------------------
#
# 5 objects detected
# detected obj 0  class #1 (person)  confidence=0.795410
# bounding box 0  (52.675781, 280.810547)  (127.031250, 437.431641)  w=74.355469  h=156.621094
# detected obj 1  class #64 (potted plant)  confidence=0.585449
# bounding box 1  (181.523438, 212.255859)  (280.078125, 286.083984)  w=98.554688  h=73.828125
# detected obj 2  class #1 (person)  confidence=0.777344
# bounding box 2  (296.015625, 167.036133)  (348.984375, 288.193359)  w=52.968750  h=121.157227
# detected obj 3  class #1 (person)  confidence=0.873535
# bounding box 3  (579.375000, 83.913574)  (618.750000, 200.917969)  w=39.375000  h=117.004395
# detected obj 4  class #1 (person)  confidence=0.907715
# bounding box 4  (661.406250, 62.391357)  (697.031250, 140.141602)  w=35.625000  h=77.750244
#
# [TRT]    ------------------------------------------------
# [TRT]    Timing Report /usr/local/bin/networks/SSD-Mobilenet-v2/ssd_mobilenet_v2_coco.uff
# [TRT]    ------------------------------------------------
# [TRT]    Pre-Process   CPU   0.13495ms  CUDA   1.20057ms
# [TRT]    Network       CPU  41.09329ms  CUDA  37.61974ms
# [TRT]    Post-Process  CPU   0.06250ms  CUDA   0.06219ms
# [TRT]    Visualize     CPU   0.51402ms  CUDA   1.00589ms
# [TRT]    Total         CPU  41.80476ms  CUDA  39.88839ms
# [TRT]    ------------------------------------------------
#
# 5 objects detected
# detected obj 0  class #1 (person)  confidence=0.763672
# bounding box 0  (48.544922, 281.074219)  (128.085938, 439.277344)  w=79.541016  h=158.203125
# detected obj 1  class #64 (potted plant)  confidence=0.611816
# bounding box 1  (181.406250, 211.201172)  (279.375000, 287.402344)  w=97.968750  h=76.201172
# detected obj 2  class #1 (person)  confidence=0.745605
# bounding box 2  (296.015625, 165.058594)  (349.921875, 289.775391)  w=53.906250  h=124.716797
# detected obj 3  class #1 (person)  confidence=0.856934
# bounding box 3  (577.031250, 83.056641)  (618.281250, 203.291016)  w=41.250000  h=120.234375
# detected obj 4  class #1 (person)  confidence=0.910645
# bounding box 4  (660.000000, 61.040039)  (696.562500, 139.086914)  w=36.562500  h=78.046875
#
# [TRT]    ------------------------------------------------
# [TRT]    Timing Report /usr/local/bin/networks/SSD-Mobilenet-v2/ssd_mobilenet_v2_coco.uff
# [TRT]    ------------------------------------------------
# [TRT]    Pre-Process   CPU   0.11365ms  CUDA   1.24130ms
# [TRT]    Network       CPU  41.19835ms  CUDA  37.66458ms
# [TRT]    Post-Process  CPU   0.07599ms  CUDA   0.07563ms
# [TRT]    Visualize     CPU   0.58684ms  CUDA   1.01932ms
# [TRT]    Total         CPU  41.97482ms  CUDA  40.00083ms
# [TRT]    ------------------------------------------------
#
# 5 objects detected
# detected obj 0  class #1 (person)  confidence=0.774902
# bounding box 0  (41.660156, 284.765625)  (116.660156, 440.332031)  w=75.000000  h=155.566406
# detected obj 1  class #64 (potted plant)  confidence=0.514160
# bounding box 1  (181.171875, 211.201172)  (276.796875, 286.083984)  w=95.625000  h=74.882812
# detected obj 2  class #1 (person)  confidence=0.693359
# bounding box 2  (292.031250, 166.904297)  (347.812500, 291.621094)  w=55.781250  h=124.716797
# detected obj 3  class #1 (person)  confidence=0.792969
# bounding box 3  (575.625000, 81.738281)  (617.812500, 204.345703)  w=42.187500  h=122.607422
# detected obj 4  class #1 (person)  confidence=0.911621
# bounding box 4  (660.000000, 61.237793)  (696.562500, 137.373047)  w=36.562500  h=76.135254
#
# [TRT]    ------------------------------------------------
# [TRT]    Timing Report /usr/local/bin/networks/SSD-Mobilenet-v2/ssd_mobilenet_v2_coco.uff
# [TRT]    ------------------------------------------------
# [TRT]    Pre-Process   CPU   0.12677ms  CUDA   1.07719ms
# [TRT]    Network       CPU  41.18022ms  CUDA  37.89823ms
# [TRT]    Post-Process  CPU   0.09037ms  CUDA   0.08927ms
# [TRT]    Visualize     CPU   0.71548ms  CUDA   1.09083ms
# [TRT]    Total         CPU  42.11284ms  CUDA  40.15552ms
# [TRT]    ------------------------------------------------
#
# 4 objects detected
# detected obj 0  class #1 (person)  confidence=0.631836
# bounding box 0  (36.591797, 283.974609)  (112.265625, 445.869141)  w=75.673828  h=161.894531
# detected obj 1  class #1 (person)  confidence=0.693359
# bounding box 1  (292.031250, 166.508789)  (345.468750, 294.257812)  w=53.437500  h=127.749023
# detected obj 2  class #1 (person)  confidence=0.777832
# bounding box 2  (577.968750, 83.188477)  (618.281250, 200.522461)  w=40.312500  h=117.333984
# detected obj 3  class #1 (person)  confidence=0.879883
# bounding box 3  (659.062500, 59.490967)  (695.625000, 138.032227)  w=36.562500  h=78.541260
#
# [TRT]    ------------------------------------------------
# [TRT]    Timing Report /usr/local/bin/networks/SSD-Mobilenet-v2/ssd_mobilenet_v2_coco.uff
# [TRT]    ------------------------------------------------
# [TRT]    Pre-Process   CPU   0.08979ms  CUDA   1.15562ms
# [TRT]    Network       CPU  41.13017ms  CUDA  37.73610ms
# [TRT]    Post-Process  CPU   0.07474ms  CUDA   0.08099ms
# [TRT]    Visualize     CPU   0.27157ms  CUDA   0.80354ms
# [TRT]    Total         CPU  41.56627ms  CUDA  39.77625ms
# [TRT]    ------------------------------------------------
#
# 5 objects detected
# detected obj 0  class #1 (person)  confidence=0.763672
# bounding box 0  (34.716797, 281.601562)  (101.484375, 443.496094)  w=66.767578  h=161.894531
# detected obj 1  class #64 (potted plant)  confidence=0.544434
# bounding box 1  (180.234375, 210.673828)  (278.437500, 286.875000)  w=98.203125  h=76.201172
# detected obj 2  class #1 (person)  confidence=0.689453
# bounding box 2  (290.156250, 163.740234)  (344.531250, 295.576172)  w=54.375000  h=131.835938
# detected obj 3  class #1 (person)  confidence=0.782227
# bounding box 3  (577.968750, 84.902344)  (616.406250, 196.962891)  w=38.437500  h=112.060547
# detected obj 4  class #1 (person)  confidence=0.735840
# bounding box 4  (656.718750, 58.205566)  (695.156250, 138.427734)  w=38.437500  h=80.222168
#
# [TRT]    ------------------------------------------------
# [TRT]    Timing Report /usr/local/bin/networks/SSD-Mobilenet-v2/ssd_mobilenet_v2_coco.uff
# [TRT]    ------------------------------------------------
# [TRT]    Pre-Process   CPU   0.07177ms  CUDA   1.30266ms
# [TRT]    Network       CPU  41.18261ms  CUDA  37.41838ms
# [TRT]    Post-Process  CPU   0.06063ms  CUDA   0.06083ms
# [TRT]    Visualize     CPU   0.31751ms  CUDA   0.98021ms
# [TRT]    Total         CPU  41.63252ms  CUDA  39.76208ms
# [TRT]    ------------------------------------------------
#
# 5 objects detected
# detected obj 0  class #1 (person)  confidence=0.584961
# bounding box 0  (20.068359, 281.337891)  (92.343750, 453.251953)  w=72.275391  h=171.914062
# detected obj 1  class #64 (potted plant)  confidence=0.575195
# bounding box 1  (180.703125, 211.464844)  (281.015625, 286.611328)  w=100.312500  h=75.146484
# detected obj 2  class #1 (person)  confidence=0.723145
# bounding box 2  (287.343750, 165.717773)  (339.843750, 292.675781)  w=52.500000  h=126.958008
# detected obj 3  class #1 (person)  confidence=0.841309
# bounding box 3  (578.437500, 81.870117)  (615.937500, 197.885742)  w=37.500000  h=116.015625
# detected obj 4  class #1 (person)  confidence=0.762695
# bounding box 4  (659.531250, 59.293213)  (697.031250, 136.713867)  w=37.500000  h=77.420654
#
# [TRT]    ------------------------------------------------
# [TRT]    Timing Report /usr/local/bin/networks/SSD-Mobilenet-v2/ssd_mobilenet_v2_coco.uff
# [TRT]    ------------------------------------------------
# [TRT]    Pre-Process   CPU   0.19016ms  CUDA   1.27042ms
# [TRT]    Network       CPU  41.09428ms  CUDA  37.42505ms
# [TRT]    Post-Process  CPU   0.10995ms  CUDA   0.11016ms
# [TRT]    Visualize     CPU   0.76502ms  CUDA   1.16943ms
# [TRT]    Total         CPU  42.15940ms  CUDA  39.97505ms
# [TRT]    ------------------------------------------------
#
# [gstreamer] gstDecoder -- end of stream (EOS)
# 5 objects detected
# detected obj 0  class #64 (potted plant)  confidence=0.542480
# bounding box 0  (180.585938, 211.728516)  (281.953125, 287.138672)  w=101.367188  h=75.410156
# detected obj 1  class #1 (person)  confidence=0.653320
# bounding box 1  (286.406250, 165.717773)  (338.906250, 292.148438)  w=52.500000  h=126.430664
# detected obj 2  class #1 (person)  confidence=0.849121
# bounding box 2  (578.906250, 80.156250)  (617.343750, 200.917969)  w=38.437500  h=120.761719
# detected obj 3  class #1 (person)  confidence=0.528320
# bounding box 3  (371.484375, 198.808594)  (412.734375, 293.994141)  w=41.250000  h=95.185547
# detected obj 4  class #1 (person)  confidence=0.752930
# bounding box 4  (660.937500, 60.743408)  (696.562500, 131.572266)  w=35.625000  h=70.828857
#
# [TRT]    ------------------------------------------------
# [TRT]    Timing Report /usr/local/bin/networks/SSD-Mobilenet-v2/ssd_mobilenet_v2_coco.uff
# [TRT]    ------------------------------------------------
# [TRT]    Pre-Process   CPU   0.12552ms  CUDA   1.20417ms
# [TRT]    Network       CPU  41.14199ms  CUDA  37.67537ms
# [TRT]    Post-Process  CPU   0.07255ms  CUDA   0.06385ms
# [TRT]    Visualize     CPU   0.51662ms  CUDA   0.91042ms
# [TRT]    Total         CPU  41.85669ms  CUDA  39.85380ms
# [TRT]    ------------------------------------------------
#
# [gstreamer] gstDecoder -- end of stream (EOS) has been reached, stream has been closed
# detectnet:  shutting down...
# [gstreamer] gstDecoder -- stopping pipeline, transitioning to GST_STATE_NULL
# [gstreamer] gstDecoder -- pipeline stopped
# [gstreamer] gstEncoder -- shutting down pipeline, sending EOS
# [gstreamer] gstEncoder -- transitioning pipeline to GST_STATE_NULL
# [gstreamer] gstEncoder -- pipeline stopped
# detectnet:  shutdown complete.

# %%
# !video-viewer videos/pedestrians_tracking.mp4 rtp://192.168.1.13:1234
# Out:
# [gstreamer] initialized gstreamer, version 1.14.5.0
# [gstreamer] gstDecoder -- creating decoder for videos/pedestrians_tracking.mp4
# Opening in BLOCKING MODE
# NvMMLiteOpen : Block : BlockType = 261
# NVMEDIA: Reading vendor.tegra.display-size : status: 6
# NvMMLiteBlockCreate : Block : BlockType = 261
# [gstreamer] gstDecoder -- discovered video resolution: 960x540  (framerate 21.333334 Hz)
# [gstreamer] gstDecoder -- discovered video caps:  video/x-h264, stream-format=(string)byte-stream, alignment=(string)au, level=(string)4, profile=(string)constrained-baseline, width=(int)960, height=(int)540, framerate=(fraction)64/3, pixel-aspect-ratio=(fraction)1/1, interlace-mode=(string)progressive, colorimetry=(string)bt601, chroma-format=(string)4:2:0, bit-depth-luma=(uint)8, bit-depth-chroma=(uint)8, parsed=(boolean)true
# [gstreamer] gstDecoder -- pipeline string:
# [gstreamer] filesrc location=videos/pedestrians_tracking.mp4 ! qtdemux ! queue ! h264parse ! omxh264dec ! video/x-raw ! appsink name=mysink
# [video]  created gstDecoder from file:///jetson_telloProject/videos/pedestrians_tracking.mp4
# ------------------------------------------------
# gstDecoder video options:
# ------------------------------------------------
#   -- URI: file:///jetson_telloProject/videos/pedestrians_tracking.mp4
#      - protocol:  file
#      - location:  videos/pedestrians_tracking.mp4
#      - extension: mp4
#   -- deviceType: file
#   -- ioType:     input
#   -- codec:      h264
#   -- width:      960
#   -- height:     540
#   -- frameRate:  21.333334
#   -- bitRate:    0
#   -- numBuffers: 4
#   -- zeroCopy:   true
#   -- flipMethod: none
#   -- loop:       0
#   -- rtspLatency 2000
# ------------------------------------------------
# [gstreamer] gstEncoder -- codec not specified, defaulting to H.264
# [gstreamer] gstEncoder -- pipeline launch string:
# [gstreamer] appsrc name=mysource is-live=true do-timestamp=true format=3 ! omxh264enc bitrate=4000000 ! video/x-h264 !  rtph264pay config-interval=1 ! udpsink host=192.168.1.13 port=1234 auto-multicast=true
# [video]  created gstEncoder from rtp://192.168.1.13:1234
# ------------------------------------------------
# gstEncoder video options:
# ------------------------------------------------
#   -- URI: rtp://192.168.1.13:1234
#      - protocol:  rtp
#      - location:  192.168.1.13
#      - port:      1234
#   -- deviceType: ip
#   -- ioType:     output
#   -- codec:      h264
#   -- width:      0
#   -- height:     0
#   -- frameRate:  30.000000
#   -- bitRate:    4000000
#   -- numBuffers: 4
#   -- zeroCopy:   true
#   -- flipMethod: none
#   -- loop:       0
#   -- rtspLatency 2000
# ------------------------------------------------
# [OpenGL] failed to open X11 server connection.
# [OpenGL] failed to create X11 Window.
# [gstreamer] opening gstDecoder for streaming, transitioning pipeline to GST_STATE_PLAYING
# [gstreamer] gstreamer changed state from NULL to READY ==> mysink
# [gstreamer] gstreamer changed state from NULL to READY ==> capsfilter1
# [gstreamer] gstreamer changed state from NULL to READY ==> omxh264dec-omxh264dec0
# [gstreamer] gstreamer changed state from NULL to READY ==> h264parse1
# [gstreamer] gstreamer changed state from NULL to READY ==> queue0
# [gstreamer] gstreamer changed state from NULL to READY ==> qtdemux1
# [gstreamer] gstreamer changed state from NULL to READY ==> filesrc0
# [gstreamer] gstreamer changed state from NULL to READY ==> pipeline0
# [gstreamer] gstreamer changed state from READY to PAUSED ==> capsfilter1
# [gstreamer] gstreamer changed state from READY to PAUSED ==> omxh264dec-omxh264dec0
# [gstreamer] gstreamer changed state from READY to PAUSED ==> h264parse1
# [gstreamer] gstreamer stream status CREATE ==> src
# [gstreamer] gstreamer changed state from READY to PAUSED ==> queue0
# [gstreamer] gstreamer stream status ENTER ==> src
# [gstreamer] gstreamer stream status CREATE ==> sink
# [gstreamer] gstreamer changed state from READY to PAUSED ==> qtdemux1
# [gstreamer] gstreamer stream status ENTER ==> sink
# [gstreamer] gstreamer changed state from READY to PAUSED ==> filesrc0
#
# (video-viewer:1342): GStreamer-CRITICAL **: 20:54:28.900: gst_caps_is_empty: assertion 'GST_IS_CAPS (caps)' failed
#
# (video-viewer:1342): GStreamer-CRITICAL **: 20:54:28.901: gst_caps_truncate: assertion 'GST_IS_CAPS (caps)' failed
#
# (video-viewer:1342): GStreamer-CRITICAL **: 20:54:28.901: gst_caps_fixate: assertion 'GST_IS_CAPS (caps)' failed
#
# (video-viewer:1342): GStreamer-CRITICAL **: 20:54:28.901: gst_caps_get_structure: assertion 'GST_IS_CAPS (caps)' failed
#
# (video-viewer:1342): GStreamer-CRITICAL **: 20:54:28.901: gst_structure_get_string: assertion 'structure != NULL' failed
#
# (video-viewer:1342): GStreamer-CRITICAL **: 20:54:28.901: gst_mini_object_unref: assertion 'mini_object != NULL' failed
# NvMMLiteOpen : Block : BlockType = 261
# NVMEDIA: Reading vendor.tegra.display-size : status: 6
# NvMMLiteBlockCreate : Block : BlockType = 261
# Allocating new output: 960x544 (x 23), ThumbnailMode = 0
# OPENMAX: HandleNewStreamFormat: 3605: Send OMX_EventPortSettingsChanged: nFrameWidth = 960, nFrameHeight = 540
# [gstreamer] gstDecoder -- onPreroll()
# [gstreamer] gstreamer message stream-start ==> pipeline0
# [gstreamer] gstreamer stream status CREATE ==> src
# [gstreamer] gstreamer stream status ENTER ==> src
# [gstreamer] gstreamer message duration-changed ==> h264parse1
# [gstreamer] gstreamer mysink taglist, video-codec=(string)"H.264\ /\ AVC", maximum-bitrate=(uint)16871520, bitrate=(uint)2974333;
# [gstreamer] gstreamer mysink taglist, datetime=(datetime)2023-12-31T20:51:05Z, container-format=(string)Quicktime;
# [gstreamer] gstreamer mysink taglist, video-codec=(string)"H.264\ \(Constrained\ Baseline\ Profile\)", maximum-bitrate=(uint)16871520, bitrate=(uint)2974333;
# [gstreamer] gstDecoder recieve caps:  video/x-raw, format=(string)NV12, width=(int)960, height=(int)540, interlace-mode=(string)progressive, multiview-mode=(string)mono, multiview-flags=(GstVideoMultiviewFlagsSet)0:ffffffff:/right-view-first/left-flipped/left-flopped/right-flipped/right-flopped/half-aspect/mixed-mono, pixel-aspect-ratio=(fraction)1/1, chroma-site=(string)jpeg, colorimetry=(string)bt601, framerate=(fraction)64/3
# [gstreamer] gstDecoder -- recieved first frame, codec=h264 format=nv12 width=960 height=540 size=777600
# [gstreamer] gstreamer changed state from READY to PAUSED ==> mysink
# [gstreamer] gstreamer changed state from READY to PAUSED ==> pipeline0
# [gstreamer] gstreamer message async-done ==> pipeline0
# [gstreamer] gstreamer message new-clock ==> pipeline0
# [gstreamer] gstreamer changed state from PAUSED to PLAYING ==> mysink
# [gstreamer] gstreamer changed state from PAUSED to PLAYING ==> capsfilter1
# [gstreamer] gstreamer changed state from PAUSED to PLAYING ==> omxh264dec-omxh264dec0
# [gstreamer] gstreamer changed state from PAUSED to PLAYING ==> h264parse1
# [gstreamer] gstreamer changed state from PAUSED to PLAYING ==> queue0
# [gstreamer] gstreamer changed state from PAUSED to PLAYING ==> qtdemux1
# [gstreamer] gstreamer changed state from PAUSED to PLAYING ==> filesrc0
# [gstreamer] gstreamer changed state from PAUSED to PLAYING ==> pipeline0
# RingBuffer -- allocated 4 buffers (777600 bytes each, 3110400 bytes total)
# RingBuffer -- allocated 4 buffers (1555200 bytes each, 6220800 bytes total)
# video-viewer:  captured 1 frames (960 x 540)
# RingBuffer -- allocated 2 buffers (777600 bytes each, 1555200 bytes total)
# [gstreamer] gstEncoder-- starting pipeline, transitioning to GST_STATE_PLAYING
# [gstreamer] gstreamer changed state from NULL to READY ==> udpsink0
# [gstreamer] gstreamer changed state from NULL to READY ==> rtph264pay0
# [gstreamer] gstreamer changed state from NULL to READY ==> capsfilter2
# [gstreamer] gstreamer changed state from NULL to READY ==> omxh264enc-omxh264enc0
# [gstreamer] gstreamer changed state from NULL to READY ==> mysource
# [gstreamer] gstreamer changed state from NULL to READY ==> pipeline1
# [gstreamer] gstreamer changed state from READY to PAUSED ==> rtph264pay0
# [gstreamer] gstreamer changed state from READY to PAUSED ==> capsfilter2
# [gstreamer] gstreamer changed state from READY to PAUSED ==> omxh264enc-omxh264enc0
# [gstreamer] gstreamer stream status CREATE ==> src
# [gstreamer] gstreamer changed state from READY to PAUSED ==> mysource
# [gstreamer] gstreamer changed state from READY to PAUSED ==> pipeline1
# [gstreamer] gstreamer message new-clock ==> pipeline1
# [gstreamer] gstreamer stream status ENTER ==> src
# [gstreamer] gstreamer changed state from PAUSED to PLAYING ==> rtph264pay0
# [gstreamer] gstreamer changed state from PAUSED to PLAYING ==> capsfilter2
# [gstreamer] gstreamer changed state from PAUSED to PLAYING ==> omxh264enc-omxh264enc0
# [gstreamer] gstreamer changed state from PAUSED to PLAYING ==> mysource
# [gstreamer] gstEncoder -- new caps: video/x-raw, width=960, height=540, format=(string)I420, framerate=30/1
# video-viewer:  captured 2 frames (960 x 540)
# Framerate set to : 30 at NvxVideoEncoderSetParameterNvMMLiteOpen : Block : BlockType = 4
# ===== NVMEDIA: NVENC =====
# NvMMLiteBlockCreate : Block : BlockType = 4
# H264: Profile = 66, Level = 40
# NVMEDIA_ENC: bBlitMode is set to TRUE
# [gstreamer] gstreamer stream status CREATE ==> src
# [gstreamer] gstreamer stream status ENTER ==> src
# video-viewer:  captured 3 frames (960 x 540)
# [gstreamer] gstreamer message stream-start ==> pipeline1
# [gstreamer] gstreamer changed state from READY to PAUSED ==> udpsink0
# [gstreamer] gstreamer message async-done ==> pipeline1
# [gstreamer] gstreamer changed state from PAUSED to PLAYING ==> udpsink0
# [gstreamer] gstreamer changed state from PAUSED to PLAYING ==> pipeline1
# video-viewer:  captured 4 frames (960 x 540)
# video-viewer:  captured 5 frames (960 x 540)
# video-viewer:  captured 6 frames (960 x 540)
# [gstreamer] gstreamer mysink taglist, video-codec=(string)"H.264\ \(Constrained\ Baseline\ Profile\)", maximum-bitrate=(uint)16871520, bitrate=(uint)2974333, minimum-bitrate=(uint)1285632;
# video-viewer:  captured 7 frames (960 x 540)
# [gstreamer] gstreamer mysink taglist, video-codec=(string)"H.264\ \(Constrained\ Baseline\ Profile\)", maximum-bitrate=(uint)16871520, bitrate=(uint)2974333, minimum-bitrate=(uint)1030826;
# video-viewer:  captured 8 frames (960 x 540)
# video-viewer:  captured 9 frames (960 x 540)
# video-viewer:  captured 10 frames (960 x 540)
# video-viewer:  captured 11 frames (960 x 540)
# [gstreamer] gstreamer mysink taglist, video-codec=(string)"H.264\ \(Constrained\ Baseline\ Profile\)", maximum-bitrate=(uint)16871520, bitrate=(uint)2974333, minimum-bitrate=(uint)793258;
# video-viewer:  captured 12 frames (960 x 540)
# video-viewer:  captured 13 frames (960 x 540)
# video-viewer:  captured 14 frames (960 x 540)
# video-viewer:  captured 15 frames (960 x 540)
# video-viewer:  captured 16 frames (960 x 540)
# video-viewer:  captured 17 frames (960 x 540)
# video-viewer:  captured 18 frames (960 x 540)
# video-viewer:  captured 19 frames (960 x 540)
# video-viewer:  captured 20 frames (960 x 540)
# video-viewer:  captured 21 frames (960 x 540)
# video-viewer:  captured 22 frames (960 x 540)
# video-viewer:  captured 23 frames (960 x 540)
# video-viewer:  captured 24 frames (960 x 540)
# video-viewer:  captured 25 frames (960 x 540)
# video-viewer:  captured 26 frames (960 x 540)
# video-viewer:  captured 27 frames (960 x 540)
# video-viewer:  captured 28 frames (960 x 540)
# video-viewer:  captured 29 frames (960 x 540)
# video-viewer:  captured 30 frames (960 x 540)
# video-viewer:  captured 31 frames (960 x 540)
# video-viewer:  captured 32 frames (960 x 540)
# video-viewer:  captured 33 frames (960 x 540)
# video-viewer:  captured 34 frames (960 x 540)
# video-viewer:  captured 35 frames (960 x 540)
# video-viewer:  captured 36 frames (960 x 540)
# video-viewer:  captured 37 frames (960 x 540)
# video-viewer:  captured 38 frames (960 x 540)
# video-viewer:  captured 39 frames (960 x 540)
# video-viewer:  captured 40 frames (960 x 540)
# video-viewer:  captured 41 frames (960 x 540)
# video-viewer:  captured 42 frames (960 x 540)
# video-viewer:  captured 43 frames (960 x 540)
# video-viewer:  captured 44 frames (960 x 540)
# video-viewer:  captured 45 frames (960 x 540)
# video-viewer:  captured 46 frames (960 x 540)
# video-viewer:  captured 47 frames (960 x 540)
# video-viewer:  captured 48 frames (960 x 540)
# video-viewer:  captured 49 frames (960 x 540)
# video-viewer:  captured 50 frames (960 x 540)
# video-viewer:  captured 51 frames (960 x 540)
# video-viewer:  captured 52 frames (960 x 540)
# video-viewer:  captured 53 frames (960 x 540)
# video-viewer:  captured 54 frames (960 x 540)
# video-viewer:  captured 55 frames (960 x 540)
# video-viewer:  captured 56 frames (960 x 540)
# video-viewer:  captured 57 frames (960 x 540)
# video-viewer:  captured 58 frames (960 x 540)
# video-viewer:  captured 59 frames (960 x 540)
# video-viewer:  captured 60 frames (960 x 540)
# video-viewer:  captured 61 frames (960 x 540)
# video-viewer:  captured 62 frames (960 x 540)
# video-viewer:  captured 63 frames (960 x 540)
# video-viewer:  captured 64 frames (960 x 540)
# video-viewer:  captured 65 frames (960 x 540)
# video-viewer:  captured 66 frames (960 x 540)
# video-viewer:  captured 67 frames (960 x 540)
# video-viewer:  captured 68 frames (960 x 540)
# video-viewer:  captured 69 frames (960 x 540)
# video-viewer:  captured 70 frames (960 x 540)
# video-viewer:  captured 71 frames (960 x 540)
# video-viewer:  captured 72 frames (960 x 540)
# video-viewer:  captured 73 frames (960 x 540)
# video-viewer:  captured 74 frames (960 x 540)
# video-viewer:  captured 75 frames (960 x 540)
# video-viewer:  captured 76 frames (960 x 540)
# video-viewer:  captured 77 frames (960 x 540)
# video-viewer:  captured 78 frames (960 x 540)
# video-viewer:  captured 79 frames (960 x 540)
# video-viewer:  captured 80 frames (960 x 540)
# video-viewer:  captured 81 frames (960 x 540)
# video-viewer:  captured 82 frames (960 x 540)
# video-viewer:  captured 83 frames (960 x 540)
# video-viewer:  captured 84 frames (960 x 540)
# video-viewer:  captured 85 frames (960 x 540)
# video-viewer:  captured 86 frames (960 x 540)
# video-viewer:  captured 87 frames (960 x 540)
# video-viewer:  captured 88 frames (960 x 540)
# video-viewer:  captured 89 frames (960 x 540)
# video-viewer:  captured 90 frames (960 x 540)
# video-viewer:  captured 91 frames (960 x 540)
# video-viewer:  captured 92 frames (960 x 540)
# video-viewer:  captured 93 frames (960 x 540)
# video-viewer:  captured 94 frames (960 x 540)
# video-viewer:  captured 95 frames (960 x 540)
# video-viewer:  captured 96 frames (960 x 540)
# video-viewer:  captured 97 frames (960 x 540)
# video-viewer:  captured 98 frames (960 x 540)
# video-viewer:  captured 99 frames (960 x 540)
# video-viewer:  captured 100 frames (960 x 540)
# video-viewer:  captured 101 frames (960 x 540)
# video-viewer:  captured 102 frames (960 x 540)
# video-viewer:  captured 103 frames (960 x 540)
# video-viewer:  captured 104 frames (960 x 540)
# video-viewer:  captured 105 frames (960 x 540)
# video-viewer:  captured 106 frames (960 x 540)
# video-viewer:  captured 107 frames (960 x 540)
# video-viewer:  captured 108 frames (960 x 540)
# video-viewer:  captured 109 frames (960 x 540)
# video-viewer:  captured 110 frames (960 x 540)
# video-viewer:  captured 111 frames (960 x 540)
# video-viewer:  captured 112 frames (960 x 540)
# video-viewer:  captured 113 frames (960 x 540)
# video-viewer:  captured 114 frames (960 x 540)
# video-viewer:  captured 115 frames (960 x 540)
# video-viewer:  captured 116 frames (960 x 540)
# video-viewer:  captured 117 frames (960 x 540)
# video-viewer:  captured 118 frames (960 x 540)
# video-viewer:  captured 119 frames (960 x 540)
# video-viewer:  captured 120 frames (960 x 540)
# video-viewer:  captured 121 frames (960 x 540)
# video-viewer:  captured 122 frames (960 x 540)
# video-viewer:  captured 123 frames (960 x 540)
# video-viewer:  captured 124 frames (960 x 540)
# video-viewer:  captured 125 frames (960 x 540)
# video-viewer:  captured 126 frames (960 x 540)
# video-viewer:  captured 127 frames (960 x 540)
# video-viewer:  captured 128 frames (960 x 540)
# video-viewer:  captured 129 frames (960 x 540)
# video-viewer:  captured 130 frames (960 x 540)
# video-viewer:  captured 131 frames (960 x 540)
# video-viewer:  captured 132 frames (960 x 540)
# video-viewer:  captured 133 frames (960 x 540)
# video-viewer:  captured 134 frames (960 x 540)
# video-viewer:  captured 135 frames (960 x 540)
# video-viewer:  captured 136 frames (960 x 540)
# video-viewer:  captured 137 frames (960 x 540)
# video-viewer:  captured 138 frames (960 x 540)
# video-viewer:  captured 139 frames (960 x 540)
# video-viewer:  captured 140 frames (960 x 540)
# video-viewer:  captured 141 frames (960 x 540)
# video-viewer:  captured 142 frames (960 x 540)
# video-viewer:  captured 143 frames (960 x 540)
# video-viewer:  captured 144 frames (960 x 540)
# video-viewer:  captured 145 frames (960 x 540)
# video-viewer:  captured 146 frames (960 x 540)
# video-viewer:  captured 147 frames (960 x 540)
# video-viewer:  captured 148 frames (960 x 540)
# video-viewer:  captured 149 frames (960 x 540)
# video-viewer:  captured 150 frames (960 x 540)
# video-viewer:  captured 151 frames (960 x 540)
# video-viewer:  captured 152 frames (960 x 540)
# video-viewer:  captured 153 frames (960 x 540)
# video-viewer:  captured 154 frames (960 x 540)
# video-viewer:  captured 155 frames (960 x 540)
# video-viewer:  captured 156 frames (960 x 540)
# video-viewer:  captured 157 frames (960 x 540)
# video-viewer:  captured 158 frames (960 x 540)
# video-viewer:  captured 159 frames (960 x 540)
# video-viewer:  captured 160 frames (960 x 540)
# video-viewer:  captured 161 frames (960 x 540)
# video-viewer:  captured 162 frames (960 x 540)
# video-viewer:  captured 163 frames (960 x 540)
# video-viewer:  captured 164 frames (960 x 540)
# video-viewer:  captured 165 frames (960 x 540)
# video-viewer:  captured 166 frames (960 x 540)
# video-viewer:  captured 167 frames (960 x 540)
# video-viewer:  captured 168 frames (960 x 540)
# video-viewer:  captured 169 frames (960 x 540)
# video-viewer:  captured 170 frames (960 x 540)
# video-viewer:  captured 171 frames (960 x 540)
# video-viewer:  captured 172 frames (960 x 540)
# video-viewer:  captured 173 frames (960 x 540)
# video-viewer:  captured 174 frames (960 x 540)
# video-viewer:  captured 175 frames (960 x 540)
# video-viewer:  captured 176 frames (960 x 540)
# video-viewer:  captured 177 frames (960 x 540)
# video-viewer:  captured 178 frames (960 x 540)
# video-viewer:  captured 179 frames (960 x 540)
# video-viewer:  captured 180 frames (960 x 540)
# video-viewer:  captured 181 frames (960 x 540)
# video-viewer:  captured 182 frames (960 x 540)
# video-viewer:  captured 183 frames (960 x 540)
# video-viewer:  captured 184 frames (960 x 540)
# video-viewer:  captured 185 frames (960 x 540)
# video-viewer:  captured 186 frames (960 x 540)
# video-viewer:  captured 187 frames (960 x 540)
# video-viewer:  captured 188 frames (960 x 540)
# video-viewer:  captured 189 frames (960 x 540)
# video-viewer:  captured 190 frames (960 x 540)
# video-viewer:  captured 191 frames (960 x 540)
# video-viewer:  captured 192 frames (960 x 540)
# video-viewer:  captured 193 frames (960 x 540)
# video-viewer:  captured 194 frames (960 x 540)
# video-viewer:  captured 195 frames (960 x 540)
# video-viewer:  captured 196 frames (960 x 540)
# video-viewer:  captured 197 frames (960 x 540)
# video-viewer:  captured 198 frames (960 x 540)
# video-viewer:  captured 199 frames (960 x 540)
# video-viewer:  captured 200 frames (960 x 540)
# video-viewer:  captured 201 frames (960 x 540)
# video-viewer:  captured 202 frames (960 x 540)
# video-viewer:  captured 203 frames (960 x 540)
# video-viewer:  captured 204 frames (960 x 540)
# video-viewer:  captured 205 frames (960 x 540)
# video-viewer:  captured 206 frames (960 x 540)
# [gstreamer] gstDecoder -- end of stream (EOS)
# video-viewer:  captured 207 frames (960 x 540)
# [gstreamer] gstDecoder -- end of stream (EOS) has been reached, stream has been closed
# video-viewer:  failed to capture video frame
# video-viewer:  shutting down...
# [gstreamer] gstDecoder -- stopping pipeline, transitioning to GST_STATE_NULL
# [gstreamer] gstDecoder -- pipeline stopped
# [gstreamer] gstEncoder -- shutting down pipeline, sending EOS
# [gstreamer] gstEncoder -- transitioning pipeline to GST_STATE_NULL
# [gstreamer] gstEncoder -- pipeline stopped
# video-viewer:  shutdown complete

# %% [markdown]
# # Test

# %%
import asyncio
from jetson.inference import detectNet
from jetson.utils import videoOutput
import jetsonTelloVideo.jetson_tello.app as jt

display = videoOutput("rtp://192.168.1.13:1234")
print('Created RTP Stream')

object_detector = detectNet("ssd-mobilenet-v2", threshold=0.5)
print('Created Object detector')

print(object_detector.GetThreshold())
print(object_detector.GetNumClasses())
# Out:
# Created RTP Stream
# Created Object detector
# 0.5
# 91
